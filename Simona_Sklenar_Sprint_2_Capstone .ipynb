# %% [markdown]
# ## Sprint 2: Advanced Preprocessing, EDA and Baseline Model Creation on Predicting Mushroom Toxicity
#
# #### Submitted by: Simona Sklenar

# %% [markdown]
# ##### Preliminaries

# %%
# Importing libraries:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from IPython.display import display

# %%
# Importing the data: 

df = pd.read_csv('C:/Users/simon/Python_2024/Mushroom_Cap_2024.csv')

# %% [markdown]
# ### Data Inspection

# %%
# Checking the shape:

print(df.shape)
# Out:
# (8124, 22)

# %%
# Checking the head:

df.head()
# Out:
#   cap_shape cap_surface cap_color  has_bruises     odor gill_attachment  \
# 0    convex      smooth     brown         True  pungent            free
# 1    convex      smooth    yellow         True   almond            free
# 2      bell      smooth     white         True    anise            free
# 3    convex       scaly     white         True  pungent            free
# 4    convex      smooth      gray        False     none            free
#
#   gill_spacing gill_size gill_color stalk_shape  ... stalk_color_above_ring  \
# 0        close    narrow      black   enlarging  ...                  white
# 1        close     broad      black   enlarging  ...                  white
# 2        close     broad      brown   enlarging  ...                  white
# 3        close    narrow      brown   enlarging  ...                  white
# 4      crowded     broad      black    tapering  ...                  white
#
#   stalk_color_below_ring veil_type veil_color number_of_rings   ring_type  \
# 0                  white   partial      white               o     pendant
# 1                  white   partial      white               o     pendant
# 2                  white   partial      white               o     pendant
# 3                  white   partial      white               o     pendant
# 4                  white   partial      white               o  evanescent
#
#   spore_print_color population  habitat is_poisonous
# 0             black  scattered    urban            1
# 1             brown   numerous  grasses            0
# 2             brown   numerous  meadows            0
# 3             black  scattered    urban            1
# 4             brown   abundant  grasses            0
#
# [5 rows x 22 columns]

# %%
# Checking variable data types:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cap_shape                  8124 non-null   object
#  1   cap_surface                8124 non-null   object
#  2   cap_color                  8124 non-null   object
#  3   has_bruises                8124 non-null   bool
#  4   odor                       8124 non-null   object
#  5   gill_attachment            8124 non-null   object
#  6   gill_spacing               8124 non-null   object
#  7   gill_size                  8124 non-null   object
#  8   gill_color                 8124 non-null   object
#  9   stalk_shape                8124 non-null   object
#  10  stalk_surface_above_ring   8124 non-null   object
#  11  stalk_surface_belows_ring  8124 non-null   object
#  12  stalk_color_above_ring     8124 non-null   object
#  13  stalk_color_below_ring     8124 non-null   object
#  14  veil_type                  8124 non-null   object
#  15  veil_color                 8124 non-null   object
#  16  number_of_rings            8124 non-null   object
#  17  ring_type                  8124 non-null   object
#  18  spore_print_color          8124 non-null   object
#  19  population                 8124 non-null   object
#  20  habitat                    8124 non-null   object
#  21  is_poisonous               8124 non-null   int64
# dtypes: bool(1), int64(1), object(20)
# memory usage: 1.3+ MB

# %%
# Checking for null values:

null_values = df.isnull().sum()
print(null_values)
# Out:
# cap_shape                    0
# cap_surface                  0
# cap_color                    0
# has_bruises                  0
# odor                         0
# gill_attachment              0
# gill_spacing                 0
# gill_size                    0
# gill_color                   0
# stalk_shape                  0
# stalk_surface_above_ring     0
# stalk_surface_belows_ring    0
# stalk_color_above_ring       0
# stalk_color_below_ring       0
# veil_type                    0
# veil_color                   0
# number_of_rings              0
# ring_type                    0
# spore_print_color            0
# population                   0
# habitat                      0
# is_poisonous                 0
# dtype: int64

# %%
# Checking for duplicate rows:

duplicate_rows = df[df.duplicated()]
print("Duplicate Rows:", duplicate_rows)
# Out:
# Duplicate Rows: Empty DataFrame
# Columns: [cap_shape, cap_surface, cap_color, has_bruises, odor, gill_attachment, gill_spacing, gill_size, gill_color, stalk_shape, stalk_surface_above_ring, stalk_surface_belows_ring, stalk_color_above_ring, stalk_color_below_ring, veil_type, veil_color, number_of_rings, ring_type, spore_print_color, population, habitat, is_poisonous]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Checking unique values in each column:

for column in df.columns:
    print(column, df[column].unique())
# Out:
# cap_shape ['convex' 'bell' 'sunken' 'flat' 'knobbed' 'conical']
# cap_surface ['smooth' 'scaly' 'fibrous' 'grooves']
# cap_color ['brown' 'yellow' 'white' 'gray' 'red' 'pink' 'buff' 'purple' 'cinnamon'
#  'green']
# has_bruises [ True False]
# odor ['pungent' 'almond' 'anise' 'none' 'foul' 'creosote' 'fishy' 'spicy'
#  'musty']
# gill_attachment ['free' 'attached']
# gill_spacing ['close' 'crowded']
# gill_size ['narrow' 'broad']
# gill_color ['black' 'brown' 'gray' 'pink' 'white' 'chocolate' 'purple' 'red' 'buff'
#  'green' 'yellow' 'orange']
# stalk_shape ['enlarging' 'tapering']
# stalk_surface_above_ring ['smooth' 'fibrous' 'silky' 'scaly']
# stalk_surface_belows_ring ['s' 'f' 'y' 'k']
# stalk_color_above_ring ['white' 'gray' 'pink' 'brown' 'buff' 'red' 'orange' 'cinnamon' 'yellow']
# stalk_color_below_ring ['white' 'pink' 'gray' 'buff' 'brown' 'red' 'yellow' 'orange' 'cinnamon']
# veil_type ['partial']
# veil_color ['white' 'brown' 'orange' 'yellow']
# number_of_rings ['o' 't' 'n']
# ring_type ['pendant' 'evanescent' 'large' 'flaring' 'none']
# spore_print_color ['black' 'brown' 'purple' 'chocolate' 'white' 'green' 'orange' 'yellow'
#  'buff']
# population ['scattered' 'numerous' 'abundant' 'several' 'solitary' 'clustered']
# habitat ['urban' 'grasses' 'meadows' 'woods' 'paths' 'waste' 'leaves']
# is_poisonous [1 0]

# %% [markdown]
# ### Univariate Analysis
#
# ##### Data visualization

# %% [markdown]
# In this section, we will be looking at distributions of each individual variable and examining the proportion of occurrences of the classes for each value of each independent variable. The purpose of this is to determince any biases and imbalances.

# %% [markdown]
# ##### 1. cap_shape

# %%
# Calculating frequency counts for cap_shape:
cap_shape_counts = df['cap_shape'].value_counts()

# Calculating proportions for cap_shape:
cap_shape_proportions = df['cap_shape'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for cap_shape:
cap_shape_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Cap_Shape', fontsize=13)
axes[0].set_xlabel('Cap_Shape', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)


# Plotting proportions for cap_shape:
cap_shape_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Cap_Shape', fontsize=13)
axes[1].set_xlabel('Cap_Shape', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for cap_shape:
print("Frequency counts for cap_shape:")
print(cap_shape_counts)
print("\nProportions for cap_shape:")
print(cap_shape_proportions)
# Out:
# Frequency counts for cap_shape:
# convex     3656
# flat       3152
# knobbed     828
# bell        452
# sunken       32
# conical       4
# Name: cap_shape, dtype: int64
#
# Proportions for cap_shape:
# convex     0.4500
# flat       0.3880
# knobbed    0.1019
# bell       0.0556
# sunken     0.0039
# conical    0.0005
# Name: cap_shape, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *convex* and *flat* cap shapes are the most prevalent, comprising around 84% of the data.
#
# - The rarest shapes are *sunken* and *conical*, each representing less than 0.5% of the data.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='cap_shape', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Cap_Shape', fontsize=13)
plt.xlabel('Cap_Shape', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
cap_shape_poison_counts = df.groupby(['cap_shape', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each cap_shape group:")
print(cap_shape_poison_counts)

cap_shape_poison_proportions = cap_shape_poison_counts.div(cap_shape_poison_counts.sum(axis=1), axis=0)
cap_shape_poison_proportions = cap_shape_poison_proportions.round(2)

print("\nProportions of poisonousness within each cap_shape group:")
print(cap_shape_poison_proportions)
# Out:
# Frequency count of poisonousness within each cap_shape group:
# is_poisonous     0     1
# cap_shape
# bell           404    48
# conical          0     4
# convex        1948  1708
# flat          1596  1556
# knobbed        228   600
# sunken          32     0
#
# Proportions of poisonousness within each cap_shape group:
# is_poisonous     0     1
# cap_shape
# bell          0.89  0.11
# conical       0.00  1.00
# convex        0.53  0.47
# flat          0.51  0.49
# knobbed       0.28  0.72
# sunken        1.00  0.00

# %% [markdown]
# ##### Observations:
#
# - *conical* shape is exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *sunken* shape is exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# - *bell* shape has a higher proportion of non-poisonous mushrooms (89%) compared to poisonous mushrooms (11%).
#
# - *convex* shape has a relatively balanced proportion, with 47% poisonous and 53% non-poisonous mushrooms.
#
# - *flat* shape also has a relatively balanced proportion, with 49% poisonous and 51% non-poisonous mushrooms.
#
# - *knobbed* shape is predominantly associated with poisonous mushrooms, with 72% poisonous and 28% non-poisonous mushrooms.
#
# ##### Conclusion:
#
# - Class imbalance is evident within certain cap shapes. *knobbed* mushrooms have a higher proportion of poisonous instances compared to non-poisonous instances, indicating a class imbalance skewed towards poisonous mushrooms; *conical* and *sunken* mushrooms have extreme class imbalances, with all instances belonging to only one class (poisonous for *conical* and non-poisonous for *sunken*).
#
# - *cap_shape* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 2. cap_surface

# %%
# Calculating frequency counts for cap_surface:
cap_surface_counts = df['cap_surface'].value_counts()

# Calculating proportions for cap_surface:
cap_surface_proportions = df['cap_surface'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for cap_surface:
cap_surface_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Cap_Surface', fontsize=13)
axes[0].set_xlabel('Cap_Surface', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)


# Plotting proportions for cap_surface:
cap_surface_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Cap_Surface', fontsize=13)
axes[1].set_xlabel('Cap_Surface', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout
plt.tight_layout()

# Showing plot
plt.show()

# Print frequency counts and proportions for cap_surface:
print("Frequency counts for cap_surface:")
print(cap_surface_counts)
print("\nProportions for cap_surface:")
print(cap_surface_proportions)
# Out:
# Frequency counts for cap_surface:
# scaly      3244
# smooth     2556
# fibrous    2320
# grooves       4
# Name: cap_surface, dtype: int64
#
# Proportions for cap_surface:
# scaly      0.3993
# smooth     0.3146
# fibrous    0.2856
# grooves    0.0005
# Name: cap_surface, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *scaly* surface comprises approximately 40% of the total data, followed by *smooth* (31%) and *fibrous* (29%).
#
# - *grooves* is the rarest surface type, making up only 0.05% of the data.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='cap_surface', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Cap_Surface', fontsize=13)
plt.xlabel('Cap_Surface', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
cap_surface_poison_counts = df.groupby(['cap_surface', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each cap_surface group:")
print(cap_surface_poison_counts)

cap_surface_poison_proportions = cap_surface_poison_counts.div(cap_surface_poison_counts.sum(axis=1), axis=0)
cap_surface_poison_proportions = cap_surface_poison_proportions.round(2)

print("\nProportions of poisonousness within each cap_surface group:")
print(cap_surface_poison_proportions)
# Out:
# Frequency count of poisonousness within each cap_surface group:
# is_poisonous     0     1
# cap_surface
# fibrous       1560   760
# grooves          0     4
# scaly         1504  1740
# smooth        1144  1412
#
# Proportions of poisonousness within each cap_surface group:
# is_poisonous     0     1
# cap_surface
# fibrous       0.67  0.33
# grooves       0.00  1.00
# scaly         0.46  0.54
# smooth        0.45  0.55

# %% [markdown]
# ##### Observations:
#
# - *grooves* surface is exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *fibrous* surface has a higher proportion of non-poisonous mushrooms (67%) compared to poisonous mushrooms (33%).
#
# - *scaly* surface has a relatively balanced proportion, with 54% poisonous and 46% non-poisonous mushrooms.
#
# - *smooth* surface also has a balanced proportion, with 55% poisonous and 45% non-poisonous mushrooms.
#
# ##### Conclusion:
#
# - Class imbalance is observed within certain cap surface categories. For example:
#
#     - *grooves* surfaces have an extreme class imbalance, with all instances being poisonous (100% poisonous).
#
#     - *fibrous* surfaces have a higher proportion of non-poisonous instances (67%) compared to poisonous instances (33%).
#
#     - *scaly* and *smooth* surfaces also exhibit class imbalance, with slightly higher proportions of poisonous instances compared to non-poisonous instances.
#
# - *cap_surface* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 3. cap_color

# %%
# Calculating frequency counts for cap_color:
cap_color_counts = df['cap_color'].value_counts()

# Calculating proportions for cap_color:
cap_color_proportions = df['cap_color'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for cap_color:
cap_color_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Cap_Color', fontsize=13)
axes[0].set_xlabel('Cap_Color', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for cap_color:
cap_color_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Cap_Color', fontsize=13)
axes[1].set_xlabel('Cap_Color', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for cap_color:
print("Frequency counts for cap_color:")
print(cap_color_counts)
print("\nProportions for cap_color:")
print(cap_color_proportions)
# Out:
# Frequency counts for cap_color:
# brown       2284
# gray        1840
# red         1500
# yellow      1072
# white       1040
# buff         168
# pink         144
# cinnamon      44
# purple        16
# green         16
# Name: cap_color, dtype: int64
#
# Proportions for cap_color:
# brown       0.2811
# gray        0.2265
# red         0.1846
# yellow      0.1320
# white       0.1280
# buff        0.0207
# pink        0.0177
# cinnamon    0.0054
# purple      0.0020
# green       0.0020
# Name: cap_color, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *brown* is the most common cap color, followed by *gray*, *red*, *yellow*, and *white* (all 5 colors represent 95% of the data).
#
# - *green*, *pink*, *cinnamon*, and *purple* are relatively rare colors.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='cap_color', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Cap_Color', fontsize=13)
plt.xlabel('Cap_Color', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
cap_color_poison_counts = df.groupby(['cap_color', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each cap_color group:")
print(cap_color_poison_counts)

cap_color_poison_proportions = cap_color_poison_counts.div(cap_color_poison_counts.sum(axis=1), axis=0)
cap_color_poison_proportions = cap_color_poison_proportions.round(2)

print("\nProportions of poisonousness within each cap_color group:")
print(cap_color_poison_proportions)
# Out:
# Frequency count of poisonousness within each cap_color group:
# is_poisonous     0     1
# cap_color
# brown         1264  1020
# buff            48   120
# cinnamon        32    12
# gray          1032   808
# green           16     0
# pink            56    88
# purple          16     0
# red            624   876
# white          720   320
# yellow         400   672
#
# Proportions of poisonousness within each cap_color group:
# is_poisonous     0     1
# cap_color
# brown         0.55  0.45
# buff          0.29  0.71
# cinnamon      0.73  0.27
# gray          0.56  0.44
# green         1.00  0.00
# pink          0.39  0.61
# purple        1.00  0.00
# red           0.42  0.58
# white         0.69  0.31
# yellow        0.37  0.63

# %% [markdown]
# ##### Observations:
#
# - *green* and *purple* colors are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# - *buff*, *cinnamon*, and *pink* colors have a higher proportion of poisonous mushrooms compared to non-poisonous mushrooms.
#
# - *red* and *yellow* colors have a higher proportion of poisonous mushrooms compared to non-poisonous mushrooms as well.
#
# - *white* color has a relatively balanced proportion, with 31% poisonous and 69% non-poisonous mushrooms.
#
# - *brown* and *gray* colors also have a relatively balanced proportion, with slightly higher proportions of non-poisonous mushrooms.
#
# ##### Conclusion:
#
# - The distribution of mushrooms across different cap colors shows a bias towards *brown*, *gray*, *red*, and *yellow* colors, which collectively represent the majority of the data.
#
# - Class imbalance is observed within certain cap color categories. *green* and *purple* indicate extreme class imbalance, with only poisonous instances present while *buff* and *cinnamon* also demonstrate substantial imbalances.
#
# - *cap_color* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 4. has_bruises

# %%
# Calculating frequency counts for has_bruises:
bruises_counts = df['has_bruises'].value_counts()

# Calculating proportions for has_bruises:
bruises_proportions = df['has_bruises'].value_counts(normalize=True).round(2)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for has_bruises:
bruises_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Bruises', fontsize=13)
axes[0].set_xlabel('Bruises', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for has_bruises:
bruises_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Bruises', fontsize=13)
axes[1].set_xlabel('Bruises', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for has_bruises:
print("Frequency counts for has_bruises:")
print(bruises_counts)
print("\nProportions for has_bruises:")
print(bruises_proportions)
# Out:
# Frequency counts for has_bruises:
# False    4748
# True     3376
# Name: has_bruises, dtype: int64
#
# Proportions for has_bruises:
# False    0.58
# True     0.42
# Name: has_bruises, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - Mushrooms without bruises comprise 58% of the dataset, while mushrooms with bruises make up 42% of the dataset.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(8, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='has_bruises', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Has_Bruises', fontsize=13)
plt.xlabel('Has_Bruises', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
has_bruises_poison_counts = df.groupby(['has_bruises', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each has_bruises group:")
print(has_bruises_poison_counts)

has_bruises_poison_proportions = has_bruises_poison_counts.div(has_bruises_poison_counts.sum(axis=1), axis=0)
has_bruises_poison_proportions = has_bruises_poison_proportions.round(2)

print("\nProportions of poisonousness within each has_bruises group:")
print(has_bruises_poison_proportions)
# Out:
# Frequency count of poisonousness within each has_bruises group:
# is_poisonous     0     1
# has_bruises
# False         1456  3292
# True          2752   624
#
# Proportions of poisonousness within each has_bruises group:
# is_poisonous     0     1
# has_bruises
# False         0.31  0.69
# True          0.82  0.18

# %% [markdown]
# ##### Observations:
#
# - Within the mushrooms without bruises, 69% are poisonous and 31% are non-poisonous.
#
# - Within the mushrooms with bruises, 18% are poisonous and 82% are non-poisonous.
#
# ##### Conclusion:
#
# - The dataset contains a higher proportion of mushrooms without bruises compared to mushrooms with bruises, indicating a bias towards mushrooms without bruises.
#
# - There is a significant class imbalance within the *has_bruises* variable since among mushrooms without bruises, 69% are poisonous, whereas among mushrooms with bruises, only 18% are poisonous.
#
# - *has_bruises* appears to be an important factor in predicting mushroom toxicity.

# %% [markdown]
# ##### 5. odor

# %%
# Calculating frequency counts for odor:
odor_counts = df['odor'].value_counts()

# Calculating proportions for odor:
odor_proportions = df['odor'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for odor:
odor_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Odor', fontsize=13)
axes[0].set_xlabel('Odor', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for odor:
odor_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Odor', fontsize=13)
axes[1].set_xlabel('Odor', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for odor:
print("Frequency counts for odor:")
print(odor_counts)
print("\nProportions for odor:")
print(odor_proportions)
# Out:
# Frequency counts for odor:
# none        3528
# foul        2160
# fishy        576
# spicy        576
# almond       400
# anise        400
# pungent      256
# creosote     192
# musty         36
# Name: odor, dtype: int64
#
# Proportions for odor:
# none        0.4343
# foul        0.2659
# fishy       0.0709
# spicy       0.0709
# almond      0.0492
# anise       0.0492
# pungent     0.0315
# creosote    0.0236
# musty       0.0044
# Name: odor, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *none* odor comprises the highest proportion of the dataset at 43.43%, with *musty* odor having the smallest proportion at 0.44%.
#
# - *none* and *foul* make up 70% of the dataset.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='odor', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Odor', fontsize=13)
plt.xlabel('Odor', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
odor_poison_counts = df.groupby(['odor', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each odor group:")
print(odor_poison_counts)

odor_poison_proportions = odor_poison_counts.div(odor_poison_counts.sum(axis=1), axis=0)
odor_poison_proportions = odor_poison_proportions.round(2)

print("\nProportions of poisonousness within each odor group:")
print(odor_poison_proportions)
# Out:
# Frequency count of poisonousness within each odor group:
# is_poisonous     0     1
# odor
# almond         400     0
# anise          400     0
# creosote         0   192
# fishy            0   576
# foul             0  2160
# musty            0    36
# none          3408   120
# pungent          0   256
# spicy            0   576
#
# Proportions of poisonousness within each odor group:
# is_poisonous     0     1
# odor
# almond        1.00  0.00
# anise         1.00  0.00
# creosote      0.00  1.00
# fishy         0.00  1.00
# foul          0.00  1.00
# musty         0.00  1.00
# none          0.97  0.03
# pungent       0.00  1.00
# spicy         0.00  1.00

# %% [markdown]
# ##### Observations:
#
# - Mushrooms with *creosote*, *fishy*, *foul*, *musty*, *pungent*, and *spicy* odors are exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *almond* and *anise'* odors are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# - *none* odor has a predominantly non-poisonous association, with 97% non-poisonous and 3% poisonous mushrooms.
#
# ##### Conclusion:
#
# - There is a bias towards the *none* order since mushrooms with no order make up the highest proportion of mushrooms in the dataset.
#
# - There is significant class imbalance within the *odor* variable, with the least extreme balance being with the *none* odor, where non-poisonous mushrooms dominate (97%). The other categories have maximum imbalances, either being exclusively poisonous or non-poisonous.
#
# - *odor* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 6. gill_attachment

# %%
# Calculating frequency counts for gill_attachment:
gill_attachment_counts = df['gill_attachment'].value_counts()

# Calculating proportions for gill_attachment:
gill_attachment_proportions = df['gill_attachment'].value_counts(normalize=True).round(2)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for gill_attachment:
gill_attachment_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Gill_Attachment', fontsize=13)
axes[0].set_xlabel('Gill_Attachment', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for gill_attachment:
gill_attachment_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Gill_Attachment', fontsize=13)
axes[1].set_xlabel('Gill_Attachment', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for gill_attachment:
print("Frequency counts for gill_attachment:")
print(gill_attachment_counts)
print("\nProportions for gill_attachment:")
print(gill_attachment_proportions)
# Out:
# Frequency counts for gill_attachment:
# free        7914
# attached     210
# Name: gill_attachment, dtype: int64
#
# Proportions for gill_attachment:
# free        0.97
# attached    0.03
# Name: gill_attachment, dtype: float64

# %% [markdown]
# ##### Observations:
#
# -  The majority of mushrooms having *free* gill attachment (97%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='gill_attachment', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Gill_Attachment', fontsize=13)
plt.xlabel('Gill_Attachment', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=12, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
gill_attachment_poison_counts = df.groupby(['gill_attachment', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each gill_attachment group:")
print(gill_attachment_poison_counts)

gill_attachment_poison_proportions = gill_attachment_poison_counts.div(gill_attachment_poison_counts.sum(axis=1), axis=0)
gill_attachment_poison_proportions = gill_attachment_poison_proportions.round(2)

print("\nProportions of poisonousness within each gill_attachment group:")
print(gill_attachment_poison_proportions)
# Out:
# Frequency count of poisonousness within each gill_attachment group:
# is_poisonous        0     1
# gill_attachment
# attached          192    18
# free             4016  3898
#
# Proportions of poisonousness within each gill_attachment group:
# is_poisonous        0     1
# gill_attachment
# attached         0.91  0.09
# free             0.51  0.49

# %% [markdown]
# ##### Observations:
#
# - For mushrooms with *attached* gill attachment, 91% are non-poisonous and 9% are poisonous.
#
# - For mushrooms with *free* gill attachment, 51% are non-poisonous and 49% are poisonous, making it a more balanced distribution.
#
# ##### Conclusion:
#
# - Representation bias is clear in this case, where *free* gill attachment dominates the dataset.
#
# - The class imbalance within the *gill_attachment* variable exists when considering poisonousness. While the majority of mushrooms with *attached* gill attachment are non-poisonous, the distribution is more balanced among mushrooms with *free* gill attachment.
#
# - *gill_attachment* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 7. gill_spacing

# %%
# Calculating frequency counts for gill_spacing:
gill_spacing_counts = df['gill_spacing'].value_counts()

# Calculating proportions for gill_spacing:
gill_spacing_proportions = df['gill_spacing'].value_counts(normalize=True).round(2)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for gill_spacing:
gill_spacing_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Gill_Spacing', fontsize=13)
axes[0].set_xlabel('Gill_Spacing', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for gill_spacing:
gill_spacing_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Gill_Spacing', fontsize=13)
axes[1].set_xlabel('Gill_Spacing', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for gill_spacing:
print("Frequency counts for gill_spacing:")
print(gill_spacing_counts)
print("\nProportions for gill_spacing:")
print(gill_spacing_proportions)
# Out:
# Frequency counts for gill_spacing:
# close      6812
# crowded    1312
# Name: gill_spacing, dtype: int64
#
# Proportions for gill_spacing:
# close      0.84
# crowded    0.16
# Name: gill_spacing, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *close* gill spacing comprises the majority of the dataset at 84%, while *crowded* gill spacing accounts for 16%.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='gill_spacing', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Gill_Spacing', fontsize=13)
plt.xlabel('Gill_Spacing', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
gill_spacing_poison_counts = df.groupby(['gill_spacing', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each gill_spacing group:")
print(gill_spacing_poison_counts)

gill_spacing_poison_proportions = gill_spacing_poison_counts.div(gill_spacing_poison_counts.sum(axis=1), axis=0)
gill_spacing_poison_proportions = gill_spacing_poison_proportions.round(2)

print("\nProportions of poisonousness within each gill_spacing group:")
print(gill_spacing_poison_proportions)
# Out:
# Frequency count of poisonousness within each gill_spacing group:
# is_poisonous     0     1
# gill_spacing
# close         3008  3804
# crowded       1200   112
#
# Proportions of poisonousness within each gill_spacing group:
# is_poisonous     0     1
# gill_spacing
# close         0.44  0.56
# crowded       0.91  0.09

# %% [markdown]
# ##### Observations:
#
# - For mushrooms with *close* gill spacing, 44% are non-poisonous and 56% are poisonous.
#
# - For mushrooms with *crowded* gill spacing, 91% are non-poisonous and 9% are poisonous.
#
# ###### Conclusion:
#
# - The majority of mushrooms in the dataset have *close* gill spacing. This indicates a representation bias, since *close* gill spacing makes up 84% of the data.
#
# - There is significant class imbalance within *gill_spacing* groups. For the *close* group, the proportions are more balanced, while for the *crowded* group, there is a considerable imbalance. For instance, while 56 % of mushrooms with *close* gill spacing are poisonous, a higher proportion of mushrooms with *crowded* gill spacing are non-poisonous (91%).
#
# - *gill_spacing* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 8. gill_size

# %%
# Calculating frequency counts for gill_size:
gill_size_counts = df['gill_size'].value_counts()

# Calculating proportions for gill_size:
gill_size_proportions = df['gill_size'].value_counts(normalize=True).round(2)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for gill_size:
gill_size_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Gill_Size', fontsize=13)
axes[0].set_xlabel('Gill_Size', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for gill_size:
gill_size_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Gill_Size', fontsize=13)
axes[1].set_xlabel('Gill_Size', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for gill_size:
print("Frequency counts for gill_size:")
print(gill_size_counts)
print("\nProportions for gill_size:")
print(gill_size_proportions)
# Out:
# Frequency counts for gill_size:
# broad     5612
# narrow    2512
# Name: gill_size, dtype: int64
#
# Proportions for gill_size:
# broad     0.69
# narrow    0.31
# Name: gill_size, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *broad* gill size makes up the majority of the dataset at 69%, while *narrow* gill size accounts for 31%.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='gill_size', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Gill_Size', fontsize=13)
plt.xlabel('Gill_Size', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
gill_size_poison_counts = df.groupby(['gill_size', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each gill_size group:")
print(gill_size_poison_counts)

gill_size_poison_proportions = gill_size_poison_counts.div(gill_size_poison_counts.sum(axis=1), axis=0)
gill_size_poison_proportions = gill_size_poison_proportions.round(2)

print("\nProportions of poisonousness within each gill_size group:")
print(gill_size_poison_proportions)
# Out:
# Frequency count of poisonousness within each gill_size group:
# is_poisonous     0     1
# gill_size
# broad         3920  1692
# narrow         288  2224
#
# Proportions of poisonousness within each gill_size group:
# is_poisonous     0     1
# gill_size
# broad         0.70  0.30
# narrow        0.11  0.89

# %% [markdown]
# ##### Observations:
#
# - For mushrooms with *broad* gill size, 70% are non-poisonous and 30% are poisonous.
#
# - For mushrooms with *narrow* gill size, 11% are non-poisonous and 89% are poisonous.
#
# ##### Conclusion:
#
# - The *gill_size* variable shows a significant representation bias, with the majority of mushrooms having *broad* gill size at 69%.
#
# - There is a significant class imbalance in the distribution of poisonous and non-poisonous mushrooms within each gill size category.
#
# - *gill_size* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 9. gill_color

# %%
# Calculating frequency counts for gill_color:
gill_color_counts = df['gill_color'].value_counts()

# Calculating proportions for gill_color:
gill_color_proportions = df['gill_color'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for gill_color:
gill_color_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Gill_Color', fontsize=13)
axes[0].set_xlabel('Gill_Color', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for gill_color:
gill_color_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Gill_Color', fontsize=13)
axes[1].set_xlabel('Gill_Color', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for gill_color:
print("Frequency counts for gill_color:")
print(gill_color_counts)
print("\nProportions for gill_color:")
print(gill_color_proportions)
# Out:
# Frequency counts for gill_color:
# buff         1728
# pink         1492
# white        1202
# brown        1048
# gray          752
# chocolate     732
# purple        492
# black         408
# red            96
# yellow         86
# orange         64
# green          24
# Name: gill_color, dtype: int64
#
# Proportions for gill_color:
# buff         0.2127
# pink         0.1837
# white        0.1480
# brown        0.1290
# gray         0.0926
# chocolate    0.0901
# purple       0.0606
# black        0.0502
# red          0.0118
# yellow       0.0106
# orange       0.0079
# green        0.0030
# Name: gill_color, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - The most prevalent gill colors are *buff*, *pink*, and *white*, with all comprising approximately 55% of the dataset.
#
# - Rare gill colors are *purple*, *black*, *red*, *yellow*, *orange*, and *green*, with all making up 8% of the dataset.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='gill_color', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Gill_Color', fontsize=13)
plt.xlabel('Gill_Color', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
gill_color_poison_counts = df.groupby(['gill_color', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each gill_color group:")
print(gill_color_poison_counts)

gill_color_poison_proportions = gill_color_poison_counts.div(gill_color_poison_counts.sum(axis=1), axis=0)
gill_color_poison_proportions = gill_color_poison_proportions.round(2)

print("\nProportions of poisonousness within each gill_color group:")
print(gill_color_poison_proportions)
# Out:
# Frequency count of poisonousness within each gill_color group:
# is_poisonous    0     1
# gill_color
# black         344    64
# brown         936   112
# buff            0  1728
# chocolate     204   528
# gray          248   504
# green           0    24
# orange         64     0
# pink          852   640
# purple        444    48
# red            96     0
# white         956   246
# yellow         64    22
#
# Proportions of poisonousness within each gill_color group:
# is_poisonous     0     1
# gill_color
# black         0.84  0.16
# brown         0.89  0.11
# buff          0.00  1.00
# chocolate     0.28  0.72
# gray          0.33  0.67
# green         0.00  1.00
# orange        1.00  0.00
# pink          0.57  0.43
# purple        0.90  0.10
# red           1.00  0.00
# white         0.80  0.20
# yellow        0.74  0.26

# %% [markdown]
# ##### Observations:
#
# - Gill colors such as *chocolate*, *purple*, and *gray* have a higher proportion of poisonous mushrooms, with approximately 72%, 10%, and 67% of mushrooms in these colors being poisonous, respectively.
#
# -  Gill colors like *white*, *brown*, and *black* have a higher proportion of non-poisonous mushrooms, with approximately 80%, 89%, and 84% of mushrooms in these colors being non-poisonous, respectively.
#
# ##### Conclusions:
#
# - There is representation bias as seen in the various frequency counts across different gill colors. For example, *buff*, *pink*, and *white* gill colors have relatively high frequency counts, while *green* and *orange* gill colors have much lower frequency counts, indicating a bias towards *buff*, *pink*, and *white*.
#
# - Some gill colors exhibit an extreme class imbalance. For example, all mushrooms with *buff* and *green* gill colors are poisonous (100%), while those with *orange* and *red* gill colors are non-poisonous (100%).
#
# - *gill_color* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 10. stalk_shape

# %%
# Calculating frequency counts for stalk_shape:
stalk_shape_counts = df['stalk_shape'].value_counts()

# Calculating proportions for stalk_shape:
stalk_shape_proportions = df['stalk_shape'].value_counts(normalize=True)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for stalk_shape:
stalk_shape_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Stalk_Shape', fontsize=13)
axes[0].set_xlabel('Stalk_Shape', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for stalk_shape:
stalk_shape_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Stalk_Shape', fontsize=13)
axes[1].set_xlabel('Stalk_Shape', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for stalk_shape:
print("Frequency counts for stalk_shape:")
print(stalk_shape_counts)
print("\nProportions for stalk_shape:")
print(stalk_shape_proportions)
# Out:
# Frequency counts for stalk_shape:
# tapering     4608
# enlarging    3516
# Name: stalk_shape, dtype: int64
#
# Proportions for stalk_shape:
# tapering     0.567208
# enlarging    0.432792
# Name: stalk_shape, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - The proportions of mushrooms with tapering stalk shape (56.72%) are higher than those with enlarging stalk shape (43.28%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='stalk_shape', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Stalk_Shape', fontsize=13)
plt.xlabel('Stalk_Shape', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
stalk_shape_poison_counts = df.groupby(['stalk_shape', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each stalk_shape group:")
print(stalk_shape_poison_counts)

stalk_shape_poison_proportions = stalk_shape_poison_counts.div(stalk_shape_poison_counts.sum(axis=1), axis=0)
stalk_shape_poison_proportions = stalk_shape_poison_proportions.round(2)

print("\nProportions of poisonousness within each stalk_shape group:")
print(stalk_shape_poison_proportions)
# Out:
# Frequency count of poisonousness within each stalk_shape group:
# is_poisonous     0     1
# stalk_shape
# enlarging     1616  1900
# tapering      2592  2016
#
# Proportions of poisonousness within each stalk_shape group:
# is_poisonous     0     1
# stalk_shape
# enlarging     0.46  0.54
# tapering      0.56  0.44

# %% [markdown]
# ##### Observations:
#
# - For mushroom with an enlarging stalk shape, 46% are non-poisonous and 54% are poisonous.
#
# - For mushrooms with tapering stalk shape, 56% are non-poisonous and 44% are poisonous.
#
# ##### Conclusion:
#
# - There is a bias towards *tapering* stalks since there are significantly more observations for *tapering* stalks.
#
# - There is only a slight (non significant) class imbalance since the ratio between non-poisonous and poisonous mushrooms in both groups is almost evenly split.
#
# - *stalk_shape* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 11. stalk_surface_above_ring

# %%
# Calculating frequency counts for stalk_surface_above_ring:
stalk_surface_above_ring_counts = df['stalk_surface_above_ring'].value_counts()

# Calculating proportions for stalk_surface_above_ring:
stalk_surface_above_ring_proportions = df['stalk_surface_above_ring'].value_counts(normalize=True)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for stalk_surface_above_ring:
stalk_surface_above_ring_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Stalk_Surface_Above_Ring', fontsize=13)
axes[0].set_xlabel('Stalk_Surface_Above_Ring', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for stalk_surface_above_ring:
stalk_surface_above_ring_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Stalk_Surface_Above_Ring', fontsize=13)
axes[1].set_xlabel('Stalk_Surface_Above_Ring', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for stalk_surface_above_ring:
print("Frequency counts for stalk_surface_above_ring:")
print(stalk_surface_above_ring_counts)
print("\nProportions for stalk_surface_above_ring:")
print(stalk_surface_above_ring_proportions)
# Out:
# Frequency counts for stalk_surface_above_ring:
# smooth     5176
# silky      2372
# fibrous     552
# scaly        24
# Name: stalk_surface_above_ring, dtype: int64
#
# Proportions for stalk_surface_above_ring:
# smooth     0.637125
# silky      0.291974
# fibrous    0.067947
# scaly      0.002954
# Name: stalk_surface_above_ring, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *smooth* surface makes up approximately 64% of the total data, making it the most prevalent surface type.
#
# - *silky* surface represents around 29% of the data, followed by *fibrous* (7%) and *scaly* (0.30%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='stalk_surface_above_ring', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Stalk_Surface_Above_Ring', fontsize=13)
plt.xlabel('Stalk_Surface_Above_Ring', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
stalk_surface_above_ring_poison_counts = df.groupby(['stalk_surface_above_ring', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each stalk_surface_above_ring group:")
print(stalk_surface_above_ring_poison_counts)

stalk_surface_above_ring_poison_proportions = stalk_surface_above_ring_poison_counts.div(stalk_surface_above_ring_poison_counts.sum(axis=1), axis=0)
stalk_surface_above_ring_poison_proportions = stalk_surface_above_ring_poison_proportions.round(2)

print("\nProportions of poisonousness within each stalk_surface_above_ring group:")
print(stalk_surface_above_ring_poison_proportions)
# Out:
# Frequency count of poisonousness within each stalk_surface_above_ring group:
# is_poisonous                 0     1
# stalk_surface_above_ring
# fibrous                    408   144
# scaly                       16     8
# silky                      144  2228
# smooth                    3640  1536
#
# Proportions of poisonousness within each stalk_surface_above_ring group:
# is_poisonous                 0     1
# stalk_surface_above_ring
# fibrous                   0.74  0.26
# scaly                     0.67  0.33
# silky                     0.06  0.94
# smooth                    0.70  0.30

# %% [markdown]
# ##### Observations:
#
# - *fibrous* has a higher proportion of poisonous mushrooms (26%) compared to non-poisonous ones (74%).
#
# - *scaly* also has a higher proportion of poisonous mushrooms (33%) compared to non-poisonous ones (67%).
#
# - *silky* predominantly consists of non-poisonous mushrooms (94%), with a small proportion being poisonous (6%).
#
# - *smooth* surface has a relatively balanced proportion, with 30% poisonous and 70% non-poisonous mushrooms.
#
# ##### Conclusion:
#
# - The distribution of mushrooms across different surface types shows a bias towards *smooth* and *silky* surfaces, which collectively represent over 92% of the data.
#
# - There are class imbalances withint the different surface types.  *Fibrous* and *scaly* surfaces exhibit a class imbalance towards poisonous mushrooms, while *silky* and *smooth* surfaces show relatively balanced proportions.
#
# - *stalk_surface_above_ring* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ###### 12. stalk_surface_belows_ring

# %%
# Calculating frequency counts for stalk_surface_belows_ring:
stalk_surface_belows_ring_counts = df['stalk_surface_belows_ring'].value_counts()

# Calculating proportions for stalk_surface_belows_ring:
stalk_surface_belows_ring_proportions = df['stalk_surface_belows_ring'].value_counts(normalize=True)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for stalk_surface_belows_ring:
stalk_surface_belows_ring_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Stalk_Surface_Belows_Ring', fontsize=13)
axes[0].set_xlabel('Stalk_Surface_Belows_Ring', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', labelsize=12, rotation=360)

# Plotting proportions for stalk_surface_belows_ring:
stalk_surface_belows_ring_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Stalk_Surface_Belows_Ring', fontsize=13)
axes[1].set_xlabel('Stalk_Surface_Belows_Ring', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', labelsize=12, rotation=360)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for stalk_surface_belows_ring:
print("Frequency counts for stalk_surface_belows_ring:")
print(stalk_surface_belows_ring_counts)
print("\nProportions for stalk_surface_belows_ring:")
print(stalk_surface_belows_ring_proportions)
# Out:
# Frequency counts for stalk_surface_belows_ring:
# s    4936
# k    2304
# f     600
# y     284
# Name: stalk_surface_belows_ring, dtype: int64
#
# Proportions for stalk_surface_belows_ring:
# s    0.607582
# k    0.283604
# f    0.073855
# y    0.034958
# Name: stalk_surface_belows_ring, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *s* makes up approximately 61% of the total data, making it the most prevalent type.
#
# - *k* represents around 28% of the data, followed by *f* (7%) and *y* (3.50%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='stalk_surface_belows_ring', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Stalk_Surface_Belows_Ring', fontsize=13)
plt.xlabel('Stalk_Surface_Belows_Ring', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=12)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
stalk_surface_belows_ring_poison_counts = df.groupby(['stalk_surface_belows_ring', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each stalk_surface_belows_ring group:")
print(stalk_surface_belows_ring_poison_counts)

stalk_surface_belows_ring_poison_proportions = stalk_surface_belows_ring_poison_counts.div(stalk_surface_belows_ring_poison_counts.sum(axis=1), axis=0)
stalk_surface_belows_ring_poison_proportions = stalk_surface_belows_ring_poison_proportions.round(2)

print("\nProportions of poisonousness within each stalk_surfaces_below_ring group:")
print(stalk_surface_belows_ring_poison_proportions)
# Out:
# Frequency count of poisonousness within each stalk_surface_belows_ring group:
# is_poisonous                  0     1
# stalk_surface_belows_ring
# f                           456   144
# k                           144  2160
# s                          3400  1536
# y                           208    76
#
# Proportions of poisonousness within each stalk_surfaces_below_ring group:
# is_poisonous                  0     1
# stalk_surface_belows_ring
# f                          0.76  0.24
# k                          0.06  0.94
# s                          0.69  0.31
# y                          0.73  0.27

# %% [markdown]
# ##### Observations:
#
# - *f* has a higher proportion of poisonous mushrooms (24%) compared to non-poisonous ones (76%).
#
# - *k* predominantly consists of non-poisonous mushrooms (94%), with a small proportion being poisonous (6%).
#
# - *s* also has a higher proportion of non-poisonous mushrooms (69%) compared to poisonous ones (31%).
#
# - *y* predominantly consists of non-poisonous mushrooms (88%), with a small proportion being poisonous (12%).
#
# ##### Conclusion:
#
# - The distribution of mushrooms across different stalk surface below ring types shows a representation bias towards *s* and *k* surfaces, which collectively represent over 88% of the data.
#
# -  *f* surface exhibits a class imbalance towards poisonous mushrooms, while *k* and *s* surfaces show relatively balanced proportions.
#
# - *stalk_surface_belows_ring* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 13. stalk_color_above_ring

# %%
# Calculating frequency counts for stalk_color_above_ring:
stalk_color_above_ring_counts = df['stalk_color_above_ring'].value_counts()

# Calculating proportions for stalk_color_above_ring:
stalk_color_above_ring_proportions = df['stalk_color_above_ring'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for stalk_color_above_ring:
stalk_color_above_ring_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Stalk_Color_Above_Ring', fontsize=13)
axes[0].set_xlabel('Stalk_Color_Above_Ring', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for stalk_color_above_ring:
stalk_color_above_ring_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Stalk_Color_Above_Ring', fontsize=13)
axes[1].set_xlabel('Stalk_Color_Above_Ring', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for stalk_color_above_ring:
print("Frequency counts for stalk_color_above_ring:")
print(stalk_color_above_ring_counts)
print("\nProportions for stalk_color_above_ring:")
print(stalk_color_above_ring_proportions)
# Out:
# Frequency counts for stalk_color_above_ring:
# white       4464
# pink        1872
# gray         576
# brown        448
# buff         432
# orange       192
# red           96
# cinnamon      36
# yellow         8
# Name: stalk_color_above_ring, dtype: int64
#
# Proportions for stalk_color_above_ring:
# white       0.5495
# pink        0.2304
# gray        0.0709
# brown       0.0551
# buff        0.0532
# orange      0.0236
# red         0.0118
# cinnamon    0.0044
# yellow      0.0010
# Name: stalk_color_above_ring, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *white* makes up approximately 55% of the total data, making it the most prevalent color.
#
# - *pink* represents around 23% of the data, followed by *gray* (7%), *brown* (5.5%), *buff* (5%), *orange* (2%), *red* (1%), *cinnamon* (0.4%), and *yellow* (0.10%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='stalk_color_above_ring', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Stalk_Color_Above_Ring', fontsize=13)
plt.xlabel('Stalk_Color_Above_Ring', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
stalk_color_above_ring_poison_counts = df.groupby(['stalk_color_above_ring', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each stalk_color_above_ring group:")
print(stalk_color_above_ring_poison_counts)

stalk_color_above_ring_poison_proportions = stalk_color_above_ring_poison_counts.div(stalk_color_above_ring_poison_counts.sum(axis=1), axis=0)
stalk_color_above_ring_poison_proportions = stalk_color_above_ring_poison_proportions.round(2)

print("\nProportions of poisonousness within each stalk_color_above_ring group:")
print(stalk_color_above_ring_poison_proportions)
# Out:
# Frequency count of poisonousness within each stalk_color_above_ring group:
# is_poisonous               0     1
# stalk_color_above_ring
# brown                     16   432
# buff                       0   432
# cinnamon                   0    36
# gray                     576     0
# orange                   192     0
# pink                     576  1296
# red                       96     0
# white                   2752  1712
# yellow                     0     8
#
# Proportions of poisonousness within each stalk_color_above_ring group:
# is_poisonous               0     1
# stalk_color_above_ring
# brown                   0.04  0.96
# buff                    0.00  1.00
# cinnamon                0.00  1.00
# gray                    1.00  0.00
# orange                  1.00  0.00
# pink                    0.31  0.69
# red                     1.00  0.00
# white                   0.62  0.38
# yellow                  0.00  1.00

# %% [markdown]
# ##### Observations:
#
# - *brown*, *buff*, *cinnamon*, and *yellow* are exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *gray* and *orange* are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# - *pink* has a higher proportion of poisonous mushrooms (69%) compared to non-poisonous ones (31%).
#
# - *white* predominantly consists of non-poisonous mushrooms (62%), with a substantial proportion being poisonous (38%).
#
# ##### Conclusion:
#
# - The distribution of mushrooms across different stalk colors shows a bias towards *white*, *pink*, and *gray*, which collectively represent over 85% of the data.
#
# - *brown*, *buff*, *cinnamon*, and *yellow* indicate class imbalance towards poisonous mushrooms, while *gray* and *orange* colors show class imbalance towards non-poisonous mushrooms.
#
# - *pink* and *white* have relatively balanced proportions of poisonous and non-poisonous mushrooms, but still indicate a class imbalance
#
# - *stalk_color_above_ring* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 14. stalk_color_below_ring

# %%
# Calculating frequency counts for stalk_color_below_ring:
stalk_color_below_ring_counts = df['stalk_color_below_ring'].value_counts()

# Calculating proportions for stalk_color_below_ring:
stalk_color_below_ring_proportions = df['stalk_color_below_ring'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for stalk_color_below_ring:
stalk_color_below_ring_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Stalk_Color_Below_Ring', fontsize=13)
axes[0].set_xlabel('Stalk_Color_Below_Ring', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for stalk_color_below_ring:
stalk_color_below_ring_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Stalk_Color_Below_Ring', fontsize=13)
axes[1].set_xlabel('Stalk_Color_Below_Ring', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for stalk_color_below_ring:
print("Frequency counts for stalk_color_below_ring:")
print(stalk_color_below_ring_counts)
print("\nProportions for stalk_color_below_ring:")
print(stalk_color_below_ring_proportions)
# Out:
# Frequency counts for stalk_color_below_ring:
# white       4384
# pink        1872
# gray         576
# brown        512
# buff         432
# orange       192
# red           96
# cinnamon      36
# yellow        24
# Name: stalk_color_below_ring, dtype: int64
#
# Proportions for stalk_color_below_ring:
# white       0.5396
# pink        0.2304
# gray        0.0709
# brown       0.0630
# buff        0.0532
# orange      0.0236
# red         0.0118
# cinnamon    0.0044
# yellow      0.0030
# Name: stalk_color_below_ring, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *white* makes up approximately 54% of the total data, making it the most prevalent color.
#
# - *pink* color represents around 23% of the data, followed by *gray* (7%), *brown* (6%), *buff* (5%), *orange* (2%), *red* (1%), *cinnamon* (0.4%), and *yellow* (0.3%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='stalk_color_below_ring', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Stalk_Color_Below_Ring', fontsize=13)
plt.xlabel('Stalk_Color_Below_Ring', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
stalk_color_below_ring_poison_counts = df.groupby(['stalk_color_below_ring', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each stalk_color_below_ring group:")
print(stalk_color_below_ring_poison_counts)

stalk_color_below_ring_poison_proportions = stalk_color_below_ring_poison_counts.div(stalk_color_below_ring_poison_counts.sum(axis=1), axis=0)
stalk_color_below_ring_poison_proportions = stalk_color_below_ring_poison_proportions.round(2)

print("\nProportions of poisonousness within each stalk_color_below_ring group:")
print(stalk_color_below_ring_poison_proportions)
# Out:
# Frequency count of poisonousness within each stalk_color_below_ring group:
# is_poisonous               0     1
# stalk_color_below_ring
# brown                     64   448
# buff                       0   432
# cinnamon                   0    36
# gray                     576     0
# orange                   192     0
# pink                     576  1296
# red                       96     0
# white                   2704  1680
# yellow                     0    24
#
# Proportions of poisonousness within each stalk_color_below_ring group:
# is_poisonous               0     1
# stalk_color_below_ring
# brown                   0.12  0.88
# buff                    0.00  1.00
# cinnamon                0.00  1.00
# gray                    1.00  0.00
# orange                  1.00  0.00
# pink                    0.31  0.69
# red                     1.00  0.00
# white                   0.62  0.38
# yellow                  0.00  1.00

# %% [markdown]
# ##### Observations:
#
# - *brown*, *buff*, *cinnamon*, and *yellow* are exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *gray* and *orange* are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# - *pink* has a higher proportion of poisonous mushrooms (69%) compared to non-poisonous ones (31%).
#
# - *white* predominantly consists of non-poisonous mushrooms (62%), with a substantial proportion being poisonous (38%).
#
# ##### Conclusion:
#
#  - The distribution of mushrooms across different colors shows a bias towards *white*, *pink*, and *gray*, which collectively represent over 85% of the data.
#
# - *brown*, *buff*, *cinnamon*, and *yellow* indicate class imbalance towards poisonous mushrooms, while *gray* and *orange* colors show class imbalance towards non-poisonous mushrooms.
#
# - *pink* and *white* have relatively balanced proportions of poisonous and non-poisonous mushrooms, but still indicate class imbalance.
#
# - *stalk_color_below_ring* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 15. veil_type

# %%
# Calculating frequency counts for veil_type:
veil_type_counts = df['veil_type'].value_counts()

# Calculating proportions for veil_type:
veil_type_proportions = df['veil_type'].value_counts(normalize=True)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for veil_type:
veil_type_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Veil_Type', fontsize=13)
axes[0].set_xlabel('Veil_Type', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for veil_type:
veil_type_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Veil_Type', fontsize=13)
axes[1].set_xlabel('Veil_Type', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for veil_type:
print("Frequency counts for veil_type:")
print(veil_type_counts)
print("\nProportions for veil_type:")
print(veil_type_proportions)
# Out:
# Frequency counts for veil_type:
# partial    8124
# Name: veil_type, dtype: int64
#
# Proportions for veil_type:
# partial    1.0
# Name: veil_type, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - The *partial* veil type represents the entirety of the dataset, making up 100% of the total data.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='veil_type', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Veil_Type', fontsize=13)
plt.xlabel('Veil_Type', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
veil_type_poison_counts = df.groupby(['veil_type', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each veil_type group:")
print(veil_type_poison_counts)

veil_type_poison_proportions = veil_type_poison_counts.div(veil_type_poison_counts.sum(axis=1), axis=0)
veil_type_poison_proportions = veil_type_poison_proportions.round(2)

print("\nProportions of poisonousness within each veil_type group:")
print(veil_type_poison_proportions)
# Out:
# Frequency count of poisonousness within each veil_type group:
# is_poisonous     0     1
# veil_type
# partial       4208  3916
#
# Proportions of poisonousness within each veil_type group:
# is_poisonous     0     1
# veil_type
# partial       0.52  0.48

# %% [markdown]
# ##### Observations:
#
# - 52% of mushrooms with a 'partial' veil type are non-poisonous.
#
# - 48% of mushrooms with a 'partial' veil type are poisonous.
#
# ##### Conclusion:
#
# - There is no representation bias within the *veil_type* variable since all mushrooms have a *partial* veil type.
#
# - The *partial* veil type exhibits a balanced distribution of poisonous and non-poisonous mushrooms.
#
# - While *veil_type* does not seem to be a significant factor for predicting mushroom toxicity in this dataset, we will still consider in the overall analysis.

# %% [markdown]
# ##### 16. veil_color

# %%
# Calculating frequency counts for veil_color:
veil_color_counts = df['veil_color'].value_counts()

# Calculating proportions for veil_color:
veil_color_proportions = df['veil_color'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for veil_color:
veil_color_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Veil_Color', fontsize=13)
axes[0].set_xlabel('Veil_Color', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for veil_color:
veil_color_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Veil_Color', fontsize=13)
axes[1].set_xlabel('Veil_Color', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for veil_color:
print("Frequency counts for veil_color:")
print(veil_color_counts)
print("\nProportions for veil_color:")
print(veil_color_proportions)
# Out:
# Frequency counts for veil_color:
# white     7924
# brown       96
# orange      96
# yellow       8
# Name: veil_color, dtype: int64
#
# Proportions for veil_color:
# white     0.9754
# brown     0.0118
# orange    0.0118
# yellow    0.0010
# Name: veil_color, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *white* represents almost 98% of the entire dataset, with *brown* at 1%, *orange* at 1% and *yellow* at 0.1%.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='veil_color', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Veil_Color', fontsize=13)
plt.xlabel('Veil_Color', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
veil_color_poison_counts = df.groupby(['veil_color', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each veil_color group:")
print(veil_color_poison_counts)

veil_color_poison_proportions = veil_color_poison_counts.div(veil_color_poison_counts.sum(axis=1), axis=0)
veil_color_poison_proportions = veil_color_poison_proportions.round(2)

print("\nProportions of poisonousness within each veil_color group:")
print(veil_color_poison_proportions)
# Out:
# Frequency count of poisonousness within each veil_color group:
# is_poisonous     0     1
# veil_color
# brown           96     0
# orange          96     0
# white         4016  3908
# yellow           0     8
#
# Proportions of poisonousness within each veil_color group:
# is_poisonous     0     1
# veil_color
# brown         1.00  0.00
# orange        1.00  0.00
# white         0.51  0.49
# yellow        0.00  1.00

# %% [markdown]
# ##### Observations:
#
# - For *brown* and *orange* veil colors, all mushrooms are non-poisonous (100% non-poisonous).
#
# - For *white* veil color, the proportion of non-poisonous mushrooms is slightly higher than poisonous mushrooms (51% non-poisonous, 49% poisonous).
#
# - For *yellow* veil color, all mushrooms are poisonous (100% poisonous).
#
# ##### Conclusion:
#
# - The dataset exhibits a significant representation bias towards mushrooms with *white* veil color.
#
# - There is a significant class imbalance within the veil color categories, especially for *brown*, *orange*, and *yellow* colors, where all mushrooms belong to a single class (either poisonous or non-poisonous).
#
# - There is no class imbalance for the *white* veil color, where the proportions are balanced.
#
# - *veil_color* may not be a strong predictor of mushroom toxicity due to the imbalance in the dataset and the predominance of one color category, but we will still consider it in the overall analysis.

# %% [markdown]
# ##### 17. number_of_rings

# %%
# Calculating frequency counts for number_of_rings:
number_of_rings_counts = df['number_of_rings'].value_counts()

# Calculating proportions for number_of_rings:
number_of_rings_proportions = df['number_of_rings'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for number_of_rings:
number_of_rings_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Number_of_Rings', fontsize=13)
axes[0].set_xlabel('Number_of_Rings', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', labelsize=12, rotation=360)

# Plotting proportions for number_of_rings:
number_of_rings_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Number_of_Rings', fontsize=13)
axes[1].set_xlabel('Number_of_Rings', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', labelsize=12, rotation=360)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for number_of_rings:
print("Frequency counts for number_of_rings:")
print(number_of_rings_counts)
print("\nProportions for number_of_rings:")
print(number_of_rings_proportions)
# Out:
# Frequency counts for number_of_rings:
# o    7488
# t     600
# n      36
# Name: number_of_rings, dtype: int64
#
# Proportions for number_of_rings:
# o    0.9217
# t    0.0739
# n    0.0044
# Name: number_of_rings, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - one ring (*o*) makes up approximately 92% of the entire dataset, with two rings (*t*) at 7% and no ring (*n*) at 0.4%.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='number_of_rings', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Number_of_Rings', fontsize=13)
plt.xlabel('Number_of_Rings', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
number_of_rings_poison_counts = df.groupby(['number_of_rings', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each number_of_rings group:")
print(number_of_rings_poison_counts)

number_of_rings_poison_proportions = number_of_rings_poison_counts.div(number_of_rings_poison_counts.sum(axis=1), axis=0)
number_of_rings_poison_proportions = number_of_rings_poison_proportions.round(2)

print("\nProportions of poisonousness within each number_of_rings group:")
print(number_of_rings_poison_proportions)
# Out:
# Frequency count of poisonousness within each number_of_rings group:
# is_poisonous        0     1
# number_of_rings
# n                   0    36
# o                3680  3808
# t                 528    72
#
# Proportions of poisonousness within each number_of_rings group:
# is_poisonous        0     1
# number_of_rings
# n                0.00  1.00
# o                0.49  0.51
# t                0.88  0.12

# %% [markdown]
# ##### Observations:
#
# - For mushrooms with no ring (*n*), all mushrooms are poisonous (100% poisonous).
#
# - For mushrooms with one ring (*o*), the proportion of poisonous mushrooms is slightly higher than non-poisonous mushrooms (51% poisonous, 49% non-poisonous).
#
# - For mushrooms with two rings (*t*), the majority are non-poisonous mushrooms (88% non-poisonous, 12% poisonous).
#
# ##### Conclusion:
#
# - The dataset exhibits a significant representation bias towards mushrooms with one ring (*o*).
#
# - There is a notable class imbalance within the number of rings categories, specifically for mushrooms with no ring (*n*) and those with two rings (*t*), where one class predominates.
#
# - There is no class imbalance for the one ring that rules them all (*o*), where the proportions are almost perfectly split.
#
# - *number_of_rings* appears to be a relevant factor in predicting mushroom toxicity.

# %% [markdown]
# ##### 18. ring_type

# %%
# Calculating frequency counts for ring_type:
ring_type_counts = df['ring_type'].value_counts()

# Calculating proportions for ring_type:
ring_type_proportions = df['ring_type'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for ring_type:
ring_type_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Ring_Type', fontsize=13)
axes[0].set_xlabel('Ring_Type', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for ring_type:
ring_type_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Ring_Type', fontsize=13)
axes[1].set_xlabel('Ring_Type', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for ring_type:
print("Frequency counts for ring_type:")
print(ring_type_counts)
print("\nProportions for ring_type:")
print(ring_type_proportions)
# Out:
# Frequency counts for ring_type:
# pendant       3968
# evanescent    2776
# large         1296
# flaring         48
# none            36
# Name: ring_type, dtype: int64
#
# Proportions for ring_type:
# pendant       0.4884
# evanescent    0.3417
# large         0.1595
# flaring       0.0059
# none          0.0044
# Name: ring_type, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *pendant* ring type makes up 48.84% of the total data, making it the most prevalent ring type.
#
# - *evanescent* ring type represents around 34.17% of the data, followed by *large* (15.95%), *flaring* (0.59%), and *none* (0.44%).

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(9, 5))

# Plotting countplot with the paired color palette:
sns.countplot(x='ring_type', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Ring_Type', fontsize=13)
plt.xlabel('Ring_Type', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
ring_type_poison_counts = df.groupby(['ring_type', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each ring_type group:")
print(ring_type_poison_counts)

ring_type_poison_proportions = ring_type_poison_counts.div(ring_type_poison_counts.sum(axis=1), axis=0)
ring_type_poison_proportions = ring_type_poison_proportions.round(2)

print("\nProportions of poisonousness within each ring_type group:")
print(ring_type_poison_proportions)
# Out:
# Frequency count of poisonousness within each ring_type group:
# is_poisonous     0     1
# ring_type
# evanescent    1008  1768
# flaring         48     0
# large            0  1296
# none             0    36
# pendant       3152   816
#
# Proportions of poisonousness within each ring_type group:
# is_poisonous     0     1
# ring_type
# evanescent    0.36  0.64
# flaring       1.00  0.00
# large         0.00  1.00
# none          0.00  1.00
# pendant       0.79  0.21

# %% [markdown]
# ##### Observations:
#
# - *evanescent* ring type has a higher proportion of poisonous mushrooms (64%) compared to non-poisonous ones (36%).
#
# - *flaring* and *none* ring types are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# - *large* ring type is exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *pendant* ring type predominantly consists of non-poisonous mushrooms (79%), with a smaller proportion being poisonous (21%).
#
# ###### Conclusion:
#
# -  The distribution of mushrooms across different ring types shows a bias towards *pendant* and *evanescent* types, which collectively represent over 82% of the data.
#
# - *flaring*, *large* and *none* ring types indicate extreme class imbalances where the categories fall exclusively into one class.
#
# -   *evanescent* ring type exhibits a significant class imbalance towards poisonous mushrooms, while *pendant* ring type shows a significant class imbalance towards non-poisonous mushrooms.
#
# - *ring_type* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ###### 19. spore_print_color

# %%
# Calculating frequency counts for spore_print_color:
spore_print_color_counts = df['spore_print_color'].value_counts()

# Calculating proportions for spore_print_color:
spore_print_color_proportions = df['spore_print_color'].value_counts(normalize=True).round(4)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for spore_print_color:
spore_print_color_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Spore_Print_Color', fontsize=13)
axes[0].set_xlabel('Spore_Print_Color', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for spore_print_color:
spore_print_color_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Spore_Print_Color', fontsize=13)
axes[1].set_xlabel('Spore_Print_Color', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for spore_print_color:
print("Frequency counts for spore_print_color:")
print(spore_print_color_counts)
print("\nProportions for spore_print_color:")
print(spore_print_color_proportions)
# Out:
# Frequency counts for spore_print_color:
# white        2388
# brown        1968
# black        1872
# chocolate    1632
# green          72
# purple         48
# orange         48
# yellow         48
# buff           48
# Name: spore_print_color, dtype: int64
#
# Proportions for spore_print_color:
# white        0.2939
# brown        0.2422
# black        0.2304
# chocolate    0.2009
# green        0.0089
# purple       0.0059
# orange       0.0059
# yellow       0.0059
# buff         0.0059
# Name: spore_print_color, dtype: float64

# %% [markdown]
# ###### Observations:
#
# - *white* spore print color makes up approximately 29% of the total data, making it the most prevalent.
#
# - *brown*, *black*, and *chocolate* each contribute to around 24-25% of the data.
#
# - *green*, *purple*, *orange*, *yellow*, and *buff* each have very low proportions, less than 1%.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='spore_print_color', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Spore_Print_Color', fontsize=13)
plt.xlabel('Spore_Print_Color', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
spore_print_color_poison_counts = df.groupby(['spore_print_color', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each spore_print_color group:")
print(spore_print_color_poison_counts)

spore_print_color_poison_proportions = spore_print_color_poison_counts.div(spore_print_color_poison_counts.sum(axis=1), axis=0)
spore_print_color_poison_proportions = spore_print_color_poison_proportions.round(2)

print("\nProportions of poisonousness within each spore_print_color group:")
print(spore_print_color_poison_proportions)
# Out:
# Frequency count of poisonousness within each spore_print_color group:
# is_poisonous          0     1
# spore_print_color
# black              1648   224
# brown              1744   224
# buff                 48     0
# chocolate            48  1584
# green                 0    72
# orange               48     0
# purple               48     0
# white               576  1812
# yellow               48     0
#
# Proportions of poisonousness within each spore_print_color group:
# is_poisonous          0     1
# spore_print_color
# black              0.88  0.12
# brown              0.89  0.11
# buff               1.00  0.00
# chocolate          0.03  0.97
# green              0.00  1.00
# orange             1.00  0.00
# purple             1.00  0.00
# white              0.24  0.76
# yellow             1.00  0.00

# %% [markdown]
# ##### Observations:
#
# - *chocolate* spore print color has the highest proportion of poisonous mushrooms (97%) compared to non-poisonous ones (3%).
#
# - *green* spore print color is exclusively associated with poisonous mushrooms (100% poisonous).
#
# - *white* spore print color also has a high proportion of poisonous mushrooms (76%) compared to non-poisonous ones (24%).
#
# - *black* and *brown* spore print colors show relatively balanced proportions, with both having around 11-12% poisonous mushrooms.
#
# - *orange*, *yellow*, *purple*, and *buff* spore print colors are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# ##### Conclusion:
#
# - The distribution of mushrooms across different spore print colors is not uniform, indicating representation bias. *white*, *brown*, *black*, and *chocolate* are more prevalent, while *green*, *purple*, *orange, *yellow*, and *buff* are rare.
#
# - *buff*, *green*, *orange*, *purple*, and *yellow* exhibit extreme class imbalance, where the categories fall exclusively into one class.
#
# - *black* and *brown* have significant class imbalance towards non-poisonous mushrooms.
#
# - *white* has a signficant class imbalance twoards poisonous mushrooms.
#
# - *spore_print_color* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 20. population

# %%
# Calculating frequency counts for population:
population_counts = df['population'].value_counts()

# Calculating proportions for population:
population_proportions = df['population'].value_counts(normalize=True).round(2)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for population:
population_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Population', fontsize=13)
axes[0].set_xlabel('Population', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for population:
population_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Population', fontsize=13)
axes[1].set_xlabel('Population', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for population:
print("Frequency counts for population:")
print(population_counts)
print("\nProportions for population:")
print(population_proportions)
# Out:
# Frequency counts for population:
# several      4040
# solitary     1712
# scattered    1248
# numerous      400
# abundant      384
# clustered     340
# Name: population, dtype: int64
#
# Proportions for population:
# several      0.50
# solitary     0.21
# scattered    0.15
# numerous     0.05
# abundant     0.05
# clustered    0.04
# Name: population, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *several* constitutes approximately 50% of the total data, making it the most prevalent.
#
# - *solitary* represents around 21% of the data, followed by *scattered* (15%) and *numerous* and *abundant* (both 5%).
#
# - *clustered* has the lowest proportion, around 4%.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='population', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Population', fontsize=13)
plt.xlabel('Population', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
population_poison_counts = df.groupby(['population', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each population group:")
print(population_poison_counts)

population_poison_proportions = population_poison_counts.div(population_poison_counts.sum(axis=1), axis=0)
population_poison_proportions = population_poison_proportions.round(2)

print("\nProportions of poisonousness within each population group:")
print(population_poison_proportions)
# Out:
# Frequency count of poisonousness within each population group:
# is_poisonous     0     1
# population
# abundant       384     0
# clustered      288    52
# numerous       400     0
# scattered      880   368
# several       1192  2848
# solitary      1064   648
#
# Proportions of poisonousness within each population group:
# is_poisonous     0     1
# population
# abundant      1.00  0.00
# clustered     0.85  0.15
# numerous      1.00  0.00
# scattered     0.71  0.29
# several       0.30  0.70
# solitary      0.62  0.38

# %% [markdown]
# ##### Observations:
#
# - *several* has a higher proportion of poisonous mushrooms (70%) compared to non-poisonous ones (30%).
#
# - *solitary* and *scattered* have higher proportions of non-poisonous mushrooms (62% and 71%, respectively).
#
# - *clustered* has a higher proportion of non-poisonous mushrooms (85%) compared to poisonous ones (15%).
#
# - *numerous* and *abundant* are exclusively associated with non-poisonous mushrooms (100% non-poisonous).
#
# ##### Conclusion:
#
# - There is representation bias with *several* making up 50% of the dataset, while *clustered* constituting only 4% of the dataset.
#
# - *several* exhibits a significant class imbalance towards poisonous mushrooms, *solitary*, *scattered*, and *clustered* exhibit a significant class imbalance towards non-poisonous mushrooms, while *numerous* and *absundant* indicate extreme class imbalance.
#
# - *population_type* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 21. habitat

# %%
# Calculating frequency counts for habitat:
habitat_counts = df['habitat'].value_counts()

# Calculating proportions for habitat:
habitat_proportions = df['habitat'].value_counts(normalize=True).round(2)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for habitat:
habitat_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Habitat', fontsize=13)
axes[0].set_xlabel('Habitat', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=45, labelsize=11)

# Plotting proportions for habitat:
habitat_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Habitat', fontsize=13)
axes[1].set_xlabel('Habitat', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation=45, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for habitat:
print("Frequency counts for habitat:")
print(habitat_counts)
print("\nProportions for habitat:")
print(habitat_proportions)
# Out:
# Frequency counts for habitat:
# woods      3148
# grasses    2148
# paths      1144
# leaves      832
# urban       368
# meadows     292
# waste       192
# Name: habitat, dtype: int64
#
# Proportions for habitat:
# woods      0.39
# grasses    0.26
# paths      0.14
# leaves     0.10
# urban      0.05
# meadows    0.04
# waste      0.02
# Name: habitat, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - *woods* and *grasses* collectively make up 65% of the entire dataset.
#
# - *paths* and *leaves* collectively make up 24% of the dataset.
#
# - *urban*, *meadows* and *waste* collectively make up 11% of the data set.

# %%
# Getting the paired color palette:
paired_palette = sns.color_palette("Paired")

# Setting the size of the figure:
plt.figure(figsize=(12, 6))

# Plotting countplot with the paired color palette:
sns.countplot(x='habitat', hue='is_poisonous', data=df, palette=paired_palette)

# Adding title and labels:
plt.title('Count of Mushroom Poisonousness by Habitat', fontsize=13)
plt.xlabel('Habitat', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adjusting x-axis tick labels:
plt.xticks(fontsize=11, rotation=45)

# Showing plot:
plt.show()

# Calculating and printing values and proportions:
habitat_poison_counts = df.groupby(['habitat', 'is_poisonous']).size().unstack(fill_value=0)
print("\nFrequency count of poisonousness within each habitat group:")
print(habitat_poison_counts)

habitat_poison_proportions = habitat_poison_counts.div(habitat_poison_counts.sum(axis=1), axis=0)
habitat_poison_proportions = habitat_poison_proportions.round(2)

print("\nProportions of poisonousness within each habitat group:")
print(habitat_poison_proportions)
# Out:
# Frequency count of poisonousness within each habitat group:
# is_poisonous     0     1
# habitat
# grasses       1408   740
# leaves         240   592
# meadows        256    36
# paths          136  1008
# urban           96   272
# waste          192     0
# woods         1880  1268
#
# Proportions of poisonousness within each habitat group:
# is_poisonous     0     1
# habitat
# grasses       0.66  0.34
# leaves        0.29  0.71
# meadows       0.88  0.12
# paths         0.12  0.88
# urban         0.26  0.74
# waste         1.00  0.00
# woods         0.60  0.40

# %% [markdown]
# ##### Observations:
#
# - *paths*, *leaves*, and *urban* have high proportion of poisonous mushrooms (88%, 71% and 74%, respectively).
#
# - *woods* has a relatively balanced proportion, with 60% poisonous and 40% non-poisonous mushrooms.
#
# - *grasses* also shows a somewhat balanced proportion, with 34% poisonous and 66% non-poisonous mushrooms.
#
# - *meadows* has a small proportion of poisonous mushrooms (12%), with a majority being non-poisonous.
#
#
# ##### Conclusion:
#
# - There is representation bias in the dataset, with *woods* and *grasses* collectively making up 65% of the entire dataset.
#
# - There is significant class imbalances in the *paths*, *leaves*, *urban* and *meadows* groups.
#
# - *habitat_type* appears to be an important feature in predicting mushroom toxicity.

# %% [markdown]
# ##### 22. is_poisonous

# %%
# Calculating frequency counts for is_poisonous:
is_poisonous_counts = df['is_poisonous'].value_counts()

# Calculating proportions for is_poisonous:
is_poisonous_proportions = df['is_poisonous'].value_counts(normalize=True)

# Creating a figure and axis object:
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting frequency counts for is_poisonous:
is_poisonous_counts.plot(kind='bar', ax=axes[0], color='wheat')
axes[0].set_title('Frequency Counts of Is_Poisonous', fontsize=13)
axes[0].set_xlabel('Is_Poisonous', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', rotation=360, labelsize=11)

# Plotting proportions for is_poisonous:
is_poisonous_proportions.plot(kind='bar', ax=axes[1], color='darkseagreen')
axes[1].set_title('Proportions of Is_Poisonous', fontsize=13)
axes[1].set_xlabel('Is_Poisonous', fontsize=13)
axes[1].set_ylabel('Proportion', fontsize=13)
axes[1].tick_params(axis='x', rotation= 360, labelsize=11)
axes[1].tick_params(axis='y', labelsize=11)

# Adjusting layout:
plt.tight_layout()

# Showing plot:
plt.show()

# Printing frequency counts and proportions for is_poisonous:
print("Frequency counts for is_poisonous:")
print(is_poisonous_counts)
print("\nProportions for is_poisonous:")
print(is_poisonous_proportions)
# Out:
# Frequency counts for is_poisonous:
# 0    4208
# 1    3916
# Name: is_poisonous, dtype: int64
#
# Proportions for is_poisonous:
# 0    0.517971
# 1    0.482029
# Name: is_poisonous, dtype: float64

# %% [markdown]
# ##### Observations:
#
# - The distribution between the two classes is relatively balanced, with class 0 (non-poisonous) having a slightly higher proportion compared to class 1 (poisonous). However, the difference in proportions is not significant, indicating a relatively balanced dataset in terms of the target variable.

# %% [markdown]
# ##### Feature Engineering
#
# In this section, we will be transforming all of our categorical variables via one-hot encoding. The aim is for our dataset to be entirely made up of binary points.

# %%
# Creating dummy variables:
dummy_1 = pd.get_dummies(df['cap_shape'], prefix = 'cap_shape', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_1], axis=1)

# Dropping the original 'cap_shape' column:
df.drop('cap_shape', axis=1, inplace=True)

# Dropping the dummy variable 'trap_conical':
df.drop('cap_shape_conical', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_2 = pd.get_dummies(df['cap_surface'], prefix = 'cap_surface', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_2], axis=1)

# Dropping the original column:
df.drop('cap_surface', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('cap_surface_grooves', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_3 = pd.get_dummies(df['cap_color'], prefix = 'cap_color', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_3], axis=1)

# Dropping the original column:
df.drop('cap_color', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('cap_color_purple', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_4 = pd.get_dummies(df['has_bruises'], prefix = 'has_bruises', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_4], axis=1)

# Dropping the original column:
df.drop('has_bruises', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('has_bruises_True', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_5 = pd.get_dummies(df['odor'], prefix = 'odor', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_5], axis=1)

# Dropping the original column:
df.drop('odor', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('odor_musty', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_6 = pd.get_dummies(df['gill_attachment'], prefix = 'gill_attachment', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_6], axis=1)

# Dropping the original column:
df.drop('gill_attachment', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('gill_attachment_attached', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_7 = pd.get_dummies(df['gill_spacing'], prefix = 'gill_spacing', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_7], axis=1)

# Dropping the original column:
df.drop('gill_spacing', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('gill_spacing_crowded', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_8 = pd.get_dummies(df['gill_size'], prefix = 'gill_size', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_8], axis=1)

# Dropping the original column:
df.drop('gill_size', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('gill_size_narrow', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_9 = pd.get_dummies(df['gill_color'], prefix = 'gill_color', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_9], axis=1)

# Dropping the original column:
df.drop('gill_color', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('gill_color_orange', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_10 = pd.get_dummies(df['stalk_shape'], prefix = 'stalk_shape', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_10], axis=1)

# Dropping the original column:
df.drop('stalk_shape', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('stalk_shape_enlarging', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_11 = pd.get_dummies(df['stalk_surface_above_ring'], prefix = 'stalk_surface_above_ring', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_11], axis=1)

# Dropping the original column:
df.drop('stalk_surface_above_ring', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('stalk_surface_above_ring_fibrous', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_12 = pd.get_dummies(df['stalk_surface_belows_ring'], prefix = 'stalk_surface_belows_ring', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_12], axis=1)

# Dropping the original column:
df.drop('stalk_surface_belows_ring', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('stalk_surface_belows_ring_f', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_13 = pd.get_dummies(df['stalk_color_above_ring'], prefix = 'stalk_color_above_ring', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_13], axis=1)

# Dropping the original column:
df.drop('stalk_color_above_ring', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('stalk_color_above_ring_yellow', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_14 = pd.get_dummies(df['stalk_color_below_ring'], prefix = 'stalk_color_below_ring', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_14], axis=1)

# Dropping the original column:
df.drop('stalk_color_below_ring', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('stalk_color_below_ring_cinnamon', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_15 = pd.get_dummies(df['veil_type'], prefix = 'veil_type', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_15], axis=1)

# Dropping the original column:
df.drop('veil_type', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_16 = pd.get_dummies(df['veil_color'], prefix = 'veil_color', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_16], axis=1)

# Dropping the original column:
df.drop('veil_color', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('veil_color_orange', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_17 = pd.get_dummies(df['number_of_rings'], prefix = 'number_of_rings', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_17], axis=1)

# Dropping the original column:
df.drop('number_of_rings', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('number_of_rings_n', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_18 = pd.get_dummies(df['ring_type'], prefix = 'ring_type', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_18], axis=1)

# Dropping the original column:
df.drop('ring_type', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('ring_type_none', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_19 = pd.get_dummies(df['spore_print_color'], prefix = 'spore_p_color', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_19], axis=1)

# Dropping the original column:
df.drop('spore_print_color', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('spore_p_color_buff', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_20 = pd.get_dummies(df['population'], prefix = 'pop', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_20], axis=1)

# Dropping the original column:
df.drop('population', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('pop_abundant', axis=1, inplace=True)

# %%
# Creating dummy variables:
dummy_21 = pd.get_dummies(df['habitat'], prefix = 'habitat', dtype=int)

# Concatenating dummy variables with original DataFrame: 
df = pd.concat([df, dummy_21], axis=1)

# Dropping the original column:
df.drop('habitat', axis=1, inplace=True)

# Dropping a dummy variable:
df.drop('habitat_waste', axis=1, inplace=True)

# %%
# Checking that all of our data are integers:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 93 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   is_poisonous                     8124 non-null   int64
#  1   cap_shape_bell                   8124 non-null   int32
#  2   cap_shape_convex                 8124 non-null   int32
#  3   cap_shape_flat                   8124 non-null   int32
#  4   cap_shape_knobbed                8124 non-null   int32
#  5   cap_shape_sunken                 8124 non-null   int32
#  6   cap_surface_fibrous              8124 non-null   int32
#  7   cap_surface_scaly                8124 non-null   int32
#  8   cap_surface_smooth               8124 non-null   int32
#  9   cap_color_brown                  8124 non-null   int32
#  10  cap_color_buff                   8124 non-null   int32
#  11  cap_color_cinnamon               8124 non-null   int32
#  12  cap_color_gray                   8124 non-null   int32
#  13  cap_color_green                  8124 non-null   int32
#  14  cap_color_pink                   8124 non-null   int32
#  15  cap_color_red                    8124 non-null   int32
#  16  cap_color_white                  8124 non-null   int32
#  17  cap_color_yellow                 8124 non-null   int32
#  18  has_bruises_False                8124 non-null   int32
#  19  odor_almond                      8124 non-null   int32
#  20  odor_anise                       8124 non-null   int32
#  21  odor_creosote                    8124 non-null   int32
#  22  odor_fishy                       8124 non-null   int32
#  23  odor_foul                        8124 non-null   int32
#  24  odor_none                        8124 non-null   int32
#  25  odor_pungent                     8124 non-null   int32
#  26  odor_spicy                       8124 non-null   int32
#  27  gill_attachment_free             8124 non-null   int32
#  28  gill_spacing_close               8124 non-null   int32
#  29  gill_size_broad                  8124 non-null   int32
#  30  gill_color_black                 8124 non-null   int32
#  31  gill_color_brown                 8124 non-null   int32
#  32  gill_color_buff                  8124 non-null   int32
#  33  gill_color_chocolate             8124 non-null   int32
#  34  gill_color_gray                  8124 non-null   int32
#  35  gill_color_green                 8124 non-null   int32
#  36  gill_color_pink                  8124 non-null   int32
#  37  gill_color_purple                8124 non-null   int32
#  38  gill_color_red                   8124 non-null   int32
#  39  gill_color_white                 8124 non-null   int32
#  40  gill_color_yellow                8124 non-null   int32
#  41  stalk_shape_tapering             8124 non-null   int32
#  42  stalk_surface_above_ring_scaly   8124 non-null   int32
#  43  stalk_surface_above_ring_silky   8124 non-null   int32
#  44  stalk_surface_above_ring_smooth  8124 non-null   int32
#  45  stalk_surface_belows_ring_k      8124 non-null   int32
#  46  stalk_surface_belows_ring_s      8124 non-null   int32
#  47  stalk_surface_belows_ring_y      8124 non-null   int32
#  48  stalk_color_above_ring_brown     8124 non-null   int32
#  49  stalk_color_above_ring_buff      8124 non-null   int32
#  50  stalk_color_above_ring_cinnamon  8124 non-null   int32
#  51  stalk_color_above_ring_gray      8124 non-null   int32
#  52  stalk_color_above_ring_orange    8124 non-null   int32
#  53  stalk_color_above_ring_pink      8124 non-null   int32
#  54  stalk_color_above_ring_red       8124 non-null   int32
#  55  stalk_color_above_ring_white     8124 non-null   int32
#  56  stalk_color_below_ring_brown     8124 non-null   int32
#  57  stalk_color_below_ring_buff      8124 non-null   int32
#  58  stalk_color_below_ring_gray      8124 non-null   int32
#  59  stalk_color_below_ring_orange    8124 non-null   int32
#  60  stalk_color_below_ring_pink      8124 non-null   int32
#  61  stalk_color_below_ring_red       8124 non-null   int32
#  62  stalk_color_below_ring_white     8124 non-null   int32
#  63  stalk_color_below_ring_yellow    8124 non-null   int32
#  64  veil_type_partial                8124 non-null   int32
#  65  veil_color_brown                 8124 non-null   int32
#  66  veil_color_white                 8124 non-null   int32
#  67  veil_color_yellow                8124 non-null   int32
#  68  number_of_rings_o                8124 non-null   int32
#  69  number_of_rings_t                8124 non-null   int32
#  70  ring_type_evanescent             8124 non-null   int32
#  71  ring_type_flaring                8124 non-null   int32
#  72  ring_type_large                  8124 non-null   int32
#  73  ring_type_pendant                8124 non-null   int32
#  74  spore_p_color_black              8124 non-null   int32
#  75  spore_p_color_brown              8124 non-null   int32
#  76  spore_p_color_chocolate          8124 non-null   int32
#  77  spore_p_color_green              8124 non-null   int32
#  78  spore_p_color_orange             8124 non-null   int32
#  79  spore_p_color_purple             8124 non-null   int32
#  80  spore_p_color_white              8124 non-null   int32
#  81  spore_p_color_yellow             8124 non-null   int32
#  82  pop_clustered                    8124 non-null   int32
#  83  pop_numerous                     8124 non-null   int32
#  84  pop_scattered                    8124 non-null   int32
#  85  pop_several                      8124 non-null   int32
#  86  pop_solitary                     8124 non-null   int32
#  87  habitat_grasses                  8124 non-null   int32
#  88  habitat_leaves                   8124 non-null   int32
#  89  habitat_meadows                  8124 non-null   int32
#  90  habitat_paths                    8124 non-null   int32
#  91  habitat_urban                    8124 non-null   int32
#  92  habitat_woods                    8124 non-null   int32
# dtypes: int32(92), int64(1)
# memory usage: 2.9 MB

# %%
# Checking that all columns have binary data:

for column in df.columns:
    print(column, df[column].unique())
# Out:
# is_poisonous [1 0]
# cap_shape_bell [0 1]
# cap_shape_convex [1 0]
# cap_shape_flat [0 1]
# cap_shape_knobbed [0 1]
# cap_shape_sunken [0 1]
# cap_surface_fibrous [0 1]
# cap_surface_scaly [0 1]
# cap_surface_smooth [1 0]
# cap_color_brown [1 0]
# cap_color_buff [0 1]
# cap_color_cinnamon [0 1]
# cap_color_gray [0 1]
# cap_color_green [0 1]
# cap_color_pink [0 1]
# cap_color_red [0 1]
# cap_color_white [0 1]
# cap_color_yellow [0 1]
# has_bruises_False [0 1]
# odor_almond [0 1]
# odor_anise [0 1]
# odor_creosote [0 1]
# odor_fishy [0 1]
# odor_foul [0 1]
# odor_none [0 1]
# odor_pungent [1 0]
# odor_spicy [0 1]
# gill_attachment_free [1 0]
# gill_spacing_close [1 0]
# gill_size_broad [0 1]
# gill_color_black [1 0]
# gill_color_brown [0 1]
# gill_color_buff [0 1]
# gill_color_chocolate [0 1]
# gill_color_gray [0 1]
# gill_color_green [0 1]
# gill_color_pink [0 1]
# gill_color_purple [0 1]
# gill_color_red [0 1]
# gill_color_white [0 1]
# gill_color_yellow [0 1]
# stalk_shape_tapering [0 1]
# stalk_surface_above_ring_scaly [0 1]
# stalk_surface_above_ring_silky [0 1]
# stalk_surface_above_ring_smooth [1 0]
# stalk_surface_belows_ring_k [0 1]
# stalk_surface_belows_ring_s [1 0]
# stalk_surface_belows_ring_y [0 1]
# stalk_color_above_ring_brown [0 1]
# stalk_color_above_ring_buff [0 1]
# stalk_color_above_ring_cinnamon [0 1]
# stalk_color_above_ring_gray [0 1]
# stalk_color_above_ring_orange [0 1]
# stalk_color_above_ring_pink [0 1]
# stalk_color_above_ring_red [0 1]
# stalk_color_above_ring_white [1 0]
# stalk_color_below_ring_brown [0 1]
# stalk_color_below_ring_buff [0 1]
# stalk_color_below_ring_gray [0 1]
# stalk_color_below_ring_orange [0 1]
# stalk_color_below_ring_pink [0 1]
# stalk_color_below_ring_red [0 1]
# stalk_color_below_ring_white [1 0]
# stalk_color_below_ring_yellow [0 1]
# veil_type_partial [1]
# veil_color_brown [0 1]
# veil_color_white [1 0]
# veil_color_yellow [0 1]
# number_of_rings_o [1 0]
# number_of_rings_t [0 1]
# ring_type_evanescent [0 1]
# ring_type_flaring [0 1]
# ring_type_large [0 1]
# ring_type_pendant [1 0]
# spore_p_color_black [1 0]
# spore_p_color_brown [0 1]
# spore_p_color_chocolate [0 1]
# spore_p_color_green [0 1]
# spore_p_color_orange [0 1]
# spore_p_color_purple [0 1]
# spore_p_color_white [0 1]
# spore_p_color_yellow [0 1]
# pop_clustered [0 1]
# pop_numerous [0 1]
# pop_scattered [1 0]
# pop_several [0 1]
# pop_solitary [0 1]
# habitat_grasses [0 1]
# habitat_leaves [0 1]
# habitat_meadows [0 1]
# habitat_paths [0 1]
# habitat_urban [1 0]
# habitat_woods [0 1]

# %% [markdown]
# ##### Represention Bias
#
# Representation bias refers to a situation where certain categories or groups within a dataset are overrepresented or underrepresented compared to their true distribution in the population. Representation bias can affect the validity and generalizability of results obtained from the dataset, as the findings may not accurately reflect the true relationships or patterns present in the population.
#
# The overall representation bias measures the extent to which variables contribute to the dataset. A representation bias close to 0 indicates that each variable contributes relatively equally to the dataset, while higher values suggest that some variables contribute more significantly than others.
#
# In what follows, we will first compute, for each variable, the percentage of how much that variable contributes to the dataset. Then, we will find the overall representation bias, which is a number between 0 and 1.

# %%
total_rows = len(df)

# Creating an empty dictionary to store the percentage contribution of each variable:
variable_contributions = {}

# Iterating over each column (variable) in the dataset:
for col in df.columns:
    # Calculating the percentage contribution of the variable:
    contribution = len(df[df[col] == 1]) / total_rows * 100
    
    # Storing the contribution in the dictionary:
    variable_contributions[col] = contribution

# Converting the dictionary to a DataFrame for easy visualization:
variable_contributions_df = pd.DataFrame.from_dict(variable_contributions, orient='index', columns=['Contribution'])

# Sorting the DataFrame by contribution in descending order:
variable_contributions_df = variable_contributions_df.sort_values(by='Contribution', ascending=False)

# Setting display options to ensure all rows are displayed
pd.set_option('display.max_rows', None)  

# Printing the percentage contribution of each variable to the dataset:
print(variable_contributions_df)
# Out:
#                                  Contribution
# veil_type_partial                  100.000000
# veil_color_white                    97.538159
# gill_attachment_free                97.415066
# number_of_rings_o                   92.171344
# gill_spacing_close                  83.850320
# gill_size_broad                     69.079271
# stalk_surface_above_ring_smooth     63.712457
# stalk_surface_belows_ring_s         60.758247
# has_bruises_False                   58.444116
# stalk_shape_tapering                56.720827
# stalk_color_above_ring_white        54.948301
# stalk_color_below_ring_white        53.963565
# pop_several                         49.729197
# ring_type_pendant                   48.842935
# is_poisonous                        48.202856
# cap_shape_convex                    45.002462
# odor_none                           43.426883
# cap_surface_scaly                   39.931068
# cap_shape_flat                      38.798621
# habitat_woods                       38.749385
# ring_type_evanescent                34.170359
# cap_surface_smooth                  31.462334
# spore_p_color_white                 29.394387
# stalk_surface_above_ring_silky      29.197440
# cap_surface_fibrous                 28.557361
# stalk_surface_belows_ring_k         28.360414
# cap_color_brown                     28.114229
# odor_foul                           26.587888
# habitat_grasses                     26.440177
# spore_p_color_brown                 24.224520
# spore_p_color_black                 23.042836
# stalk_color_below_ring_pink         23.042836
# stalk_color_above_ring_pink         23.042836
# cap_color_gray                      22.648941
# gill_color_buff                     21.270310
# pop_solitary                        21.073363
# spore_p_color_chocolate             20.088626
# cap_color_red                       18.463811
# gill_color_pink                     18.365337
# ring_type_large                     15.952733
# pop_scattered                       15.361891
# gill_color_white                    14.795667
# habitat_paths                       14.081733
# cap_color_yellow                    13.195470
# gill_color_brown                    12.900049
# cap_color_white                     12.801576
# habitat_leaves                      10.241260
# cap_shape_knobbed                   10.192024
# gill_color_gray                      9.256524
# gill_color_chocolate                 9.010340
# number_of_rings_t                    7.385524
# odor_fishy                           7.090103
# stalk_color_below_ring_gray          7.090103
# stalk_color_above_ring_gray          7.090103
# odor_spicy                           7.090103
# stalk_color_below_ring_brown         6.302314
# gill_color_purple                    6.056130
# cap_shape_bell                       5.563762
# stalk_color_above_ring_brown         5.514525
# stalk_color_below_ring_buff          5.317578
# stalk_color_above_ring_buff          5.317578
# gill_color_black                     5.022157
# odor_almond                          4.923683
# pop_numerous                         4.923683
# odor_anise                           4.923683
# habitat_urban                        4.529788
# pop_clustered                        4.185130
# habitat_meadows                      3.594289
# stalk_surface_belows_ring_y          3.495815
# odor_pungent                         3.151157
# stalk_color_below_ring_orange        2.363368
# odor_creosote                        2.363368
# stalk_color_above_ring_orange        2.363368
# cap_color_buff                       2.067947
# cap_color_pink                       1.772526
# gill_color_red                       1.181684
# veil_color_brown                     1.181684
# stalk_color_below_ring_red           1.181684
# stalk_color_above_ring_red           1.181684
# gill_color_yellow                    1.058592
# spore_p_color_green                  0.886263
# spore_p_color_orange                 0.590842
# spore_p_color_purple                 0.590842
# ring_type_flaring                    0.590842
# spore_p_color_yellow                 0.590842
# cap_color_cinnamon                   0.541605
# stalk_color_above_ring_cinnamon      0.443131
# cap_shape_sunken                     0.393895
# stalk_color_below_ring_yellow        0.295421
# gill_color_green                     0.295421
# stalk_surface_above_ring_scaly       0.295421
# cap_color_green                      0.196947
# veil_color_yellow                    0.098474

# %%
# Calculate the percentage contribution of each variable
variable_contributions = (df.astype(bool).sum() / len(df))

# Calculate the ideal contribution assuming each variable contributes equally
ideal_contribution = 1 / len(df.columns)

# Calculate the absolute differences between each variable's contribution and the ideal contribution
absolute_differences = abs(variable_contributions - ideal_contribution)

# Calculate the overall representation bias (median of absolute differences)
overall_bias = absolute_differences.median()

print("Overall Representation Bias:", overall_bias)
# Out:
# Overall Representation Bias: 0.09165991645621893

# %% [markdown]
# ##### Observations:
#
# In our case, the overall representation bias is 0.09. This means that, on average, each variable contributes approximately 9% to the dataset. This suggests a relatively balanced distribution of contributions among the variables, which is generally desirable in statistical analysis and modeling.
#
# Again, an overall representation bias of 0.09 is considered quite good, indicating a relatively balanced distribution of variables in our dataset. A low overall representation bias indicates that the dataset is diverse and contains a good representation of different variables, making it more robust for analysis and modeling tasks.

# %% [markdown]
# ##### Variable Bias
#
# Although we have binary data, assessing variable bias can still be meaningful. The variable bias measures the association between each predictor variable and the target variable. It quantifies how much each variable contributes to the predictive power or imbalance observed in the target variable. A higher variable bias suggests that the variable has a greater influence on the target variable's imbalance, indicating its potential importance or relevance in predictive modeling or analysis. However,  a high variance bias can indicate that the model is overly sensitive to small changes in the training data and may not generalize well to new, unseen data and this could lead to overfitting.
#
# First we will compute, for each variable, the proportions of being in class 0 (non-poisonous) and class 1 (poisnous). We will then take the absolute value of the difference between these proportions to get the variance bias for each variable. And then we will count how many variables have bias between 0 and 0.4, 0.4 and 0.7, and 0.7 and 1.

# %%
# Creating an empty dictionary to store class imbalance information:
class_imbalance = {}

# Iterating over each column (variable) in the dataset:
for col in df.columns:
    # If the column is the target variable, skip it:
    if col == 'is_poisonous':
        continue
    
    # Calculating the value counts for each class (0 and 1):
    value_counts = df[col].value_counts()
    
    # Calculating the proportion of each class:
    proportion_0 = value_counts.get(0, 0) / len(df)
    proportion_1 = value_counts.get(1, 0) / len(df)
    
    # Storing the class imbalance information in the dictionary:
    class_imbalance[col] = {'Proportion_0': proportion_0, 'Proportion_1': proportion_1}

# Converting the dictionary to a DataFrame for easy visualization:
class_imbalance_df = pd.DataFrame.from_dict(class_imbalance, orient='index')

# Setting display options to ensure all rows are displayed
pd.set_option('display.max_rows', None) 

# Printing the class imbalance information:
print(class_imbalance_df)
# Out:
#                                  Proportion_0  Proportion_1
# cap_shape_bell                       0.944362      0.055638
# cap_shape_convex                     0.549975      0.450025
# cap_shape_flat                       0.612014      0.387986
# cap_shape_knobbed                    0.898080      0.101920
# cap_shape_sunken                     0.996061      0.003939
# cap_surface_fibrous                  0.714426      0.285574
# cap_surface_scaly                    0.600689      0.399311
# cap_surface_smooth                   0.685377      0.314623
# cap_color_brown                      0.718858      0.281142
# cap_color_buff                       0.979321      0.020679
# cap_color_cinnamon                   0.994584      0.005416
# cap_color_gray                       0.773511      0.226489
# cap_color_green                      0.998031      0.001969
# cap_color_pink                       0.982275      0.017725
# cap_color_red                        0.815362      0.184638
# cap_color_white                      0.871984      0.128016
# cap_color_yellow                     0.868045      0.131955
# has_bruises_False                    0.415559      0.584441
# odor_almond                          0.950763      0.049237
# odor_anise                           0.950763      0.049237
# odor_creosote                        0.976366      0.023634
# odor_fishy                           0.929099      0.070901
# odor_foul                            0.734121      0.265879
# odor_none                            0.565731      0.434269
# odor_pungent                         0.968488      0.031512
# odor_spicy                           0.929099      0.070901
# gill_attachment_free                 0.025849      0.974151
# gill_spacing_close                   0.161497      0.838503
# gill_size_broad                      0.309207      0.690793
# gill_color_black                     0.949778      0.050222
# gill_color_brown                     0.871000      0.129000
# gill_color_buff                      0.787297      0.212703
# gill_color_chocolate                 0.909897      0.090103
# gill_color_gray                      0.907435      0.092565
# gill_color_green                     0.997046      0.002954
# gill_color_pink                      0.816347      0.183653
# gill_color_purple                    0.939439      0.060561
# gill_color_red                       0.988183      0.011817
# gill_color_white                     0.852043      0.147957
# gill_color_yellow                    0.989414      0.010586
# stalk_shape_tapering                 0.432792      0.567208
# stalk_surface_above_ring_scaly       0.997046      0.002954
# stalk_surface_above_ring_silky       0.708026      0.291974
# stalk_surface_above_ring_smooth      0.362875      0.637125
# stalk_surface_belows_ring_k          0.716396      0.283604
# stalk_surface_belows_ring_s          0.392418      0.607582
# stalk_surface_belows_ring_y          0.965042      0.034958
# stalk_color_above_ring_brown         0.944855      0.055145
# stalk_color_above_ring_buff          0.946824      0.053176
# stalk_color_above_ring_cinnamon      0.995569      0.004431
# stalk_color_above_ring_gray          0.929099      0.070901
# stalk_color_above_ring_orange        0.976366      0.023634
# stalk_color_above_ring_pink          0.769572      0.230428
# stalk_color_above_ring_red           0.988183      0.011817
# stalk_color_above_ring_white         0.450517      0.549483
# stalk_color_below_ring_brown         0.936977      0.063023
# stalk_color_below_ring_buff          0.946824      0.053176
# stalk_color_below_ring_gray          0.929099      0.070901
# stalk_color_below_ring_orange        0.976366      0.023634
# stalk_color_below_ring_pink          0.769572      0.230428
# stalk_color_below_ring_red           0.988183      0.011817
# stalk_color_below_ring_white         0.460364      0.539636
# stalk_color_below_ring_yellow        0.997046      0.002954
# veil_type_partial                    0.000000      1.000000
# veil_color_brown                     0.988183      0.011817
# veil_color_white                     0.024618      0.975382
# veil_color_yellow                    0.999015      0.000985
# number_of_rings_o                    0.078287      0.921713
# number_of_rings_t                    0.926145      0.073855
# ring_type_evanescent                 0.658296      0.341704
# ring_type_flaring                    0.994092      0.005908
# ring_type_large                      0.840473      0.159527
# ring_type_pendant                    0.511571      0.488429
# spore_p_color_black                  0.769572      0.230428
# spore_p_color_brown                  0.757755      0.242245
# spore_p_color_chocolate              0.799114      0.200886
# spore_p_color_green                  0.991137      0.008863
# spore_p_color_orange                 0.994092      0.005908
# spore_p_color_purple                 0.994092      0.005908
# spore_p_color_white                  0.706056      0.293944
# spore_p_color_yellow                 0.994092      0.005908
# pop_clustered                        0.958149      0.041851
# pop_numerous                         0.950763      0.049237
# pop_scattered                        0.846381      0.153619
# pop_several                          0.502708      0.497292
# pop_solitary                         0.789266      0.210734
# habitat_grasses                      0.735598      0.264402
# habitat_leaves                       0.897587      0.102413
# habitat_meadows                      0.964057      0.035943
# habitat_paths                        0.859183      0.140817
# habitat_urban                        0.954702      0.045298
# habitat_woods                        0.612506      0.387494

# %%
# Creating an empty dictionary to store bias information:
variable_bias = {}

# Iterating over each column (variable) in the dataset:
for col in df.columns:
    # If the column is the target variable, skip it:
    if col == 'is_poisonous':
        continue
    
    # Calculating the value counts for each class (0 and 1):
    value_counts = df[col].value_counts()
    
    # Calculating the proportion of each class:
    proportion_0 = value_counts.get(0, 0) / len(df)
    proportion_1 = value_counts.get(1, 0) / len(df)
    
    # Calculating the bias of the variable:
    bias = abs(proportion_0 - proportion_1)
    
    # Storing the bias information in the dictionary
    variable_bias[col] = bias

# Converting the dictionary to a DataFrame for easy visualization:
variable_bias_df = pd.DataFrame.from_dict(variable_bias, orient='index', columns=['Bias'])

# Sorting the DataFrame by bias in descending order:
variable_bias_df = variable_bias_df.sort_values(by='Bias', ascending=False)

# Setting display options to ensure all rows are displayed
pd.set_option('display.max_rows', None) 

# Printing the variable bias information:
print(variable_bias_df)
# Out:
#                                      Bias
# veil_type_partial                1.000000
# veil_color_yellow                0.998031
# cap_color_green                  0.996061
# stalk_color_below_ring_yellow    0.994092
# stalk_surface_above_ring_scaly   0.994092
# gill_color_green                 0.994092
# cap_shape_sunken                 0.992122
# stalk_color_above_ring_cinnamon  0.991137
# cap_color_cinnamon               0.989168
# spore_p_color_yellow             0.988183
# spore_p_color_purple             0.988183
# spore_p_color_orange             0.988183
# ring_type_flaring                0.988183
# spore_p_color_green              0.982275
# gill_color_yellow                0.978828
# veil_color_brown                 0.976366
# gill_color_red                   0.976366
# stalk_color_below_ring_red       0.976366
# stalk_color_above_ring_red       0.976366
# cap_color_pink                   0.964549
# cap_color_buff                   0.958641
# odor_creosote                    0.952733
# stalk_color_below_ring_orange    0.952733
# stalk_color_above_ring_orange    0.952733
# veil_color_white                 0.950763
# gill_attachment_free             0.948301
# odor_pungent                     0.936977
# stalk_surface_belows_ring_y      0.930084
# habitat_meadows                  0.928114
# pop_clustered                    0.916297
# habitat_urban                    0.909404
# odor_almond                      0.901526
# pop_numerous                     0.901526
# odor_anise                       0.901526
# gill_color_black                 0.899557
# stalk_color_below_ring_buff      0.893648
# stalk_color_above_ring_buff      0.893648
# stalk_color_above_ring_brown     0.889710
# cap_shape_bell                   0.888725
# gill_color_purple                0.878877
# stalk_color_below_ring_brown     0.873954
# stalk_color_below_ring_gray      0.858198
# stalk_color_above_ring_gray      0.858198
# odor_spicy                       0.858198
# odor_fishy                       0.858198
# number_of_rings_t                0.852290
# number_of_rings_o                0.843427
# gill_color_chocolate             0.819793
# gill_color_gray                  0.814870
# cap_shape_knobbed                0.796160
# habitat_leaves                   0.795175
# cap_color_white                  0.743968
# gill_color_brown                 0.741999
# cap_color_yellow                 0.736091
# habitat_paths                    0.718365
# gill_color_white                 0.704087
# pop_scattered                    0.692762
# ring_type_large                  0.680945
# gill_spacing_close               0.677006
# gill_color_pink                  0.632693
# cap_color_red                    0.630724
# spore_p_color_chocolate          0.598227
# pop_solitary                     0.578533
# gill_color_buff                  0.574594
# cap_color_gray                   0.547021
# spore_p_color_black              0.539143
# stalk_color_below_ring_pink      0.539143
# stalk_color_above_ring_pink      0.539143
# spore_p_color_brown              0.515510
# habitat_grasses                  0.471196
# odor_foul                        0.468242
# cap_color_brown                  0.437715
# stalk_surface_belows_ring_k      0.432792
# cap_surface_fibrous              0.428853
# stalk_surface_above_ring_silky   0.416051
# spore_p_color_white              0.412112
# gill_size_broad                  0.381585
# cap_surface_smooth               0.370753
# ring_type_evanescent             0.316593
# stalk_surface_above_ring_smooth  0.274249
# habitat_woods                    0.225012
# cap_shape_flat                   0.224028
# stalk_surface_belows_ring_s      0.215165
# cap_surface_scaly                0.201379
# has_bruises_False                0.168882
# stalk_shape_tapering             0.134417
# odor_none                        0.131462
# cap_shape_convex                 0.099951
# stalk_color_above_ring_white     0.098966
# stalk_color_below_ring_white     0.079271
# ring_type_pendant                0.023141
# pop_several                      0.005416

# %%
# Creating counters for the bias buckets
bias_buckets = {'0 to 0.4': 0, '0.4 to 0.7': 0, '0.7 to 1': 0}

# Iterating over each bias value and counting the variables in each bucket
for bias_value in variable_bias_df['Bias']:
    if bias_value < 0.4:
        bias_buckets['0 to 0.4'] += 1
    elif 0.4 <= bias_value < 0.7:
        bias_buckets['0.4 to 0.7'] += 1
    else:
        bias_buckets['0.7 to 1'] += 1

# Print the count of variables in each bias bucket
for bucket, count in bias_buckets.items():
    print(f'Number of variables with variance bias between {bucket}: {count}')
# Out:
# Number of variables with variance bias between 0 to 0.4: 16
# Number of variables with variance bias between 0.4 to 0.7: 20
# Number of variables with variance bias between 0.7 to 1: 56

# %% [markdown]
# ##### Observations:
#
# We have 61% of our predictor variables having high variance bias since they are close to 1. These variables have a strong association with the target variable. They are highly predictive of whether a mushroom is poisonous or non-poisonous. In logistic regression, such variables can be valuable predictors as they contribute significantly to the model's decision-making process. However, high variance biased variables can else result in overfitting.
#
# The variables with biases closer to 0.5 may have less influence on predicting the target variable. While they still contribute to the model, their predictive power might be moderate compared to high bias variables.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ###### Pearson's $\chi^{2}$ test
#
# Now we will run a Pearson's $\chi^{2}$ test between each predictor variable and the target variable *is_poisonous*. The test will tell us if there is significant association between the predictor variable and the target variable. This will assist us in feature selection by determining which predictors are most relevant for predicting the target variable.
#
# After we run the test, we will determine which variables are not significant at $\alpha$ = 0.5 and we will keep them in mind for later.

# %%
# Importing chi2_contingency function from scipy.stats module
from scipy.stats import chi2_contingency

# Creating an empty DataFrame to store the results for the target variable with all other variables:
target_results = []

# Iterating over each variable (column) except the target variable:
for col in df.columns:
    if col != 'is_poisonous':  # Skip the target variable
        # Creating a contingency table:
        contingency_table = pd.crosstab(df['is_poisonous'], df[col])
        
        # Performing chi-square test of independence:
        chi2, p_value, dof, _ = chi2_contingency(contingency_table)
        
        # Formating p-value without scientific notation and with 7 decimal places:
        formatted_p_value = '{:.7f}'.format(p_value)
        
        # Appending results to list:
        target_results.append({'Variable 1': 'is_poisonous',
                               'Variable 2': col,
                               'P-value': formatted_p_value,
                              })

# Converting results list to DataFrame:
target_results_df = pd.DataFrame(target_results)

# Setting the option to display all rows:
pd.set_option('display.max_rows', None)

# Displaying the results for the target variable with all other variables
print("Results for the target variable 'is_poisonous' with all other variables:")
print(target_results_df)
# Out:
# Results for the target variable 'is_poisonous' with all other variables:
#       Variable 1                       Variable 2    P-value
# 0   is_poisonous                   cap_shape_bell  0.0000000
# 1   is_poisonous                 cap_shape_convex  0.0163511
# 2   is_poisonous                   cap_shape_flat  0.0995553
# 3   is_poisonous                cap_shape_knobbed  0.0000000
# 4   is_poisonous                 cap_shape_sunken  0.0000001
# 5   is_poisonous              cap_surface_fibrous  0.0000000
# 6   is_poisonous                cap_surface_scaly  0.0000000
# 7   is_poisonous               cap_surface_smooth  0.0000000
# 8   is_poisonous                  cap_color_brown  0.0000708
# 9   is_poisonous                   cap_color_buff  0.0000000
# 10  is_poisonous               cap_color_cinnamon  0.0084191
# 11  is_poisonous                   cap_color_gray  0.0000317
# 12  is_poisonous                  cap_color_green  0.0003037
# 13  is_poisonous                   cap_color_pink  0.0023369
# 14  is_poisonous                    cap_color_red  0.0000000
# 15  is_poisonous                  cap_color_white  0.0000000
# 16  is_poisonous                 cap_color_yellow  0.0000000
# 17  is_poisonous                has_bruises_False  0.0000000
# 18  is_poisonous                      odor_almond  0.0000000
# 19  is_poisonous                       odor_anise  0.0000000
# 20  is_poisonous                    odor_creosote  0.0000000
# 21  is_poisonous                       odor_fishy  0.0000000
# 22  is_poisonous                        odor_foul  0.0000000
# 23  is_poisonous                        odor_none  0.0000000
# 24  is_poisonous                     odor_pungent  0.0000000
# 25  is_poisonous                       odor_spicy  0.0000000
# 26  is_poisonous             gill_attachment_free  0.0000000
# 27  is_poisonous               gill_spacing_close  0.0000000
# 28  is_poisonous                  gill_size_broad  0.0000000
# 29  is_poisonous                 gill_color_black  0.0000000
# 30  is_poisonous                 gill_color_brown  0.0000000
# 31  is_poisonous                  gill_color_buff  0.0000000
# 32  is_poisonous             gill_color_chocolate  0.0000000
# 33  is_poisonous                  gill_color_gray  0.0000000
# 34  is_poisonous                 gill_color_green  0.0000011
# 35  is_poisonous                  gill_color_pink  0.0000064
# 36  is_poisonous                gill_color_purple  0.0000000
# 37  is_poisonous                   gill_color_red  0.0000000
# 38  is_poisonous                 gill_color_white  0.0000000
# 39  is_poisonous                gill_color_yellow  0.0000392
# 40  is_poisonous             stalk_shape_tapering  0.0000000
# 41  is_poisonous   stalk_surface_above_ring_scaly  0.2093149
# 42  is_poisonous   stalk_surface_above_ring_silky  0.0000000
# 43  is_poisonous  stalk_surface_above_ring_smooth  0.0000000
# 44  is_poisonous      stalk_surface_belows_ring_k  0.0000000
# 45  is_poisonous      stalk_surface_belows_ring_s  0.0000000
# 46  is_poisonous      stalk_surface_belows_ring_y  0.0000000
# 47  is_poisonous     stalk_color_above_ring_brown  0.0000000
# 48  is_poisonous      stalk_color_above_ring_buff  0.0000000
# 49  is_poisonous  stalk_color_above_ring_cinnamon  0.0000000
# 50  is_poisonous      stalk_color_above_ring_gray  0.0000000
# 51  is_poisonous    stalk_color_above_ring_orange  0.0000000
# 52  is_poisonous      stalk_color_above_ring_pink  0.0000000
# 53  is_poisonous       stalk_color_above_ring_red  0.0000000
# 54  is_poisonous     stalk_color_above_ring_white  0.0000000
# 55  is_poisonous     stalk_color_below_ring_brown  0.0000000
# 56  is_poisonous      stalk_color_below_ring_buff  0.0000000
# 57  is_poisonous      stalk_color_below_ring_gray  0.0000000
# 58  is_poisonous    stalk_color_below_ring_orange  0.0000000
# 59  is_poisonous      stalk_color_below_ring_pink  0.0000000
# 60  is_poisonous       stalk_color_below_ring_red  0.0000000
# 61  is_poisonous     stalk_color_below_ring_white  0.0000000
# 62  is_poisonous    stalk_color_below_ring_yellow  0.0000011
# 63  is_poisonous                veil_type_partial  1.0000000
# 64  is_poisonous                 veil_color_brown  0.0000000
# 65  is_poisonous                 veil_color_white  0.0000000
# 66  is_poisonous                veil_color_yellow  0.0098952
# 67  is_poisonous                number_of_rings_o  0.0000000
# 68  is_poisonous                number_of_rings_t  0.0000000
# 69  is_poisonous             ring_type_evanescent  0.0000000
# 70  is_poisonous                ring_type_flaring  0.0000000
# 71  is_poisonous                  ring_type_large  0.0000000
# 72  is_poisonous                ring_type_pendant  0.0000000
# 73  is_poisonous              spore_p_color_black  0.0000000
# 74  is_poisonous              spore_p_color_brown  0.0000000
# 75  is_poisonous          spore_p_color_chocolate  0.0000000
# 76  is_poisonous              spore_p_color_green  0.0000000
# 77  is_poisonous             spore_p_color_orange  0.0000000
# 78  is_poisonous             spore_p_color_purple  0.0000000
# 79  is_poisonous              spore_p_color_white  0.0000000
# 80  is_poisonous             spore_p_color_yellow  0.0000000
# 81  is_poisonous                    pop_clustered  0.0000000
# 82  is_poisonous                     pop_numerous  0.0000000
# 83  is_poisonous                    pop_scattered  0.0000000
# 84  is_poisonous                      pop_several  0.0000000
# 85  is_poisonous                     pop_solitary  0.0000000
# 86  is_poisonous                  habitat_grasses  0.0000000
# 87  is_poisonous                   habitat_leaves  0.0000000
# 88  is_poisonous                  habitat_meadows  0.0000000
# 89  is_poisonous                    habitat_paths  0.0000000
# 90  is_poisonous                    habitat_urban  0.0000000
# 91  is_poisonous                    habitat_woods  0.0000000

# %%
# Convert the 'P-value' column to numeric type
target_results_df['P-value'] = target_results_df['P-value'].astype(float)

# Filter the DataFrame to select only insignificant p-values
insignificant_results = target_results_df[target_results_df['P-value'] >= 0.05]

# Display the insignificant results
print("Insignificant results (p-value >= 0.05) for the target variable 'is_poisonous' with all other variables:")
print(insignificant_results)
# Out:
# Insignificant results (p-value >= 0.05) for the target variable 'is_poisonous' with all other variables:
#       Variable 1                      Variable 2   P-value
# 2   is_poisonous                  cap_shape_flat  0.099555
# 41  is_poisonous  stalk_surface_above_ring_scaly  0.209315
# 63  is_poisonous               veil_type_partial  1.000000

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ##### Pearson's $\chi^{2}$  without the Target Variable

# %% [markdown]
# Now we will run a Pearson's $\chi^{2}$ test without the target variable. That is, we will be testing between predictor variables and seeing which association is significant. This will help in identifying potential multicollinearity issues.
#
# After we have run the Pearson's $\chi^{2}$ test, we will again list all the variables were the association was not significant. We can refer to this list in later parts of our machine learning journey.
#
# *Note: multicollinearity can still be a concern in logistic regression when dealing with binary variables. In logistic regression, multicollinearity among binary variables can lead to inflated standard errors, which in turn affects the estimation of coefficients. This can make it challenging to interpret the individual effects of the variables on the outcome. Moreover, the presence of multicollinearity in logistic regression can also lead to instability in coefficient estimates and can affect the overall performance of the model, including its predictive accuracy and generalization to new data*.

# %%
# Creating an empty DataFrame to store the results for independent variables:
independent_results = []

# Iterating over each pair of independent variables:
for i, col1 in enumerate(df.columns):
    for j, col2 in enumerate(df.columns):
        if i < j and col1 != 'is_poisonous' and col2 != 'is_poisonous':  # To avoid including the target variable and duplicate pairs
            # Creating a contingency table
            contingency_table = pd.crosstab(df[col1], df[col2])
            
            # Performing chi-square test of independence
            chi2, p_value, dof, _ = chi2_contingency(contingency_table)
            
            # Appending results to list
            independent_results.append({'Variable 1': col1,
                                        'Variable 2': col2,
                                        
                                        'P-value': p_value,
                                        })

# Converting results list to DataFrame:
independent_results_df = pd.DataFrame(independent_results)

# Ensuring all output is on the same row:

# Creating an empty list to store formatted results:
formatted_results = []

# Iterating over each row in the DataFrame:
for index, row in independent_results_df.iterrows():
    # Formating the output string for each row:
    formatted_result = f"{row['Variable 1']} - {row['Variable 2']}: p-value = {row['P-value']}"
    # Appending the formatted result to the list:
    formatted_results.append(formatted_result)

# Printing the formatted results:
for result in formatted_results:
    print(result)
# Out:
# cap_shape_bell - cap_shape_convex: p-value = 9.5140442179398e-87
# cap_shape_bell - cap_shape_flat: p-value = 1.4043347199364784e-67
# cap_shape_bell - cap_shape_knobbed: p-value = 3.097346282669833e-13
# cap_shape_bell - cap_shape_sunken: p-value = 0.3224636193529676
# cap_shape_bell - cap_surface_fibrous: p-value = 2.285578690579694e-16
# cap_shape_bell - cap_surface_scaly: p-value = 0.013527846819791809
# cap_shape_bell - cap_surface_smooth: p-value = 4.680303582517611e-26
# cap_shape_bell - cap_color_brown: p-value = 2.992587331429119e-14
# cap_shape_bell - cap_color_buff: p-value = 0.4640264410557877
# cap_shape_bell - cap_color_cinnamon: p-value = 0.19889831560174787
# cap_shape_bell - cap_color_gray: p-value = 4.668963874410604e-10
# cap_shape_bell - cap_color_green: p-value = 0.6701119596589058
# cap_shape_bell - cap_color_pink: p-value = 0.20071310090271016
# cap_shape_bell - cap_color_red: p-value = 4.252848003724834e-25
# cap_shape_bell - cap_color_white: p-value = 4.474424597319088e-81
# cap_shape_bell - cap_color_yellow: p-value = 4.446974555853331e-26
# cap_shape_bell - has_bruises_False: p-value = 3.1207915054052913e-25
# cap_shape_bell - odor_almond: p-value = 1.4438948958139653e-122
# cap_shape_bell - odor_anise: p-value = 1.4438948958139653e-122
# cap_shape_bell - odor_creosote: p-value = 0.0011767947767687792
# cap_shape_bell - odor_fishy: p-value = 2.6929060279369465e-09
# cap_shape_bell - odor_foul: p-value = 2.8352177466233135e-39
# cap_shape_bell - odor_none: p-value = 1.0
# cap_shape_bell - odor_pungent: p-value = 0.00014023900051107362
# cap_shape_bell - odor_spicy: p-value = 2.6929060279369465e-09
# cap_shape_bell - gill_attachment_free: p-value = 8.801366858055348e-28
# cap_shape_bell - gill_spacing_close: p-value = 0.0004902702272773001
# cap_shape_bell - gill_size_broad: p-value = 1.5940580932092646e-40
# cap_shape_bell - gill_color_black: p-value = 1.5385293277953152e-19
# cap_shape_bell - gill_color_brown: p-value = 0.0022132260900388084
# cap_shape_bell - gill_color_buff: p-value = 1.1398879052940545e-29
# cap_shape_bell - gill_color_chocolate: p-value = 1.0461100711535419e-11
# cap_shape_bell - gill_color_gray: p-value = 5.590275689179153e-28
# cap_shape_bell - gill_color_green: p-value = 1.2436913315254684e-19
# cap_shape_bell - gill_color_pink: p-value = 2.716874200739668e-10
# cap_shape_bell - gill_color_purple: p-value = 4.945115853219561e-08
# cap_shape_bell - gill_color_red: p-value = 0.030125725683373246
# cap_shape_bell - gill_color_white: p-value = 3.385086026952201e-14
# cap_shape_bell - gill_color_yellow: p-value = 3.014427328389201e-08
# cap_shape_bell - stalk_shape_tapering: p-value = 6.628556303354464e-138
# cap_shape_bell - stalk_surface_above_ring_scaly: p-value = 0.000203838077506055
# cap_shape_bell - stalk_surface_above_ring_silky: p-value = 9.40458129211541e-16
# cap_shape_bell - stalk_surface_above_ring_smooth: p-value = 1.6252438773803936e-24
# cap_shape_bell - stalk_surface_belows_ring_k: p-value = 1.1572678820217784e-17
# cap_shape_bell - stalk_surface_belows_ring_s: p-value = 4.865531724095879e-30
# cap_shape_bell - stalk_surface_belows_ring_y: p-value = 0.7317023548969708
# cap_shape_bell - stalk_color_above_ring_brown: p-value = 1.4834885072550747e-05
# cap_shape_bell - stalk_color_above_ring_buff: p-value = 3.837900647471631e-07
# cap_shape_bell - stalk_color_above_ring_cinnamon: p-value = 0.27341593668582764
# cap_shape_bell - stalk_color_above_ring_gray: p-value = 2.6929060279369465e-09
# cap_shape_bell - stalk_color_above_ring_orange: p-value = 8.813848388742349e-32
# cap_shape_bell - stalk_color_above_ring_pink: p-value = 1.0019705070138288e-32
# cap_shape_bell - stalk_color_above_ring_red: p-value = 0.030125725683373246
# cap_shape_bell - stalk_color_above_ring_white: p-value = 1.0798126987267388e-47
# cap_shape_bell - stalk_color_below_ring_brown: p-value = 6.865060628948592e-05
# cap_shape_bell - stalk_color_below_ring_buff: p-value = 3.837900647471631e-07
# cap_shape_bell - stalk_color_below_ring_gray: p-value = 2.6929060279369465e-09
# cap_shape_bell - stalk_color_below_ring_orange: p-value = 8.813848388742349e-32
# cap_shape_bell - stalk_color_below_ring_pink: p-value = 1.0019705070138288e-32
# cap_shape_bell - stalk_color_below_ring_red: p-value = 0.030125725683373246
# cap_shape_bell - stalk_color_below_ring_white: p-value = 2.2272237394818407e-45
# cap_shape_bell - stalk_color_below_ring_yellow: p-value = 0.000203838077506055
# cap_shape_bell - veil_type_partial: p-value = 1.0
# cap_shape_bell - veil_color_brown: p-value = 4.1697565667536935e-16
# cap_shape_bell - veil_color_white: p-value = 4.221844387537575e-33
# cap_shape_bell - veil_color_yellow: p-value = 0.10354726081636605
# cap_shape_bell - number_of_rings_o: p-value = 9.595958457680543e-73
# cap_shape_bell - number_of_rings_t: p-value = 1.169664901642895e-79
# cap_shape_bell - ring_type_evanescent: p-value = 7.412405559029865e-49
# cap_shape_bell - ring_type_flaring: p-value = 0.17041820795869025
# cap_shape_bell - ring_type_large: p-value = 2.9276453855983218e-21
# cap_shape_bell - ring_type_pendant: p-value = 2.3743765760530682e-101
# cap_shape_bell - spore_p_color_black: p-value = 0.007287358442590213
# cap_shape_bell - spore_p_color_brown: p-value = 0.0006996052134757839
# cap_shape_bell - spore_p_color_chocolate: p-value = 1.0475450327575218e-27
# cap_shape_bell - spore_p_color_green: p-value = 1.7612848252972402e-59
# cap_shape_bell - spore_p_color_orange: p-value = 2.457357649382098e-08
# cap_shape_bell - spore_p_color_purple: p-value = 0.17041820795869025
# cap_shape_bell - spore_p_color_white: p-value = 0.030507880625694463
# cap_shape_bell - spore_p_color_yellow: p-value = 2.457357649382098e-08
# cap_shape_bell - pop_clustered: p-value = 0.03802102458723868
# cap_shape_bell - pop_numerous: p-value = 1.4544714316589384e-257
# cap_shape_bell - pop_scattered: p-value = 5.382663980909546e-46
# cap_shape_bell - pop_several: p-value = 1.0538880790503354e-51
# cap_shape_bell - pop_solitary: p-value = 4.7427115619197356e-27
# cap_shape_bell - habitat_grasses: p-value = 7.051435383526539e-41
# cap_shape_bell - habitat_leaves: p-value = 0.40560432433093907
# cap_shape_bell - habitat_meadows: p-value = 1.267518434806957e-247
# cap_shape_bell - habitat_paths: p-value = 1.7530500659490503e-17
# cap_shape_bell - habitat_urban: p-value = 3.3340927233858806e-06
# cap_shape_bell - habitat_woods: p-value = 3.8192232746616705e-60
# cap_shape_convex - cap_shape_flat: p-value = 0.0
# cap_shape_convex - cap_shape_knobbed: p-value = 1.2135446387220928e-165
# cap_shape_convex - cap_shape_sunken: p-value = 7.453363123249825e-07
# cap_shape_convex - cap_surface_fibrous: p-value = 1.1999371326619305e-08
# cap_shape_convex - cap_surface_scaly: p-value = 0.08873847053554582
# cap_shape_convex - cap_surface_smooth: p-value = 0.0002742349952505975
# cap_shape_convex - cap_color_brown: p-value = 1.0062424440745828e-07
# cap_shape_convex - cap_color_buff: p-value = 0.0818388369828513
# cap_shape_convex - cap_color_cinnamon: p-value = 0.31584000544455754
# cap_shape_convex - cap_color_gray: p-value = 1.1005479190349458e-06
# cap_shape_convex - cap_color_green: p-value = 0.8802080639906832
# cap_shape_convex - cap_color_pink: p-value = 0.0015782947243383628
# cap_shape_convex - cap_color_red: p-value = 6.361073342662425e-06
# cap_shape_convex - cap_color_white: p-value = 0.003709830826313339
# cap_shape_convex - cap_color_yellow: p-value = 0.0029774979209773347
# cap_shape_convex - has_bruises_False: p-value = 1.3366650240945246e-05
# cap_shape_convex - odor_almond: p-value = 0.04454725438105946
# cap_shape_convex - odor_anise: p-value = 0.04454725438105946
# cap_shape_convex - odor_creosote: p-value = 1.0455505888165398e-53
# cap_shape_convex - odor_fishy: p-value = 6.760380283735344e-09
# cap_shape_convex - odor_foul: p-value = 0.5633928850660553
# cap_shape_convex - odor_none: p-value = 0.16056405992109624
# cap_shape_convex - odor_pungent: p-value = 0.11656156430826704
# cap_shape_convex - odor_spicy: p-value = 6.760380283735344e-09
# cap_shape_convex - gill_attachment_free: p-value = 1.8857820031623057e-08
# cap_shape_convex - gill_spacing_close: p-value = 0.0029430144139205414
# cap_shape_convex - gill_size_broad: p-value = 3.170773166724005e-07
# cap_shape_convex - gill_color_black: p-value = 0.10469074948306421
# cap_shape_convex - gill_color_brown: p-value = 0.00020133362682359302
# cap_shape_convex - gill_color_buff: p-value = 5.847159861277205e-28
# cap_shape_convex - gill_color_chocolate: p-value = 0.0049498976492451
# cap_shape_convex - gill_color_gray: p-value = 0.02523781470388703
# cap_shape_convex - gill_color_green: p-value = 2.3098536844602513e-05
# cap_shape_convex - gill_color_pink: p-value = 6.921355394367134e-06
# cap_shape_convex - gill_color_purple: p-value = 6.92340908670331e-06
# cap_shape_convex - gill_color_red: p-value = 0.02719591837836201
# cap_shape_convex - gill_color_white: p-value = 0.43497913446544023
# cap_shape_convex - gill_color_yellow: p-value = 0.00041467913786488795
# cap_shape_convex - stalk_shape_tapering: p-value = 0.01001793261420166
# cap_shape_convex - stalk_surface_above_ring_scaly: p-value = 0.009626127141391222
# cap_shape_convex - stalk_surface_above_ring_silky: p-value = 0.002014854699704936
# cap_shape_convex - stalk_surface_above_ring_smooth: p-value = 0.032233603263939016
# cap_shape_convex - stalk_surface_belows_ring_k: p-value = 0.00958676695713099
# cap_shape_convex - stalk_surface_belows_ring_s: p-value = 0.11852514964511139
# cap_shape_convex - stalk_surface_belows_ring_y: p-value = 0.37497665185844364
# cap_shape_convex - stalk_color_above_ring_brown: p-value = 0.08051098379914252
# cap_shape_convex - stalk_color_above_ring_buff: p-value = 0.036079662060594646
# cap_shape_convex - stalk_color_above_ring_cinnamon: p-value = 0.21401762884437053
# cap_shape_convex - stalk_color_above_ring_gray: p-value = 0.013981250181119474
# cap_shape_convex - stalk_color_above_ring_orange: p-value = 2.6251035441590167e-08
# cap_shape_convex - stalk_color_above_ring_pink: p-value = 0.008167831579294146
# cap_shape_convex - stalk_color_above_ring_red: p-value = 0.02719591837836201
# cap_shape_convex - stalk_color_above_ring_white: p-value = 0.08368551377065488
# cap_shape_convex - stalk_color_below_ring_brown: p-value = 0.40429808262075473
# cap_shape_convex - stalk_color_below_ring_buff: p-value = 0.036079662060594646
# cap_shape_convex - stalk_color_below_ring_gray: p-value = 0.013981250181119474
# cap_shape_convex - stalk_color_below_ring_orange: p-value = 2.6251035441590167e-08
# cap_shape_convex - stalk_color_below_ring_pink: p-value = 0.008167831579294146
# cap_shape_convex - stalk_color_below_ring_red: p-value = 0.02719591837836201
# cap_shape_convex - stalk_color_below_ring_white: p-value = 0.023596510443600133
# cap_shape_convex - stalk_color_below_ring_yellow: p-value = 0.009626127141391222
# cap_shape_convex - veil_type_partial: p-value = 1.0
# cap_shape_convex - veil_color_brown: p-value = 0.00011353110535961109
# cap_shape_convex - veil_color_white: p-value = 2.3263403327772586e-09
# cap_shape_convex - veil_color_yellow: p-value = 0.02750404939976389
# cap_shape_convex - number_of_rings_o: p-value = 7.23575506623507e-15
# cap_shape_convex - number_of_rings_t: p-value = 2.2952121278556346e-14
# cap_shape_convex - ring_type_evanescent: p-value = 3.7177529812632126e-21
# cap_shape_convex - ring_type_flaring: p-value = 0.5805818255064321
# cap_shape_convex - ring_type_large: p-value = 9.071001976424012e-05
# cap_shape_convex - ring_type_pendant: p-value = 7.85063212354534e-10
# cap_shape_convex - spore_p_color_black: p-value = 1.837525547019763e-12
# cap_shape_convex - spore_p_color_brown: p-value = 5.724368132549987e-11
# cap_shape_convex - spore_p_color_chocolate: p-value = 6.427451581385335e-06
# cap_shape_convex - spore_p_color_green: p-value = 3.1775069904463696e-14
# cap_shape_convex - spore_p_color_orange: p-value = 0.008088744746597584
# cap_shape_convex - spore_p_color_purple: p-value = 0.5805818255064321
# cap_shape_convex - spore_p_color_white: p-value = 2.1476130376151916e-43
# cap_shape_convex - spore_p_color_yellow: p-value = 0.008088744746597584
# cap_shape_convex - pop_clustered: p-value = 4.985059884516943e-09
# cap_shape_convex - pop_numerous: p-value = 0.7175240687277977
# cap_shape_convex - pop_scattered: p-value = 1.0916098522858355e-07
# cap_shape_convex - pop_several: p-value = 5.8387508065675456e-08
# cap_shape_convex - pop_solitary: p-value = 6.470258661855079e-05
# cap_shape_convex - habitat_grasses: p-value = 0.03887166910922493
# cap_shape_convex - habitat_leaves: p-value = 4.186646700496928e-18
# cap_shape_convex - habitat_meadows: p-value = 0.7276226262684613
# cap_shape_convex - habitat_paths: p-value = 0.009720701969054963
# cap_shape_convex - habitat_urban: p-value = 0.8393051243659131
# cap_shape_convex - habitat_woods: p-value = 1.1462278173284826e-10
# cap_shape_flat - cap_shape_knobbed: p-value = 9.880629965742356e-129
# cap_shape_flat - cap_shape_sunken: p-value = 1.4830253793247633e-05
# cap_shape_flat - cap_surface_fibrous: p-value = 6.044412853454556e-09
# cap_shape_flat - cap_surface_scaly: p-value = 0.00939212237358754
# cap_shape_flat - cap_surface_smooth: p-value = 4.7122246101635766e-17
# cap_shape_flat - cap_color_brown: p-value = 0.09131559128634473
# cap_shape_flat - cap_color_buff: p-value = 0.09877278369602557
# cap_shape_flat - cap_color_cinnamon: p-value = 0.8593078022039407
# cap_shape_flat - cap_color_gray: p-value = 3.547103826006892e-07
# cap_shape_flat - cap_color_green: p-value = 0.5069369440814537
# cap_shape_flat - cap_color_pink: p-value = 5.519070086213653e-05
# cap_shape_flat - cap_color_red: p-value = 0.4275482823439555
# cap_shape_flat - cap_color_white: p-value = 1.5428520709246298e-15
# cap_shape_flat - cap_color_yellow: p-value = 0.36658444367932763
# cap_shape_flat - has_bruises_False: p-value = 5.1260804688307626e-05
# cap_shape_flat - odor_almond: p-value = 3.2593877170653985e-18
# cap_shape_flat - odor_anise: p-value = 3.2593877170653985e-18
# cap_shape_flat - odor_creosote: p-value = 1.3967229135524057e-28
# cap_shape_flat - odor_fishy: p-value = 0.005992005948866705
# cap_shape_flat - odor_foul: p-value = 6.593347147725516e-14
# cap_shape_flat - odor_none: p-value = 1.93735871570428e-09
# cap_shape_flat - odor_pungent: p-value = 0.0002405525051256121
# cap_shape_flat - odor_spicy: p-value = 0.005992005948866705
# cap_shape_flat - gill_attachment_free: p-value = 0.0001085456406150672
# cap_shape_flat - gill_spacing_close: p-value = 0.0004685922175047841
# cap_shape_flat - gill_size_broad: p-value = 1.0148673986071685e-11
# cap_shape_flat - gill_color_black: p-value = 0.02305940671720204
# cap_shape_flat - gill_color_brown: p-value = 0.5459283666174377
# cap_shape_flat - gill_color_buff: p-value = 1.7263049724311307e-07
# cap_shape_flat - gill_color_chocolate: p-value = 9.162465965444701e-11
# cap_shape_flat - gill_color_gray: p-value = 1.414491193136697e-05
# cap_shape_flat - gill_color_green: p-value = 0.3585985221987086
# cap_shape_flat - gill_color_pink: p-value = 9.882325078956141e-08
# cap_shape_flat - gill_color_purple: p-value = 0.003478764412851439
# cap_shape_flat - gill_color_red: p-value = 0.3172586421868407
# cap_shape_flat - gill_color_white: p-value = 0.22652337925899957
# cap_shape_flat - gill_color_yellow: p-value = 0.02815800955816941
# cap_shape_flat - stalk_shape_tapering: p-value = 1.295402733092333e-25
# cap_shape_flat - stalk_surface_above_ring_scaly: p-value = 0.2381836327843776
# cap_shape_flat - stalk_surface_above_ring_silky: p-value = 0.07798330713498038
# cap_shape_flat - stalk_surface_above_ring_smooth: p-value = 2.154630853984483e-05
# cap_shape_flat - stalk_surface_belows_ring_k: p-value = 0.035704941316663845
# cap_shape_flat - stalk_surface_belows_ring_s: p-value = 5.422888251793616e-08
# cap_shape_flat - stalk_surface_belows_ring_y: p-value = 0.1608505304999529
# cap_shape_flat - stalk_color_above_ring_brown: p-value = 5.199972341937515e-06
# cap_shape_flat - stalk_color_above_ring_buff: p-value = 1.1776544281660899e-06
# cap_shape_flat - stalk_color_above_ring_cinnamon: p-value = 0.6149352792096756
# cap_shape_flat - stalk_color_above_ring_gray: p-value = 1.3535590652409796e-08
# cap_shape_flat - stalk_color_above_ring_orange: p-value = 9.780308602976366e-05
# cap_shape_flat - stalk_color_above_ring_pink: p-value = 0.0004240750732066591
# cap_shape_flat - stalk_color_above_ring_red: p-value = 0.3172586421868407
# cap_shape_flat - stalk_color_above_ring_white: p-value = 4.309114038189173e-18
# cap_shape_flat - stalk_color_below_ring_brown: p-value = 0.00012945160134734992
# cap_shape_flat - stalk_color_below_ring_buff: p-value = 1.1776544281660899e-06
# cap_shape_flat - stalk_color_below_ring_gray: p-value = 1.3535590652409796e-08
# cap_shape_flat - stalk_color_below_ring_orange: p-value = 9.780308602976366e-05
# cap_shape_flat - stalk_color_below_ring_pink: p-value = 0.0004240750732066591
# cap_shape_flat - stalk_color_below_ring_red: p-value = 0.3172586421868407
# cap_shape_flat - stalk_color_below_ring_white: p-value = 7.851653777046951e-17
# cap_shape_flat - stalk_color_below_ring_yellow: p-value = 0.2381836327843776
# cap_shape_flat - veil_type_partial: p-value = 1.0
# cap_shape_flat - veil_color_brown: p-value = 0.007238289930166962
# cap_shape_flat - veil_color_white: p-value = 6.85151263880405e-05
# cap_shape_flat - veil_color_yellow: p-value = 0.6611202856330154
# cap_shape_flat - number_of_rings_o: p-value = 3.5101108007744503e-22
# cap_shape_flat - number_of_rings_t: p-value = 1.4328872144598257e-22
# cap_shape_flat - ring_type_evanescent: p-value = 0.20247480487608924
# cap_shape_flat - ring_type_flaring: p-value = 0.14740124431694884
# cap_shape_flat - ring_type_large: p-value = 2.3517153498835144e-19
# cap_shape_flat - ring_type_pendant: p-value = 3.534020323726452e-08
# cap_shape_flat - spore_p_color_black: p-value = 0.17321614579393824
# cap_shape_flat - spore_p_color_brown: p-value = 0.20323972731684872
# cap_shape_flat - spore_p_color_chocolate: p-value = 3.77972019695557e-25
# cap_shape_flat - spore_p_color_green: p-value = 0.06609915677409374
# cap_shape_flat - spore_p_color_orange: p-value = 0.06889035415459993
# cap_shape_flat - spore_p_color_purple: p-value = 0.14740124431694884
# cap_shape_flat - spore_p_color_white: p-value = 1.381671937906787e-29
# cap_shape_flat - spore_p_color_yellow: p-value = 0.06889035415459993
# cap_shape_flat - pop_clustered: p-value = 0.0018264937579581006
# cap_shape_flat - pop_numerous: p-value = 1.397910194879763e-59
# cap_shape_flat - pop_scattered: p-value = 1.0399364508360684e-11
# cap_shape_flat - pop_several: p-value = 0.0019474664749328011
# cap_shape_flat - pop_solitary: p-value = 1.4049721755638806e-23
# cap_shape_flat - habitat_grasses: p-value = 0.11071825591272294
# cap_shape_flat - habitat_leaves: p-value = 2.8861398097897634e-06
# cap_shape_flat - habitat_meadows: p-value = 4.410734052492688e-31
# cap_shape_flat - habitat_paths: p-value = 0.05233235765381928
# cap_shape_flat - habitat_urban: p-value = 0.006798038829562392
# cap_shape_flat - habitat_woods: p-value = 1.6351949184346642e-11
# cap_shape_knobbed - cap_shape_sunken: p-value = 0.10594166526852897
# cap_shape_knobbed - cap_surface_fibrous: p-value = 2.7002431352662807e-46
# cap_shape_knobbed - cap_surface_scaly: p-value = 0.1808625887768743
# cap_shape_knobbed - cap_surface_smooth: p-value = 2.68615609909086e-35
# cap_shape_knobbed - cap_color_brown: p-value = 1.1030309508979771e-29
# cap_shape_knobbed - cap_color_buff: p-value = 0.8725369498686129
# cap_shape_knobbed - cap_color_cinnamon: p-value = 0.0004561026737843399
# cap_shape_knobbed - cap_color_gray: p-value = 3.9163460803833885e-34
# cap_shape_knobbed - cap_color_green: p-value = 0.34964922497964945
# cap_shape_knobbed - cap_color_pink: p-value = 0.8189773586233878
# cap_shape_knobbed - cap_color_red: p-value = 2.3015303219297147e-48
# cap_shape_knobbed - cap_color_white: p-value = 1.1198545869039554e-09
# cap_shape_knobbed - cap_color_yellow: p-value = 8.544889693379876e-29
# cap_shape_knobbed - has_bruises_False: p-value = 8.733556460683798e-95
# cap_shape_knobbed - odor_almond: p-value = 8.788117948205046e-12
# cap_shape_knobbed - odor_anise: p-value = 8.788117948205046e-12
# cap_shape_knobbed - odor_creosote: p-value = 4.1570461754467435e-06
# cap_shape_knobbed - odor_fishy: p-value = 2.8224270137803772e-80
# cap_shape_knobbed - odor_foul: p-value = 0.02173976294414656
# cap_shape_knobbed - odor_none: p-value = 1.254589256432239e-18
# cap_shape_knobbed - odor_pungent: p-value = 7.783479255610647e-08
# cap_shape_knobbed - odor_spicy: p-value = 2.8224270137803772e-80
# cap_shape_knobbed - gill_attachment_free: p-value = 1.1945743062041035e-13
# cap_shape_knobbed - gill_spacing_close: p-value = 0.08616744773018085
# cap_shape_knobbed - gill_size_broad: p-value = 2.472864917668993e-167
# cap_shape_knobbed - gill_color_black: p-value = 5.2652071565842364e-12
# cap_shape_knobbed - gill_color_brown: p-value = 5.0680646561820283e-23
# cap_shape_knobbed - gill_color_buff: p-value = 1.5904699450048228e-280
# cap_shape_knobbed - gill_color_chocolate: p-value = 2.288331002829189e-21
# cap_shape_knobbed - gill_color_gray: p-value = 2.3293379827564134e-08
# cap_shape_knobbed - gill_color_green: p-value = 0.18852479741637243
# cap_shape_knobbed - gill_color_pink: p-value = 9.99658975415922e-30
# cap_shape_knobbed - gill_color_purple: p-value = 2.3017762623817937e-14
# cap_shape_knobbed - gill_color_red: p-value = 1.7142293468262232e-13
# cap_shape_knobbed - gill_color_white: p-value = 0.030023201239873967
# cap_shape_knobbed - gill_color_yellow: p-value = 8.587941449440605e-07
# cap_shape_knobbed - stalk_shape_tapering: p-value = 4.7053886980833535e-15
# cap_shape_knobbed - stalk_surface_above_ring_scaly: p-value = 0.03906445464254738
# cap_shape_knobbed - stalk_surface_above_ring_silky: p-value = 4.553518404464324e-20
# cap_shape_knobbed - stalk_surface_above_ring_smooth: p-value = 1.3988036626637247e-07
# cap_shape_knobbed - stalk_surface_belows_ring_k: p-value = 2.597712264792472e-16
# cap_shape_knobbed - stalk_surface_belows_ring_s: p-value = 0.0008142309517662132
# cap_shape_knobbed - stalk_surface_belows_ring_y: p-value = 0.6253900071274376
# cap_shape_knobbed - stalk_color_above_ring_brown: p-value = 3.777553224992919e-11
# cap_shape_knobbed - stalk_color_above_ring_buff: p-value = 1.1264662288020436e-12
# cap_shape_knobbed - stalk_color_above_ring_cinnamon: p-value = 1.5357242327409677e-05
# cap_shape_knobbed - stalk_color_above_ring_gray: p-value = 9.063286325927726e-17
# cap_shape_knobbed - stalk_color_above_ring_orange: p-value = 1.552563739833497e-11
# cap_shape_knobbed - stalk_color_above_ring_pink: p-value = 3.7195367057095846e-17
# cap_shape_knobbed - stalk_color_above_ring_red: p-value = 1.7142293468262232e-13
# cap_shape_knobbed - stalk_color_above_ring_white: p-value = 0.3579705177491157
# cap_shape_knobbed - stalk_color_below_ring_brown: p-value = 2.945794222330612e-05
# cap_shape_knobbed - stalk_color_below_ring_buff: p-value = 1.1264662288020436e-12
# cap_shape_knobbed - stalk_color_below_ring_gray: p-value = 9.063286325927726e-17
# cap_shape_knobbed - stalk_color_below_ring_orange: p-value = 1.552563739833497e-11
# cap_shape_knobbed - stalk_color_below_ring_pink: p-value = 3.7195367057095846e-17
# cap_shape_knobbed - stalk_color_below_ring_red: p-value = 1.7142293468262232e-13
# cap_shape_knobbed - stalk_color_below_ring_white: p-value = 0.03720561157482168
# cap_shape_knobbed - stalk_color_below_ring_yellow: p-value = 0.03906445464254738
# cap_shape_knobbed - veil_type_partial: p-value = 1.0
# cap_shape_knobbed - veil_color_brown: p-value = 3.2474108827004877e-06
# cap_shape_knobbed - veil_color_white: p-value = 5.5656633218650516e-12
# cap_shape_knobbed - veil_color_yellow: p-value = 0.42344143323946926
# cap_shape_knobbed - number_of_rings_o: p-value = 1.4020778007819408e-51
# cap_shape_knobbed - number_of_rings_t: p-value = 1.0531938676216606e-46
# cap_shape_knobbed - ring_type_evanescent: p-value = 2.680879243294768e-192
# cap_shape_knobbed - ring_type_flaring: p-value = 0.03558504980358613
# cap_shape_knobbed - ring_type_large: p-value = 1.1666876860842692e-39
# cap_shape_knobbed - ring_type_pendant: p-value = 1.8997612834213893e-77
# cap_shape_knobbed - spore_p_color_black: p-value = 1.1201699835281804e-61
# cap_shape_knobbed - spore_p_color_brown: p-value = 2.6287287996777486e-58
# cap_shape_knobbed - spore_p_color_chocolate: p-value = 4.9291729439939545e-52
# cap_shape_knobbed - spore_p_color_green: p-value = 0.007459096491372611
# cap_shape_knobbed - spore_p_color_orange: p-value = 0.0015678586678639851
# cap_shape_knobbed - spore_p_color_purple: p-value = 0.03558504980358613
# cap_shape_knobbed - spore_p_color_white: p-value = 0.0
# cap_shape_knobbed - spore_p_color_yellow: p-value = 0.0015678586678639851
# cap_shape_knobbed - pop_clustered: p-value = 1.9105457989521723e-36
# cap_shape_knobbed - pop_numerous: p-value = 0.25387153337791835
# cap_shape_knobbed - pop_scattered: p-value = 1.2098086795673836e-15
# cap_shape_knobbed - pop_several: p-value = 2.1740406835791624e-54
# cap_shape_knobbed - pop_solitary: p-value = 9.62600557098465e-53
# cap_shape_knobbed - habitat_grasses: p-value = 2.437953528437676e-24
# cap_shape_knobbed - habitat_leaves: p-value = 4.1654692866221895e-99
# cap_shape_knobbed - habitat_meadows: p-value = 8.194716219716099e-09
# cap_shape_knobbed - habitat_paths: p-value = 5.155848510562039e-16
# cap_shape_knobbed - habitat_urban: p-value = 6.76364134651504e-11
# cap_shape_knobbed - habitat_woods: p-value = 1.1955455432170725e-15
# cap_shape_sunken - cap_surface_fibrous: p-value = 1.80327264190093e-18
# cap_shape_sunken - cap_surface_scaly: p-value = 8.977010024947322e-06
# cap_shape_sunken - cap_surface_smooth: p-value = 0.0002626885656767126
# cap_shape_sunken - cap_color_brown: p-value = 0.010396189695509385
# cap_shape_sunken - cap_color_buff: p-value = 0.8404525523952389
# cap_shape_sunken - cap_color_cinnamon: p-value = 1.0
# cap_shape_sunken - cap_color_gray: p-value = 0.0004790177886972359
# cap_shape_sunken - cap_color_green: p-value = 1.0
# cap_shape_sunken - cap_color_pink: p-value = 0.9281141809698367
# cap_shape_sunken - cap_color_red: p-value = 0.013550104661952377
# cap_shape_sunken - cap_color_white: p-value = 0.05656274443981908
# cap_shape_sunken - cap_color_yellow: p-value = 0.051388109077803085
# cap_shape_sunken - has_bruises_False: p-value = 4.230139111405768e-06
# cap_shape_sunken - odor_almond: p-value = 0.37857359328469187
# cap_shape_sunken - odor_anise: p-value = 0.37857359328469187
# cap_shape_sunken - odor_creosote: p-value = 0.765071547607308
# cap_shape_sunken - odor_fishy: p-value = 0.2221967881770739
# cap_shape_sunken - odor_foul: p-value = 0.0013245529315755807
# cap_shape_sunken - odor_none: p-value = 3.1618020097277396e-10
# cap_shape_sunken - odor_pungent: p-value = 0.6062440892496221
# cap_shape_sunken - odor_spicy: p-value = 0.2221967881770739
# cap_shape_sunken - gill_attachment_free: p-value = 0.7149630167458985
# cap_shape_sunken - gill_spacing_close: p-value = 0.024651286032658003
# cap_shape_sunken - gill_size_broad: p-value = 1.2288759903763885e-16
# cap_shape_sunken - gill_color_black: p-value = 1.7599068592405183e-06
# cap_shape_sunken - gill_color_brown: p-value = 0.07477919218925327
# cap_shape_sunken - gill_color_buff: p-value = 0.0063392855589702824
# cap_shape_sunken - gill_color_chocolate: p-value = 0.1403918255311894
# cap_shape_sunken - gill_color_gray: p-value = 0.0055480468631468
# cap_shape_sunken - gill_color_green: p-value = 1.0
# cap_shape_sunken - gill_color_pink: p-value = 0.4577927622037251
# cap_shape_sunken - gill_color_purple: p-value = 0.2856023247034808
# cap_shape_sunken - gill_color_red: p-value = 1.0
# cap_shape_sunken - gill_color_white: p-value = 0.034643180137277615
# cap_shape_sunken - gill_color_yellow: p-value = 1.0
# cap_shape_sunken - stalk_shape_tapering: p-value = 2.7895733330114437e-10
# cap_shape_sunken - stalk_surface_above_ring_scaly: p-value = 1.0
# cap_shape_sunken - stalk_surface_above_ring_silky: p-value = 0.0005709850218491251
# cap_shape_sunken - stalk_surface_above_ring_smooth: p-value = 4.250993540775416e-05
# cap_shape_sunken - stalk_surface_belows_ring_k: p-value = 0.0007523112370487931
# cap_shape_sunken - stalk_surface_belows_ring_s: p-value = 1.2211039918869654e-05
# cap_shape_sunken - stalk_surface_belows_ring_y: p-value = 0.5507707420632765
# cap_shape_sunken - stalk_color_above_ring_brown: p-value = 0.32643000346311457
# cap_shape_sunken - stalk_color_above_ring_buff: p-value = 0.3428505371457298
# cap_shape_sunken - stalk_color_above_ring_cinnamon: p-value = 1.0
# cap_shape_sunken - stalk_color_above_ring_gray: p-value = 0.2221967881770739
# cap_shape_sunken - stalk_color_above_ring_orange: p-value = 0.765071547607308
# cap_shape_sunken - stalk_color_above_ring_pink: p-value = 0.0038375385787412855
# cap_shape_sunken - stalk_color_above_ring_red: p-value = 1.0
# cap_shape_sunken - stalk_color_above_ring_white: p-value = 7.259798066360325e-07
# cap_shape_sunken - stalk_color_below_ring_brown: p-value = 0.26892081634535525
# cap_shape_sunken - stalk_color_below_ring_buff: p-value = 0.3428505371457298
# cap_shape_sunken - stalk_color_below_ring_gray: p-value = 0.2221967881770739
# cap_shape_sunken - stalk_color_below_ring_orange: p-value = 0.765071547607308
# cap_shape_sunken - stalk_color_below_ring_pink: p-value = 0.0038375385787412855
# cap_shape_sunken - stalk_color_below_ring_red: p-value = 1.0
# cap_shape_sunken - stalk_color_below_ring_white: p-value = 4.247749860865904e-07
# cap_shape_sunken - stalk_color_below_ring_yellow: p-value = 1.0
# cap_shape_sunken - veil_type_partial: p-value = 1.0
# cap_shape_sunken - veil_color_brown: p-value = 1.0
# cap_shape_sunken - veil_color_white: p-value = 0.7421880899975016
# cap_shape_sunken - veil_color_yellow: p-value = 1.0
# cap_shape_sunken - number_of_rings_o: p-value = 0.18610714871447082
# cap_shape_sunken - number_of_rings_t: p-value = 0.20695803132554952
# cap_shape_sunken - ring_type_evanescent: p-value = 9.743354738627479e-05
# cap_shape_sunken - ring_type_flaring: p-value = 1.0
# cap_shape_sunken - ring_type_large: p-value = 0.02591292747163635
# cap_shape_sunken - ring_type_pendant: p-value = 1.8704660665896475e-08
# cap_shape_sunken - spore_p_color_black: p-value = 0.0006306499688194464
# cap_shape_sunken - spore_p_color_brown: p-value = 0.0013589473046348402
# cap_shape_sunken - spore_p_color_chocolate: p-value = 0.008771853597954165
# cap_shape_sunken - spore_p_color_green: p-value = 1.0
# cap_shape_sunken - spore_p_color_orange: p-value = 1.0
# cap_shape_sunken - spore_p_color_purple: p-value = 1.0
# cap_shape_sunken - spore_p_color_white: p-value = 0.0005346579088585931
# cap_shape_sunken - spore_p_color_yellow: p-value = 1.0
# cap_shape_sunken - pop_clustered: p-value = 0.4578862355085421
# cap_shape_sunken - pop_numerous: p-value = 0.37857359328469187
# cap_shape_sunken - pop_scattered: p-value = 0.030072426192841114
# cap_shape_sunken - pop_several: p-value = 1.0
# cap_shape_sunken - pop_solitary: p-value = 0.00014291028263149216
# cap_shape_sunken - habitat_grasses: p-value = 0.0013869956545921771
# cap_shape_sunken - habitat_leaves: p-value = 0.1047043840622905
# cap_shape_sunken - habitat_meadows: p-value = 0.5361397789893977
# cap_shape_sunken - habitat_paths: p-value = 0.041346227365553226
# cap_shape_sunken - habitat_urban: p-value = 1.7205039498320987e-144
# cap_shape_sunken - habitat_woods: p-value = 1.5151468992210023e-05
# cap_surface_fibrous - cap_surface_scaly: p-value = 0.0
# cap_surface_fibrous - cap_surface_smooth: p-value = 0.0
# cap_surface_fibrous - cap_color_brown: p-value = 4.9323693387575926e-20
# cap_surface_fibrous - cap_color_buff: p-value = 2.5163056632868015e-16
# cap_surface_fibrous - cap_color_cinnamon: p-value = 0.9825808615053487
# cap_surface_fibrous - cap_color_gray: p-value = 2.3449580913885824e-102
# cap_surface_fibrous - cap_color_green: p-value = 0.024169057327670992
# cap_surface_fibrous - cap_color_pink: p-value = 0.10847129820777511
# cap_surface_fibrous - cap_color_red: p-value = 8.448868220585061e-19
# cap_surface_fibrous - cap_color_white: p-value = 0.002908858243694207
# cap_surface_fibrous - cap_color_yellow: p-value = 0.00034002742508797856
# cap_surface_fibrous - has_bruises_False: p-value = 0.010121685405406197
# cap_surface_fibrous - odor_almond: p-value = 2.2748759981566432e-24
# cap_surface_fibrous - odor_anise: p-value = 2.2748759981566432e-24
# cap_surface_fibrous - odor_creosote: p-value = 4.824783612201531e-11
# cap_surface_fibrous - odor_fishy: p-value = 1.6579134548849278e-55
# cap_surface_fibrous - odor_foul: p-value = 0.08825778654917887
# cap_surface_fibrous - odor_none: p-value = 1.9878575171175798e-146
# cap_surface_fibrous - odor_pungent: p-value = 1.8118341918402986e-24
# cap_surface_fibrous - odor_spicy: p-value = 1.6579134548849278e-55
# cap_surface_fibrous - gill_attachment_free: p-value = 3.405269908994308e-20
# cap_surface_fibrous - gill_spacing_close: p-value = 4.230811048823525e-74
# cap_surface_fibrous - gill_size_broad: p-value = 3.007617000955727e-119
# cap_surface_fibrous - gill_color_black: p-value = 0.7370068951653939
# cap_surface_fibrous - gill_color_brown: p-value = 2.3349481219775295e-08
# cap_surface_fibrous - gill_color_buff: p-value = 2.019080826980772e-192
# cap_surface_fibrous - gill_color_chocolate: p-value = 1.501907887787455e-18
# cap_surface_fibrous - gill_color_gray: p-value = 2.412706840178458e-16
# cap_surface_fibrous - gill_color_green: p-value = 0.004032448979754224
# cap_surface_fibrous - gill_color_pink: p-value = 9.212971179794241e-42
# cap_surface_fibrous - gill_color_purple: p-value = 2.095686224957557e-24
# cap_surface_fibrous - gill_color_red: p-value = 9.480847151091602e-10
# cap_surface_fibrous - gill_color_white: p-value = 0.11537292304247582
# cap_surface_fibrous - gill_color_yellow: p-value = 7.722398322056405e-09
# cap_surface_fibrous - stalk_shape_tapering: p-value = 0.3355911516373646
# cap_surface_fibrous - stalk_surface_above_ring_scaly: p-value = 0.004032448979754224
# cap_surface_fibrous - stalk_surface_above_ring_silky: p-value = 0.0016906517881648093
# cap_surface_fibrous - stalk_surface_above_ring_smooth: p-value = 6.123020785095997e-07
# cap_surface_fibrous - stalk_surface_belows_ring_k: p-value = 0.0007981340106160444
# cap_surface_fibrous - stalk_surface_belows_ring_s: p-value = 0.14335700358827935
# cap_surface_fibrous - stalk_surface_belows_ring_y: p-value = 5.6524337242726445e-18
# cap_surface_fibrous - stalk_color_above_ring_brown: p-value = 4.409023324029313e-21
# cap_surface_fibrous - stalk_color_above_ring_buff: p-value = 6.404318169290856e-24
# cap_surface_fibrous - stalk_color_above_ring_cinnamon: p-value = 0.00029808943572070146
# cap_surface_fibrous - stalk_color_above_ring_gray: p-value = 5.426608704111535e-32
# cap_surface_fibrous - stalk_color_above_ring_orange: p-value = 1.5624604871340122e-18
# cap_surface_fibrous - stalk_color_above_ring_pink: p-value = 0.0792008254069019
# cap_surface_fibrous - stalk_color_above_ring_red: p-value = 9.480847151091602e-10
# cap_surface_fibrous - stalk_color_above_ring_white: p-value = 1.3401224840028088e-18
# cap_surface_fibrous - stalk_color_below_ring_brown: p-value = 1.3402811713575725e-24
# cap_surface_fibrous - stalk_color_below_ring_buff: p-value = 6.404318169290856e-24
# cap_surface_fibrous - stalk_color_below_ring_gray: p-value = 5.426608704111535e-32
# cap_surface_fibrous - stalk_color_below_ring_orange: p-value = 1.5624604871340122e-18
# cap_surface_fibrous - stalk_color_below_ring_pink: p-value = 0.0792008254069019
# cap_surface_fibrous - stalk_color_below_ring_red: p-value = 9.480847151091602e-10
# cap_surface_fibrous - stalk_color_below_ring_white: p-value = 5.850535762414185e-22
# cap_surface_fibrous - stalk_color_below_ring_yellow: p-value = 0.7699236331571665
# cap_surface_fibrous - veil_type_partial: p-value = 1.0
# cap_surface_fibrous - veil_color_brown: p-value = 9.480847151091602e-10
# cap_surface_fibrous - veil_color_white: p-value = 2.8576244834693542e-19
# cap_surface_fibrous - veil_color_yellow: p-value = 0.16224631657448935
# cap_surface_fibrous - number_of_rings_o: p-value = 0.0006870657660914723
# cap_surface_fibrous - number_of_rings_t: p-value = 0.011697510299656473
# cap_surface_fibrous - ring_type_evanescent: p-value = 4.347479184571915e-81
# cap_surface_fibrous - ring_type_flaring: p-value = 2.305760333877327e-05
# cap_surface_fibrous - ring_type_large: p-value = 2.768984011557693e-77
# cap_surface_fibrous - ring_type_pendant: p-value = 1.9238797933286857e-08
# cap_surface_fibrous - spore_p_color_black: p-value = 4.034844594053682e-27
# cap_surface_fibrous - spore_p_color_brown: p-value = 2.353352355573493e-25
# cap_surface_fibrous - spore_p_color_chocolate: p-value = 9.645029257262304e-29
# cap_surface_fibrous - spore_p_color_green: p-value = 1.459420235164811e-07
# cap_surface_fibrous - spore_p_color_orange: p-value = 2.305760333877327e-05
# cap_surface_fibrous - spore_p_color_purple: p-value = 0.0016982173032264291
# cap_surface_fibrous - spore_p_color_white: p-value = 1.8395581752874823e-158
# cap_surface_fibrous - spore_p_color_yellow: p-value = 2.305760333877327e-05
# cap_surface_fibrous - pop_clustered: p-value = 2.1924111699607745e-32
# cap_surface_fibrous - pop_numerous: p-value = 2.164940637767153e-06
# cap_surface_fibrous - pop_scattered: p-value = 0.0027882427250040826
# cap_surface_fibrous - pop_several: p-value = 1.1304936515807477e-25
# cap_surface_fibrous - pop_solitary: p-value = 4.6208581081692524e-80
# cap_surface_fibrous - habitat_grasses: p-value = 4.3120513523491176e-13
# cap_surface_fibrous - habitat_leaves: p-value = 8.789724874739926e-67
# cap_surface_fibrous - habitat_meadows: p-value = 7.647876744506016e-28
# cap_surface_fibrous - habitat_paths: p-value = 7.157034882740061e-15
# cap_surface_fibrous - habitat_urban: p-value = 0.3102322741910722
# cap_surface_fibrous - habitat_woods: p-value = 4.593874789366982e-66
# cap_surface_scaly - cap_surface_smooth: p-value = 0.0
# cap_surface_scaly - cap_color_brown: p-value = 0.07384406166098663
# cap_surface_scaly - cap_color_buff: p-value = 1.1242053053476162e-06
# cap_surface_scaly - cap_color_cinnamon: p-value = 0.0021764063467993905
# cap_surface_scaly - cap_color_gray: p-value = 1.5640971852980852e-10
# cap_surface_scaly - cap_color_green: p-value = 3.2338418567687227e-06
# cap_surface_scaly - cap_color_pink: p-value = 0.003514929742930428
# cap_surface_scaly - cap_color_red: p-value = 6.29261192065217e-20
# cap_surface_scaly - cap_color_white: p-value = 2.831885841404279e-38
# cap_surface_scaly - cap_color_yellow: p-value = 1.2396762418733216e-19
# cap_surface_scaly - has_bruises_False: p-value = 4.581803173820223e-29
# cap_surface_scaly - odor_almond: p-value = 2.4318198007352573e-11
# cap_surface_scaly - odor_anise: p-value = 2.4318198007352573e-11
# cap_surface_scaly - odor_creosote: p-value = 6.704571704708764e-30
# cap_surface_scaly - odor_fishy: p-value = 3.8780961825007485e-07
# cap_surface_scaly - odor_foul: p-value = 0.0001821736334061337
# cap_surface_scaly - odor_none: p-value = 1.2241459062044425e-39
# cap_surface_scaly - odor_pungent: p-value = 0.0010465792636806333
# cap_surface_scaly - odor_spicy: p-value = 3.8780961825007485e-07
# cap_surface_scaly - gill_attachment_free: p-value = 1.0596401932862676e-20
# cap_surface_scaly - gill_spacing_close: p-value = 8.652718703857986e-198
# cap_surface_scaly - gill_size_broad: p-value = 1.4606413603099563e-05
# cap_surface_scaly - gill_color_black: p-value = 5.61050560492143e-12
# cap_surface_scaly - gill_color_brown: p-value = 0.004555058376369341
# cap_surface_scaly - gill_color_buff: p-value = 7.684161212113945e-22
# cap_surface_scaly - gill_color_chocolate: p-value = 4.4814084728384486e-07
# cap_surface_scaly - gill_color_gray: p-value = 0.5430294095565196
# cap_surface_scaly - gill_color_green: p-value = 0.4237266791431321
# cap_surface_scaly - gill_color_pink: p-value = 0.0012219864920684264
# cap_surface_scaly - gill_color_purple: p-value = 0.0031994205400488907
# cap_surface_scaly - gill_color_red: p-value = 0.054661479326910206
# cap_surface_scaly - gill_color_white: p-value = 0.00024211840203716535
# cap_surface_scaly - gill_color_yellow: p-value = 0.008768411956412769
# cap_surface_scaly - stalk_shape_tapering: p-value = 3.4133040075291024e-07
# cap_surface_scaly - stalk_surface_above_ring_scaly: p-value = 0.013526880971807544
# cap_surface_scaly - stalk_surface_above_ring_silky: p-value = 4.142424055643447e-20
# cap_surface_scaly - stalk_surface_above_ring_smooth: p-value = 0.4322894707366399
# cap_surface_scaly - stalk_surface_belows_ring_k: p-value = 1.096947935789397e-15
# cap_surface_scaly - stalk_surface_belows_ring_s: p-value = 4.392979964365639e-09
# cap_surface_scaly - stalk_surface_belows_ring_y: p-value = 1.3881342800865233e-72
# cap_surface_scaly - stalk_color_above_ring_brown: p-value = 9.551122562272962e-06
# cap_surface_scaly - stalk_color_above_ring_buff: p-value = 1.418401215144442e-05
# cap_surface_scaly - stalk_color_above_ring_cinnamon: p-value = 5.810286527775586e-13
# cap_surface_scaly - stalk_color_above_ring_gray: p-value = 3.8780961825007485e-07
# cap_surface_scaly - stalk_color_above_ring_orange: p-value = 6.704571704708764e-30
# cap_surface_scaly - stalk_color_above_ring_pink: p-value = 4.840508194158976e-24
# cap_surface_scaly - stalk_color_above_ring_red: p-value = 0.054661479326910206
# cap_surface_scaly - stalk_color_above_ring_white: p-value = 7.203825934776315e-41
# cap_surface_scaly - stalk_color_below_ring_brown: p-value = 1.942891875038139e-06
# cap_surface_scaly - stalk_color_below_ring_buff: p-value = 1.418401215144442e-05
# cap_surface_scaly - stalk_color_below_ring_gray: p-value = 3.8780961825007485e-07
# cap_surface_scaly - stalk_color_below_ring_orange: p-value = 6.704571704708764e-30
# cap_surface_scaly - stalk_color_below_ring_pink: p-value = 4.840508194158976e-24
# cap_surface_scaly - stalk_color_below_ring_red: p-value = 0.054661479326910206
# cap_surface_scaly - stalk_color_below_ring_white: p-value = 6.766041530398285e-43
# cap_surface_scaly - stalk_color_below_ring_yellow: p-value = 0.013526880971807544
# cap_surface_scaly - veil_type_partial: p-value = 1.0
# cap_surface_scaly - veil_color_brown: p-value = 2.1682786757659232e-15
# cap_surface_scaly - veil_color_white: p-value = 1.7633497462487862e-25
# cap_surface_scaly - veil_color_yellow: p-value = 0.0018729973614414266
# cap_surface_scaly - number_of_rings_o: p-value = 2.1812595513633575e-07
# cap_surface_scaly - number_of_rings_t: p-value = 6.167890166523581e-13
# cap_surface_scaly - ring_type_evanescent: p-value = 1.7905127487400109e-06
# cap_surface_scaly - ring_type_flaring: p-value = 5.527049464158998e-17
# cap_surface_scaly - ring_type_large: p-value = 8.821893668557056e-16
# cap_surface_scaly - ring_type_pendant: p-value = 0.00029016045917134653
# cap_surface_scaly - spore_p_color_black: p-value = 0.14622868782251405
# cap_surface_scaly - spore_p_color_brown: p-value = 0.0005503489902291321
# cap_surface_scaly - spore_p_color_chocolate: p-value = 0.013217299712588764
# cap_surface_scaly - spore_p_color_green: p-value = 0.10280122238130295
# cap_surface_scaly - spore_p_color_orange: p-value = 3.4346062153855655e-08
# cap_surface_scaly - spore_p_color_purple: p-value = 3.4346062153855655e-08
# cap_surface_scaly - spore_p_color_white: p-value = 4.491940529971494e-09
# cap_surface_scaly - spore_p_color_yellow: p-value = 3.4346062153855655e-08
# cap_surface_scaly - pop_clustered: p-value = 0.38159538542550153
# cap_surface_scaly - pop_numerous: p-value = 0.0010783979851936216
# cap_surface_scaly - pop_scattered: p-value = 1.0980760138396429e-39
# cap_surface_scaly - pop_several: p-value = 6.602315232392081e-16
# cap_surface_scaly - pop_solitary: p-value = 7.645017440264967e-31
# cap_surface_scaly - habitat_grasses: p-value = 1.9083778966853693e-66
# cap_surface_scaly - habitat_leaves: p-value = 0.5637366326782378
# cap_surface_scaly - habitat_meadows: p-value = 0.00043616777281816564
# cap_surface_scaly - habitat_paths: p-value = 3.127129626464918e-26
# cap_surface_scaly - habitat_urban: p-value = 2.678949959207115e-19
# cap_surface_scaly - habitat_woods: p-value = 2.0066405828098633e-23
# cap_surface_smooth - cap_color_brown: p-value = 1.6281030451749776e-12
# cap_surface_smooth - cap_color_buff: p-value = 8.3908788830549e-40
# cap_surface_smooth - cap_color_cinnamon: p-value = 0.002353413156575075
# cap_surface_smooth - cap_color_gray: p-value = 6.200874079164959e-45
# cap_surface_smooth - cap_color_green: p-value = 0.014551331597505589
# cap_surface_smooth - cap_color_pink: p-value = 2.106352386143504e-06
# cap_surface_smooth - cap_color_red: p-value = 0.3418874172923321
# cap_surface_smooth - cap_color_white: p-value = 6.530400547147221e-60
# cap_surface_smooth - cap_color_yellow: p-value = 6.85752708596137e-39
# cap_surface_smooth - has_bruises_False: p-value = 6.047740543669064e-21
# cap_surface_smooth - odor_almond: p-value = 0.004618329462606489
# cap_surface_smooth - odor_anise: p-value = 0.004618329462606489
# cap_surface_smooth - odor_creosote: p-value = 3.400836634788795e-08
# cap_surface_smooth - odor_fishy: p-value = 4.4555638698790464e-23
# cap_surface_smooth - odor_foul: p-value = 2.4779123689964206e-08
# cap_surface_smooth - odor_none: p-value = 2.191197991474933e-29
# cap_surface_smooth - odor_pungent: p-value = 1.3452936468902955e-10
# cap_surface_smooth - odor_spicy: p-value = 4.4555638698790464e-23
# cap_surface_smooth - gill_attachment_free: p-value = 1.5172813462053683e-79
# cap_surface_smooth - gill_spacing_close: p-value = 1.3206577786576897e-42
# cap_surface_smooth - gill_size_broad: p-value = 3.236638114412277e-71
# cap_surface_smooth - gill_color_black: p-value = 4.966613352945152e-12
# cap_surface_smooth - gill_color_brown: p-value = 0.017874798523464484
# cap_surface_smooth - gill_color_buff: p-value = 8.177707014325898e-78
# cap_surface_smooth - gill_color_chocolate: p-value = 0.0016077819999507676
# cap_surface_smooth - gill_color_gray: p-value = 3.8014180986794403e-13
# cap_surface_smooth - gill_color_green: p-value = 0.08212731088627416
# cap_surface_smooth - gill_color_pink: p-value = 3.5758481996304686e-22
# cap_surface_smooth - gill_color_purple: p-value = 6.25703485461115e-39
# cap_surface_smooth - gill_color_red: p-value = 0.0001312226082960013
# cap_surface_smooth - gill_color_white: p-value = 0.01123385686269569
# cap_surface_smooth - gill_color_yellow: p-value = 1.7752764758252516e-17
# cap_surface_smooth - stalk_shape_tapering: p-value = 1.1332022206491522e-10
# cap_surface_smooth - stalk_surface_above_ring_scaly: p-value = 1.0
# cap_surface_smooth - stalk_surface_above_ring_silky: p-value = 5.51480703125976e-37
# cap_surface_smooth - stalk_surface_above_ring_smooth: p-value = 8.639113140337967e-05
# cap_surface_smooth - stalk_surface_belows_ring_k: p-value = 1.5749127311022294e-31
# cap_surface_smooth - stalk_surface_belows_ring_s: p-value = 4.009835492291912e-14
# cap_surface_smooth - stalk_surface_belows_ring_y: p-value = 7.191088254259023e-26
# cap_surface_smooth - stalk_color_above_ring_brown: p-value = 1.053345676790237e-43
# cap_surface_smooth - stalk_color_above_ring_buff: p-value = 3.9256562567115576e-47
# cap_surface_smooth - stalk_color_above_ring_cinnamon: p-value = 9.84488782491612e-05
# cap_surface_smooth - stalk_color_above_ring_gray: p-value = 1.6472363640626923e-63
# cap_surface_smooth - stalk_color_above_ring_orange: p-value = 1.8671629113088577e-94
# cap_surface_smooth - stalk_color_above_ring_pink: p-value = 6.817413112714342e-19
# cap_surface_smooth - stalk_color_above_ring_red: p-value = 0.0001312226082960013
# cap_surface_smooth - stalk_color_above_ring_white: p-value = 2.8532439534425573e-113
# cap_surface_smooth - stalk_color_below_ring_brown: p-value = 7.089728578324163e-51
# cap_surface_smooth - stalk_color_below_ring_buff: p-value = 3.9256562567115576e-47
# cap_surface_smooth - stalk_color_below_ring_gray: p-value = 1.6472363640626923e-63
# cap_surface_smooth - stalk_color_below_ring_orange: p-value = 1.8671629113088577e-94
# cap_surface_smooth - stalk_color_below_ring_pink: p-value = 6.817413112714342e-19
# cap_surface_smooth - stalk_color_below_ring_red: p-value = 0.0001312226082960013
# cap_surface_smooth - stalk_color_below_ring_white: p-value = 4.776754606390877e-125
# cap_surface_smooth - stalk_color_below_ring_yellow: p-value = 0.0019090834476119777
# cap_surface_smooth - veil_type_partial: p-value = 1.0
# cap_surface_smooth - veil_color_brown: p-value = 3.0328761776496707e-47
# cap_surface_smooth - veil_color_white: p-value = 1.8415375532871524e-87
# cap_surface_smooth - veil_color_yellow: p-value = 0.12443375257747813
# cap_surface_smooth - number_of_rings_o: p-value = 9.492763352447675e-19
# cap_surface_smooth - number_of_rings_t: p-value = 4.7305651755217565e-24
# ...
# ring_type_evanescent - habitat_leaves: p-value = 4.406257896729189e-158
# ring_type_evanescent - habitat_meadows: p-value = 1.010431628465773e-35
# ring_type_evanescent - habitat_paths: p-value = 2.188080444398647e-35
# ring_type_evanescent - habitat_urban: p-value = 4.451229019990711e-45
# ring_type_evanescent - habitat_woods: p-value = 1.8941676499990153e-111
# ring_type_flaring - ring_type_large: p-value = 0.004659510797042021
# ring_type_flaring - ring_type_pendant: p-value = 3.032748842093068e-11
# ring_type_flaring - spore_p_color_black: p-value = 0.00028292537304846794
# ring_type_flaring - spore_p_color_brown: p-value = 0.00016994555665425073
# ring_type_flaring - spore_p_color_chocolate: p-value = 1.3649350640775861e-42
# ring_type_flaring - spore_p_color_green: p-value = 1.0
# ring_type_flaring - spore_p_color_orange: p-value = 1.0
# ring_type_flaring - spore_p_color_purple: p-value = 1.0
# ring_type_flaring - spore_p_color_white: p-value = 1.5277855623167064e-05
# ring_type_flaring - spore_p_color_yellow: p-value = 1.0
# ring_type_flaring - pop_clustered: p-value = 0.27536111851515477
# ring_type_flaring - pop_numerous: p-value = 0.2124847785119635
# ring_type_flaring - pop_scattered: p-value = 0.00578656617131247
# ring_type_flaring - pop_several: p-value = 1.0
# ring_type_flaring - pop_solitary: p-value = 2.022614235572657e-06
# ring_type_flaring - habitat_grasses: p-value = 6.284339600177667e-05
# ring_type_flaring - habitat_leaves: p-value = 0.03499305352165279
# ring_type_flaring - habitat_meadows: p-value = 0.34065327249786514
# ring_type_flaring - habitat_paths: p-value = 0.009186028427530144
# ring_type_flaring - habitat_urban: p-value = 0.2438016057109474
# ring_type_flaring - habitat_woods: p-value = 8.866702306698398e-18
# ring_type_large - ring_type_pendant: p-value = 0.0
# ring_type_large - spore_p_color_black: p-value = 4.4275761656209454e-102
# ring_type_large - spore_p_color_brown: p-value = 7.1132430560646525e-109
# ring_type_large - spore_p_color_chocolate: p-value = 0.0
# ring_type_large - spore_p_color_green: p-value = 0.0003828756812178084
# ring_type_large - spore_p_color_orange: p-value = 0.004659510797042021
# ring_type_large - spore_p_color_purple: p-value = 0.004659510797042021
# ring_type_large - spore_p_color_white: p-value = 2.9131814178671944e-141
# ring_type_large - spore_p_color_yellow: p-value = 0.004659510797042021
# ring_type_large - pop_clustered: p-value = 4.249279683985628e-16
# ring_type_large - pop_numerous: p-value = 7.574469424899406e-19
# ring_type_large - pop_scattered: p-value = 1.6193956627955907e-62
# ring_type_large - pop_several: p-value = 0.8552832669484915
# ring_type_large - pop_solitary: p-value = 2.850447008063465e-170
# ring_type_large - habitat_grasses: p-value = 1.0386353556376245e-09
# ring_type_large - habitat_leaves: p-value = 7.268337946896136e-40
# ring_type_large - habitat_meadows: p-value = 6.341789930546296e-14
# ring_type_large - habitat_paths: p-value = 2.533385358244826e-104
# ring_type_large - habitat_urban: p-value = 2.238701973844148e-17
# ring_type_large - habitat_woods: p-value = 1.461439204501822e-05
# ring_type_pendant - spore_p_color_black: p-value = 1.7719543577412343e-200
# ring_type_pendant - spore_p_color_brown: p-value = 5.424228749511514e-228
# ring_type_pendant - spore_p_color_chocolate: p-value = 1.1655954029183667e-174
# ring_type_pendant - spore_p_color_green: p-value = 7.678529083236578e-18
# ring_type_pendant - spore_p_color_orange: p-value = 3.2454230004831064e-12
# ring_type_pendant - spore_p_color_purple: p-value = 3.2454230004831064e-12
# ring_type_pendant - spore_p_color_white: p-value = 0.0
# ring_type_pendant - spore_p_color_yellow: p-value = 3.2454230004831064e-12
# ring_type_pendant - pop_clustered: p-value = 8.861589043365235e-12
# ring_type_pendant - pop_numerous: p-value = 2.2991780438556182e-97
# ring_type_pendant - pop_scattered: p-value = 4.475442316151081e-55
# ring_type_pendant - pop_several: p-value = 5.453342328590475e-75
# ring_type_pendant - pop_solitary: p-value = 1.8611032020380836e-28
# ring_type_pendant - habitat_grasses: p-value = 4.077279192539428e-07
# ring_type_pendant - habitat_leaves: p-value = 2.5074599540925353e-51
# ring_type_pendant - habitat_meadows: p-value = 1.677116970297382e-70
# ring_type_pendant - habitat_paths: p-value = 6.576920402215868e-160
# ring_type_pendant - habitat_urban: p-value = 2.4925125017994568e-89
# ring_type_pendant - habitat_woods: p-value = 1.3552050497519366e-108
# spore_p_color_black - spore_p_color_brown: p-value = 9.213727570496643e-171
# spore_p_color_black - spore_p_color_chocolate: p-value = 1.1894143553061695e-134
# spore_p_color_black - spore_p_color_green: p-value = 6.088971155744038e-06
# spore_p_color_black - spore_p_color_orange: p-value = 0.00028292537304846794
# spore_p_color_black - spore_p_color_purple: p-value = 0.00028292537304846794
# spore_p_color_black - spore_p_color_white: p-value = 7.816691655689336e-222
# spore_p_color_black - spore_p_color_yellow: p-value = 0.00028292537304846794
# spore_p_color_black - pop_clustered: p-value = 1.285156909047077e-24
# spore_p_color_black - pop_numerous: p-value = 1.6927811034131515e-05
# spore_p_color_black - pop_scattered: p-value = 1.1229675424643547e-44
# spore_p_color_black - pop_several: p-value = 2.632626030657676e-81
# spore_p_color_black - pop_solitary: p-value = 1.894824360126633e-12
# spore_p_color_black - habitat_grasses: p-value = 1.6026309333602396e-14
# spore_p_color_black - habitat_leaves: p-value = 5.316940188008561e-62
# spore_p_color_black - habitat_meadows: p-value = 1.5609815600725513e-17
# spore_p_color_black - habitat_paths: p-value = 1.0989535605302594e-59
# spore_p_color_black - habitat_urban: p-value = 0.0007170400246965529
# spore_p_color_black - habitat_woods: p-value = 9.762543157962329e-37
# spore_p_color_brown - spore_p_color_chocolate: p-value = 1.202729512469471e-143
# spore_p_color_brown - spore_p_color_green: p-value = 2.8559809019758594e-06
# spore_p_color_brown - spore_p_color_orange: p-value = 0.00016994555665425073
# spore_p_color_brown - spore_p_color_purple: p-value = 0.00016994555665425073
# spore_p_color_brown - spore_p_color_white: p-value = 1.0061187044065085e-236
# spore_p_color_brown - spore_p_color_yellow: p-value = 0.00016994555665425073
# spore_p_color_brown - pop_clustered: p-value = 7.283464293660317e-14
# spore_p_color_brown - pop_numerous: p-value = 0.0002496593666884478
# spore_p_color_brown - pop_scattered: p-value = 4.343715890056147e-37
# spore_p_color_brown - pop_several: p-value = 1.1124786954473063e-68
# spore_p_color_brown - pop_solitary: p-value = 1.731295244338429e-08
# spore_p_color_brown - habitat_grasses: p-value = 1.3852707864463183e-09
# spore_p_color_brown - habitat_leaves: p-value = 4.7716956291093114e-39
# spore_p_color_brown - habitat_meadows: p-value = 2.865650021964563e-15
# spore_p_color_brown - habitat_paths: p-value = 5.7474195181130435e-65
# spore_p_color_brown - habitat_urban: p-value = 0.005376556077748218
# spore_p_color_brown - habitat_woods: p-value = 9.661410871750011e-39
# spore_p_color_chocolate - spore_p_color_green: p-value = 3.697046076951977e-05
# spore_p_color_chocolate - spore_p_color_orange: p-value = 0.000955394675351629
# spore_p_color_chocolate - spore_p_color_purple: p-value = 0.000955394675351629
# spore_p_color_chocolate - spore_p_color_white: p-value = 1.5723354752319916e-186
# spore_p_color_chocolate - spore_p_color_yellow: p-value = 0.000955394675351629
# spore_p_color_chocolate - pop_clustered: p-value = 6.872987193436099e-21
# spore_p_color_chocolate - pop_numerous: p-value = 1.6122584014942306e-24
# spore_p_color_chocolate - pop_scattered: p-value = 3.4617451767916603e-16
# spore_p_color_chocolate - pop_several: p-value = 0.8281527775819388
# spore_p_color_chocolate - pop_solitary: p-value = 1.341902005096538e-109
# spore_p_color_chocolate - habitat_grasses: p-value = 1.5471392948569045e-19
# spore_p_color_chocolate - habitat_leaves: p-value = 2.635772472049378e-52
# spore_p_color_chocolate - habitat_meadows: p-value = 5.081167278061069e-18
# spore_p_color_chocolate - habitat_paths: p-value = 5.17889246483228e-58
# spore_p_color_chocolate - habitat_urban: p-value = 1.965107063717814e-20
# spore_p_color_chocolate - habitat_woods: p-value = 5.960461023919332e-18
# spore_p_color_green - spore_p_color_orange: p-value = 1.0
# spore_p_color_green - spore_p_color_purple: p-value = 1.0
# spore_p_color_green - spore_p_color_white: p-value = 7.898400731776849e-08
# spore_p_color_green - spore_p_color_yellow: p-value = 1.0
# spore_p_color_green - pop_clustered: p-value = 0.1373512214175833
# spore_p_color_green - pop_numerous: p-value = 0.09570937571371005
# spore_p_color_green - pop_scattered: p-value = 0.0005263851411783394
# spore_p_color_green - pop_several: p-value = 2.887120456580609e-17
# spore_p_color_green - pop_solitary: p-value = 2.0539670180877703e-05
# spore_p_color_green - habitat_grasses: p-value = 9.915307498146433e-06
# spore_p_color_green - habitat_leaves: p-value = 0.0072800527118843834
# spore_p_color_green - habitat_meadows: p-value = 2.867973109760059e-97
# spore_p_color_green - habitat_paths: p-value = 0.0010367571777047623
# spore_p_color_green - habitat_urban: p-value = 0.11596886012712118
# spore_p_color_green - habitat_woods: p-value = 2.781889797218996e-11
# spore_p_color_orange - spore_p_color_purple: p-value = 1.0
# spore_p_color_orange - spore_p_color_white: p-value = 1.5277855623167064e-05
# spore_p_color_orange - spore_p_color_yellow: p-value = 1.0
# spore_p_color_orange - pop_clustered: p-value = 1.962644457730279e-54
# spore_p_color_orange - pop_numerous: p-value = 0.2124847785119635
# spore_p_color_orange - pop_scattered: p-value = 0.00578656617131247
# spore_p_color_orange - pop_several: p-value = 1.0
# spore_p_color_orange - pop_solitary: p-value = 0.0006423316480845591
# spore_p_color_orange - habitat_grasses: p-value = 6.284339600177667e-05
# spore_p_color_orange - habitat_leaves: p-value = 6.57825485482845e-92
# spore_p_color_orange - habitat_meadows: p-value = 0.34065327249786514
# spore_p_color_orange - habitat_paths: p-value = 0.009186028427530144
# spore_p_color_orange - habitat_urban: p-value = 0.2438016057109474
# spore_p_color_orange - habitat_woods: p-value = 7.516652720125908e-08
# spore_p_color_purple - spore_p_color_white: p-value = 1.5277855623167064e-05
# spore_p_color_purple - spore_p_color_yellow: p-value = 1.0
# spore_p_color_purple - pop_clustered: p-value = 0.27536111851515477
# spore_p_color_purple - pop_numerous: p-value = 0.2124847785119635
# spore_p_color_purple - pop_scattered: p-value = 0.00578656617131247
# spore_p_color_purple - pop_several: p-value = 7.82418714284566e-12
# spore_p_color_purple - pop_solitary: p-value = 0.0006423316480845591
# spore_p_color_purple - habitat_grasses: p-value = 6.284339600177667e-05
# spore_p_color_purple - habitat_leaves: p-value = 0.03499305352165279
# spore_p_color_purple - habitat_meadows: p-value = 0.34065327249786514
# spore_p_color_purple - habitat_paths: p-value = 0.009186028427530144
# spore_p_color_purple - habitat_urban: p-value = 0.2438016057109474
# spore_p_color_purple - habitat_woods: p-value = 8.866702306698398e-18
# spore_p_color_white - spore_p_color_yellow: p-value = 1.5277855623167064e-05
# spore_p_color_white - pop_clustered: p-value = 2.9329918245406143e-68
# spore_p_color_white - pop_numerous: p-value = 0.0035249085041881303
# spore_p_color_white - pop_scattered: p-value = 5.693623515401433e-51
# spore_p_color_white - pop_several: p-value = 1.1133250273609929e-210
# spore_p_color_white - pop_solitary: p-value = 7.429890102451132e-174
# spore_p_color_white - habitat_grasses: p-value = 5.861700874430565e-80
# spore_p_color_white - habitat_leaves: p-value = 7.424570814633092e-221
# spore_p_color_white - habitat_meadows: p-value = 6.125564910453048e-29
# spore_p_color_white - habitat_paths: p-value = 4.1072283455466e-85
# spore_p_color_white - habitat_urban: p-value = 1.8768773838196462e-36
# spore_p_color_white - habitat_woods: p-value = 2.354027946753531e-42
# spore_p_color_yellow - pop_clustered: p-value = 1.962644457730279e-54
# spore_p_color_yellow - pop_numerous: p-value = 0.2124847785119635
# spore_p_color_yellow - pop_scattered: p-value = 0.00578656617131247
# spore_p_color_yellow - pop_several: p-value = 1.0
# spore_p_color_yellow - pop_solitary: p-value = 0.0006423316480845591
# spore_p_color_yellow - habitat_grasses: p-value = 6.284339600177667e-05
# spore_p_color_yellow - habitat_leaves: p-value = 6.57825485482845e-92
# spore_p_color_yellow - habitat_meadows: p-value = 0.34065327249786514
# spore_p_color_yellow - habitat_paths: p-value = 0.009186028427530144
# spore_p_color_yellow - habitat_urban: p-value = 0.2438016057109474
# spore_p_color_yellow - habitat_woods: p-value = 7.516652720125908e-08
# pop_clustered - pop_numerous: p-value = 3.199933530218651e-05
# pop_clustered - pop_scattered: p-value = 1.8879255994333134e-15
# pop_clustered - pop_several: p-value = 7.157074872736309e-78
# pop_clustered - pop_solitary: p-value = 4.214061220750147e-22
# pop_clustered - habitat_grasses: p-value = 2.8770123247286313e-29
# pop_clustered - habitat_leaves: p-value = 1.3108574334904373e-44
# pop_clustered - habitat_meadows: p-value = 0.00048578774626618476
# pop_clustered - habitat_paths: p-value = 4.4690602724554746e-14
# pop_clustered - habitat_urban: p-value = 7.186087601606658e-05
# pop_clustered - habitat_woods: p-value = 2.4257899676068816e-27
# pop_numerous - pop_scattered: p-value = 4.4240798757088684e-18
# pop_numerous - pop_several: p-value = 4.713392349448193e-92
# pop_numerous - pop_solitary: p-value = 5.911431820400007e-26
# pop_numerous - habitat_grasses: p-value = 9.389575496580661e-83
# pop_numerous - habitat_leaves: p-value = 7.710739092612822e-12
# pop_numerous - habitat_meadows: p-value = 3.480918259126665e-213
# pop_numerous - habitat_paths: p-value = 1.870076846399584e-16
# pop_numerous - habitat_urban: p-value = 1.3955404841793836e-05
# pop_numerous - habitat_woods: p-value = 1.8434104177876773e-59
# pop_scattered - pop_several: p-value = 0.0
# pop_scattered - pop_solitary: p-value = 2.749517519268377e-87
# pop_scattered - habitat_grasses: p-value = 8.693360190835256e-277
# pop_scattered - habitat_leaves: p-value = 3.4743267384230273e-38
# pop_scattered - habitat_meadows: p-value = 1.7532200142697457e-42
# pop_scattered - habitat_paths: p-value = 2.1772353077983952e-29
# pop_scattered - habitat_urban: p-value = 1.5398917583364424e-31
# pop_scattered - habitat_woods: p-value = 5.333940987917099e-132
# pop_several - pop_solitary: p-value = 0.0
# pop_several - habitat_grasses: p-value = 2.5567141797350854e-256
# pop_several - habitat_leaves: p-value = 6.5531137948756114e-111
# pop_several - habitat_meadows: p-value = 2.0988283394113042e-38
# pop_several - habitat_paths: p-value = 2.560052420035615e-52
# pop_several - habitat_urban: p-value = 0.9577446802183185
# pop_several - habitat_woods: p-value = 1.7368101879497877e-53
# pop_solitary - habitat_grasses: p-value = 3.819051747066521e-31
# pop_solitary - habitat_leaves: p-value = 1.8580866675722795e-55
# pop_solitary - habitat_meadows: p-value = 4.674127268564819e-19
# pop_solitary - habitat_paths: p-value = 0.00028277171370439476
# pop_solitary - habitat_urban: p-value = 0.00014456536224451833
# pop_solitary - habitat_woods: p-value = 3.463536721921788e-138
# habitat_grasses - habitat_leaves: p-value = 4.179489731162476e-74
# habitat_grasses - habitat_meadows: p-value = 3.523651969333226e-25
# habitat_grasses - habitat_paths: p-value = 9.559362939091013e-106
# habitat_grasses - habitat_urban: p-value = 1.1301230321057832e-31
# habitat_grasses - habitat_woods: p-value = 0.0
# habitat_leaves - habitat_meadows: p-value = 7.453659083834393e-09
# habitat_leaves - habitat_paths: p-value = 1.264580553127677e-34
# habitat_leaves - habitat_urban: p-value = 5.998715685361715e-11
# habitat_leaves - habitat_woods: p-value = 3.760574818212863e-129
# habitat_meadows - habitat_paths: p-value = 3.40166539801727e-12
# habitat_meadows - habitat_urban: p-value = 0.00026467956605922497
# habitat_meadows - habitat_woods: p-value = 3.297426643846839e-43
# habitat_paths - habitat_urban: p-value = 3.5005532510481254e-15
# habitat_paths - habitat_woods: p-value = 8.642119936919557e-185
# habitat_urban - habitat_woods: p-value = 1.336766996422718e-54

# %%
# Convert the 'P-value' column to numeric type
independent_results_df['P-value'] = independent_results_df['P-value'].astype(float)

# Filter the DataFrame to select only insignificant p-values
insignificant_independent_results = independent_results_df[independent_results_df['P-value'] >= 0.05]

# Display the insignificant results
print("\nInsignificant results (p-value >= 0.05) for independent variables:")
for index, row in insignificant_independent_results.iterrows():
    print(f"{row['Variable 1']} - {row['Variable 2']}: p- value = {row['P-value']}")
# Out:
# Insignificant results (p-value >= 0.05) for independent variables:
# cap_shape_bell - cap_shape_sunken: p- value = 0.3224636193529676
# cap_shape_bell - cap_color_buff: p- value = 0.4640264410557877
# cap_shape_bell - cap_color_cinnamon: p- value = 0.19889831560174787
# cap_shape_bell - cap_color_green: p- value = 0.6701119596589058
# cap_shape_bell - cap_color_pink: p- value = 0.20071310090271016
# cap_shape_bell - odor_none: p- value = 1.0
# cap_shape_bell - stalk_surface_belows_ring_y: p- value = 0.7317023548969708
# cap_shape_bell - stalk_color_above_ring_cinnamon: p- value = 0.27341593668582764
# cap_shape_bell - veil_type_partial: p- value = 1.0
# cap_shape_bell - veil_color_yellow: p- value = 0.10354726081636605
# cap_shape_bell - ring_type_flaring: p- value = 0.17041820795869025
# cap_shape_bell - spore_p_color_purple: p- value = 0.17041820795869025
# cap_shape_bell - habitat_leaves: p- value = 0.40560432433093907
# cap_shape_convex - cap_surface_scaly: p- value = 0.08873847053554582
# cap_shape_convex - cap_color_buff: p- value = 0.0818388369828513
# cap_shape_convex - cap_color_cinnamon: p- value = 0.31584000544455754
# cap_shape_convex - cap_color_green: p- value = 0.8802080639906832
# cap_shape_convex - odor_foul: p- value = 0.5633928850660553
# cap_shape_convex - odor_none: p- value = 0.16056405992109624
# cap_shape_convex - odor_pungent: p- value = 0.11656156430826704
# cap_shape_convex - gill_color_black: p- value = 0.10469074948306421
# cap_shape_convex - gill_color_white: p- value = 0.43497913446544023
# cap_shape_convex - stalk_surface_belows_ring_s: p- value = 0.11852514964511139
# cap_shape_convex - stalk_surface_belows_ring_y: p- value = 0.37497665185844364
# cap_shape_convex - stalk_color_above_ring_brown: p- value = 0.08051098379914252
# cap_shape_convex - stalk_color_above_ring_cinnamon: p- value = 0.21401762884437053
# cap_shape_convex - stalk_color_above_ring_white: p- value = 0.08368551377065488
# cap_shape_convex - stalk_color_below_ring_brown: p- value = 0.40429808262075473
# cap_shape_convex - veil_type_partial: p- value = 1.0
# cap_shape_convex - ring_type_flaring: p- value = 0.5805818255064321
# cap_shape_convex - spore_p_color_purple: p- value = 0.5805818255064321
# cap_shape_convex - pop_numerous: p- value = 0.7175240687277977
# cap_shape_convex - habitat_meadows: p- value = 0.7276226262684613
# cap_shape_convex - habitat_urban: p- value = 0.8393051243659131
# cap_shape_flat - cap_color_brown: p- value = 0.09131559128634473
# cap_shape_flat - cap_color_buff: p- value = 0.09877278369602557
# cap_shape_flat - cap_color_cinnamon: p- value = 0.8593078022039407
# cap_shape_flat - cap_color_green: p- value = 0.5069369440814537
# cap_shape_flat - cap_color_red: p- value = 0.4275482823439555
# cap_shape_flat - cap_color_yellow: p- value = 0.36658444367932763
# cap_shape_flat - gill_color_brown: p- value = 0.5459283666174377
# cap_shape_flat - gill_color_green: p- value = 0.3585985221987086
# cap_shape_flat - gill_color_red: p- value = 0.3172586421868407
# cap_shape_flat - gill_color_white: p- value = 0.22652337925899957
# cap_shape_flat - stalk_surface_above_ring_scaly: p- value = 0.2381836327843776
# cap_shape_flat - stalk_surface_above_ring_silky: p- value = 0.07798330713498038
# cap_shape_flat - stalk_surface_belows_ring_y: p- value = 0.1608505304999529
# cap_shape_flat - stalk_color_above_ring_cinnamon: p- value = 0.6149352792096756
# cap_shape_flat - stalk_color_above_ring_red: p- value = 0.3172586421868407
# cap_shape_flat - stalk_color_below_ring_red: p- value = 0.3172586421868407
# cap_shape_flat - stalk_color_below_ring_yellow: p- value = 0.2381836327843776
# cap_shape_flat - veil_type_partial: p- value = 1.0
# cap_shape_flat - veil_color_yellow: p- value = 0.6611202856330154
# cap_shape_flat - ring_type_evanescent: p- value = 0.20247480487608924
# cap_shape_flat - ring_type_flaring: p- value = 0.14740124431694884
# cap_shape_flat - spore_p_color_black: p- value = 0.17321614579393824
# cap_shape_flat - spore_p_color_brown: p- value = 0.20323972731684872
# cap_shape_flat - spore_p_color_green: p- value = 0.06609915677409374
# cap_shape_flat - spore_p_color_orange: p- value = 0.06889035415459993
# cap_shape_flat - spore_p_color_purple: p- value = 0.14740124431694884
# cap_shape_flat - spore_p_color_yellow: p- value = 0.06889035415459993
# cap_shape_flat - habitat_grasses: p- value = 0.11071825591272294
# cap_shape_flat - habitat_paths: p- value = 0.05233235765381928
# cap_shape_knobbed - cap_shape_sunken: p- value = 0.10594166526852897
# cap_shape_knobbed - cap_surface_scaly: p- value = 0.1808625887768743
# cap_shape_knobbed - cap_color_buff: p- value = 0.8725369498686129
# cap_shape_knobbed - cap_color_green: p- value = 0.34964922497964945
# cap_shape_knobbed - cap_color_pink: p- value = 0.8189773586233878
# cap_shape_knobbed - gill_spacing_close: p- value = 0.08616744773018085
# cap_shape_knobbed - gill_color_green: p- value = 0.18852479741637243
# cap_shape_knobbed - stalk_surface_belows_ring_y: p- value = 0.6253900071274376
# cap_shape_knobbed - stalk_color_above_ring_white: p- value = 0.3579705177491157
# cap_shape_knobbed - veil_type_partial: p- value = 1.0
# cap_shape_knobbed - veil_color_yellow: p- value = 0.42344143323946926
# cap_shape_knobbed - pop_numerous: p- value = 0.25387153337791835
# cap_shape_sunken - cap_color_buff: p- value = 0.8404525523952389
# cap_shape_sunken - cap_color_cinnamon: p- value = 1.0
# cap_shape_sunken - cap_color_green: p- value = 1.0
# cap_shape_sunken - cap_color_pink: p- value = 0.9281141809698367
# cap_shape_sunken - cap_color_white: p- value = 0.05656274443981908
# cap_shape_sunken - cap_color_yellow: p- value = 0.051388109077803085
# cap_shape_sunken - odor_almond: p- value = 0.37857359328469187
# cap_shape_sunken - odor_anise: p- value = 0.37857359328469187
# cap_shape_sunken - odor_creosote: p- value = 0.765071547607308
# cap_shape_sunken - odor_fishy: p- value = 0.2221967881770739
# cap_shape_sunken - odor_pungent: p- value = 0.6062440892496221
# cap_shape_sunken - odor_spicy: p- value = 0.2221967881770739
# cap_shape_sunken - gill_attachment_free: p- value = 0.7149630167458985
# cap_shape_sunken - gill_color_brown: p- value = 0.07477919218925327
# cap_shape_sunken - gill_color_chocolate: p- value = 0.1403918255311894
# cap_shape_sunken - gill_color_green: p- value = 1.0
# cap_shape_sunken - gill_color_pink: p- value = 0.4577927622037251
# cap_shape_sunken - gill_color_purple: p- value = 0.2856023247034808
# cap_shape_sunken - gill_color_red: p- value = 1.0
# cap_shape_sunken - gill_color_yellow: p- value = 1.0
# cap_shape_sunken - stalk_surface_above_ring_scaly: p- value = 1.0
# cap_shape_sunken - stalk_surface_belows_ring_y: p- value = 0.5507707420632765
# cap_shape_sunken - stalk_color_above_ring_brown: p- value = 0.32643000346311457
# cap_shape_sunken - stalk_color_above_ring_buff: p- value = 0.3428505371457298
# cap_shape_sunken - stalk_color_above_ring_cinnamon: p- value = 1.0
# cap_shape_sunken - stalk_color_above_ring_gray: p- value = 0.2221967881770739
# cap_shape_sunken - stalk_color_above_ring_orange: p- value = 0.765071547607308
# cap_shape_sunken - stalk_color_above_ring_red: p- value = 1.0
# cap_shape_sunken - stalk_color_below_ring_brown: p- value = 0.26892081634535525
# cap_shape_sunken - stalk_color_below_ring_buff: p- value = 0.3428505371457298
# cap_shape_sunken - stalk_color_below_ring_gray: p- value = 0.2221967881770739
# cap_shape_sunken - stalk_color_below_ring_orange: p- value = 0.765071547607308
# cap_shape_sunken - stalk_color_below_ring_red: p- value = 1.0
# cap_shape_sunken - stalk_color_below_ring_yellow: p- value = 1.0
# cap_shape_sunken - veil_type_partial: p- value = 1.0
# cap_shape_sunken - veil_color_brown: p- value = 1.0
# cap_shape_sunken - veil_color_white: p- value = 0.7421880899975016
# cap_shape_sunken - veil_color_yellow: p- value = 1.0
# cap_shape_sunken - number_of_rings_o: p- value = 0.18610714871447082
# cap_shape_sunken - number_of_rings_t: p- value = 0.20695803132554952
# cap_shape_sunken - ring_type_flaring: p- value = 1.0
# cap_shape_sunken - spore_p_color_green: p- value = 1.0
# cap_shape_sunken - spore_p_color_orange: p- value = 1.0
# cap_shape_sunken - spore_p_color_purple: p- value = 1.0
# cap_shape_sunken - spore_p_color_yellow: p- value = 1.0
# cap_shape_sunken - pop_clustered: p- value = 0.4578862355085421
# cap_shape_sunken - pop_numerous: p- value = 0.37857359328469187
# cap_shape_sunken - pop_several: p- value = 1.0
# cap_shape_sunken - habitat_leaves: p- value = 0.1047043840622905
# cap_shape_sunken - habitat_meadows: p- value = 0.5361397789893977
# cap_surface_fibrous - cap_color_cinnamon: p- value = 0.9825808615053487
# cap_surface_fibrous - cap_color_pink: p- value = 0.10847129820777511
# cap_surface_fibrous - odor_foul: p- value = 0.08825778654917887
# cap_surface_fibrous - gill_color_black: p- value = 0.7370068951653939
# cap_surface_fibrous - gill_color_white: p- value = 0.11537292304247582
# cap_surface_fibrous - stalk_shape_tapering: p- value = 0.3355911516373646
# cap_surface_fibrous - stalk_surface_belows_ring_s: p- value = 0.14335700358827935
# cap_surface_fibrous - stalk_color_above_ring_pink: p- value = 0.0792008254069019
# cap_surface_fibrous - stalk_color_below_ring_pink: p- value = 0.0792008254069019
# cap_surface_fibrous - stalk_color_below_ring_yellow: p- value = 0.7699236331571665
# cap_surface_fibrous - veil_type_partial: p- value = 1.0
# cap_surface_fibrous - veil_color_yellow: p- value = 0.16224631657448935
# cap_surface_fibrous - habitat_urban: p- value = 0.3102322741910722
# cap_surface_scaly - cap_color_brown: p- value = 0.07384406166098663
# cap_surface_scaly - gill_color_gray: p- value = 0.5430294095565196
# cap_surface_scaly - gill_color_green: p- value = 0.4237266791431321
# cap_surface_scaly - gill_color_red: p- value = 0.054661479326910206
# cap_surface_scaly - stalk_surface_above_ring_smooth: p- value = 0.4322894707366399
# cap_surface_scaly - stalk_color_above_ring_red: p- value = 0.054661479326910206
# cap_surface_scaly - stalk_color_below_ring_red: p- value = 0.054661479326910206
# cap_surface_scaly - veil_type_partial: p- value = 1.0
# cap_surface_scaly - spore_p_color_black: p- value = 0.14622868782251405
# cap_surface_scaly - spore_p_color_green: p- value = 0.10280122238130295
# cap_surface_scaly - pop_clustered: p- value = 0.38159538542550153
# cap_surface_scaly - habitat_leaves: p- value = 0.5637366326782378
# cap_surface_smooth - cap_color_red: p- value = 0.3418874172923321
# cap_surface_smooth - gill_color_green: p- value = 0.08212731088627416
# cap_surface_smooth - stalk_surface_above_ring_scaly: p- value = 1.0
# cap_surface_smooth - veil_type_partial: p- value = 1.0
# cap_surface_smooth - veil_color_yellow: p- value = 0.12443375257747813
# cap_surface_smooth - ring_type_pendant: p- value = 0.08595560651822455
# cap_surface_smooth - pop_several: p- value = 0.08178698903432857
# cap_color_brown - gill_color_black: p- value = 0.4831298506305606
# cap_color_brown - gill_color_purple: p- value = 0.5921332272508238
# cap_color_brown - gill_color_red: p- value = 0.5696326609688362
# cap_color_brown - stalk_color_above_ring_cinnamon: p- value = 0.6084164045433836
# cap_color_brown - stalk_color_above_ring_red: p- value = 0.5696326609688362
# cap_color_brown - stalk_color_above_ring_white: p- value = 0.1300744139237864
# cap_color_brown - stalk_color_below_ring_red: p- value = 0.5696326609688362
# cap_color_brown - stalk_color_below_ring_yellow: p- value = 0.7321839112791957
# cap_color_brown - veil_type_partial: p- value = 1.0
# cap_color_brown - veil_color_yellow: p- value = 0.16873324564806627
# cap_color_brown - spore_p_color_black: p- value = 0.13968836549828503
# cap_color_brown - habitat_urban: p- value = 0.34003295879268486
# cap_color_brown - habitat_woods: p- value = 0.4637344380664101
# cap_color_buff - cap_color_cinnamon: p- value = 0.6632672214227692
# cap_color_buff - cap_color_green: p- value = 1.0
# cap_color_buff - cap_color_pink: p- value = 0.14319124439439562
# cap_color_buff - odor_creosote: p- value = 0.07488985008057228
# cap_color_buff - odor_none: p- value = 0.9426760035670786
# cap_color_buff - gill_attachment_free: p- value = 0.0590385892966246
# cap_color_buff - gill_color_gray: p- value = 0.057867039393659836
# cap_color_buff - gill_color_pink: p- value = 0.8964734999254454
# cap_color_buff - gill_color_yellow: p- value = 0.3301132590564006
# cap_color_buff - stalk_shape_tapering: p- value = 0.9737637522865166
# cap_color_buff - stalk_surface_above_ring_scaly: p- value = 1.0
# cap_color_buff - stalk_color_above_ring_cinnamon: p- value = 0.7741586376094052
# cap_color_buff - stalk_color_above_ring_orange: p- value = 0.07488985008057228
# cap_color_buff - stalk_color_below_ring_orange: p- value = 0.07488985008057228
# cap_color_buff - stalk_color_below_ring_yellow: p- value = 1.0
# cap_color_buff - veil_type_partial: p- value = 1.0
# cap_color_buff - veil_color_brown: p- value = 0.28392828716646046
# cap_color_buff - veil_color_white: p- value = 0.06735981876097359
# cap_color_buff - veil_color_yellow: p- value = 1.0
# cap_color_buff - ring_type_evanescent: p- value = 0.14319489895880788
# cap_color_buff - ring_type_flaring: p- value = 0.616287075055018
# cap_color_buff - spore_p_color_orange: p- value = 0.616287075055018
# cap_color_buff - spore_p_color_purple: p- value = 0.616287075055018
# cap_color_buff - spore_p_color_white: p- value = 0.8799473514734658
# cap_color_buff - spore_p_color_yellow: p- value = 0.616287075055018
# cap_color_buff - pop_several: p- value = 0.08503080818225962
# cap_color_cinnamon - cap_color_green: p- value = 1.0
# cap_color_cinnamon - cap_color_pink: p- value = 0.7484591547323974
# cap_color_cinnamon - odor_almond: p- value = 0.24431177200239482
# cap_color_cinnamon - odor_anise: p- value = 0.24431177200239482
# cap_color_cinnamon - odor_creosote: p- value = 0.5910922253786022
# cap_color_cinnamon - odor_fishy: p- value = 0.1228546864243979
# cap_color_cinnamon - odor_pungent: p- value = 0.44302005126907096
# cap_color_cinnamon - odor_spicy: p- value = 0.1228546864243979
# cap_color_cinnamon - gill_color_black: p- value = 0.23665343302929123
# cap_color_cinnamon - gill_color_chocolate: p- value = 0.06738737137283508
# cap_color_cinnamon - gill_color_gray: p- value = 0.06238643462545922
# cap_color_cinnamon - gill_color_green: p- value = 1.0
# cap_color_cinnamon - gill_color_purple: p- value = 0.17009868230419975
# cap_color_cinnamon - gill_color_red: p- value = 0.9777457790471268
# cap_color_cinnamon - stalk_surface_above_ring_scaly: p- value = 1.0
# cap_color_cinnamon - stalk_surface_above_ring_silky: p- value = 0.9081867482204223
# cap_color_cinnamon - stalk_surface_belows_ring_s: p- value = 0.05362900527051009
# cap_color_cinnamon - stalk_color_above_ring_brown: p- value = 0.2020488793721804
# cap_color_cinnamon - stalk_color_above_ring_buff: p- value = 0.21519221096684746
# cap_color_cinnamon - stalk_color_above_ring_gray: p- value = 0.1228546864243979
# cap_color_cinnamon - stalk_color_above_ring_orange: p- value = 0.5910922253786022
# cap_color_cinnamon - stalk_color_above_ring_red: p- value = 0.9777457790471268
# cap_color_cinnamon - stalk_color_below_ring_buff: p- value = 0.21519221096684746
# cap_color_cinnamon - stalk_color_below_ring_gray: p- value = 0.1228546864243979
# cap_color_cinnamon - stalk_color_below_ring_orange: p- value = 0.5910922253786022
# cap_color_cinnamon - stalk_color_below_ring_red: p- value = 0.9777457790471268
# cap_color_cinnamon - stalk_color_below_ring_yellow: p- value = 1.0
# cap_color_cinnamon - veil_type_partial: p- value = 1.0
# cap_color_cinnamon - veil_color_brown: p- value = 0.9777457790471268
# cap_color_cinnamon - veil_color_white: p- value = 0.5694019304473557
# cap_color_cinnamon - veil_color_yellow: p- value = 1.0
# cap_color_cinnamon - ring_type_flaring: p- value = 1.0
# cap_color_cinnamon - spore_p_color_green: p- value = 1.0
# cap_color_cinnamon - spore_p_color_orange: p- value = 1.0
# cap_color_cinnamon - spore_p_color_purple: p- value = 1.0
# cap_color_cinnamon - spore_p_color_yellow: p- value = 1.0
# cap_color_cinnamon - pop_numerous: p- value = 0.24431177200239482
# cap_color_cinnamon - pop_several: p- value = 0.08934366294430693
# cap_color_cinnamon - pop_solitary: p- value = 0.07691272555408007
# cap_color_cinnamon - habitat_meadows: p- value = 0.3798100228230351
# cap_color_cinnamon - habitat_paths: p- value = 0.5709011990550117
# cap_color_cinnamon - habitat_urban: p- value = 0.27776542991543507
# cap_color_cinnamon - habitat_woods: p- value = 0.15803023293312196
# cap_color_gray - cap_color_green: p- value = 0.06180907446516805
# cap_color_gray - gill_color_black: p- value = 0.05352359735366012
# cap_color_gray - gill_color_brown: p- value = 0.9457232632021958
# cap_color_gray - stalk_color_above_ring_pink: p- value = 0.329603328077023
# cap_color_gray - stalk_color_below_ring_pink: p- value = 0.329603328077023
# cap_color_gray - veil_type_partial: p- value = 1.0
# cap_color_gray - veil_color_yellow: p- value = 0.2675556411981401
# cap_color_gray - number_of_rings_o: p- value = 0.46208735140655743
# cap_color_gray - number_of_rings_t: p- value = 0.11371380985957012
# cap_color_gray - ring_type_pendant: p- value = 0.05106941917111342
# cap_color_gray - spore_p_color_brown: p- value = 0.11087647936929061
# cap_color_gray - pop_scattered: p- value = 0.8739093063516079
# cap_color_gray - habitat_urban: p- value = 0.12140086181657242
# cap_color_green - cap_color_pink: p- value = 1.0
# cap_color_green - cap_color_red: p- value = 0.11345222093155005
# cap_color_green - cap_color_white: p- value = 0.2461948063961484
# cap_color_green - cap_color_yellow: p- value = 0.233500250317101
# cap_color_green - odor_almond: p- value = 0.7392400423073215
# cap_color_green - odor_anise: p- value = 0.7392400423073215
# cap_color_green - odor_creosote: p- value = 1.0
# cap_color_green - odor_fishy: p- value = 0.5362029838251459
# cap_color_green - odor_pungent: p- value = 0.9952166482904042
# cap_color_green - odor_spicy: p- value = 0.5362029838251459
# cap_color_green - gill_attachment_free: p- value = 1.0
# cap_color_green - gill_spacing_close: p- value = 0.15643431148938894
# cap_color_green - gill_color_black: p- value = 0.7279871419224769
# cap_color_green - gill_color_brown: p- value = 0.24295913715260817
# cap_color_green - gill_color_buff: p- value = 0.07583181135517947
# cap_color_green - gill_color_chocolate: p- value = 0.07202612979165499
# cap_color_green - gill_color_gray: p- value = 0.3969500907515413
# cap_color_green - gill_color_green: p- value = 1.0
# cap_color_green - gill_color_pink: p- value = 0.7166610225526387
# cap_color_green - gill_color_red: p- value = 1.0
# cap_color_green - gill_color_white: p- value = 0.4246791795424172
# cap_color_green - gill_color_yellow: p- value = 1.0
# cap_color_green - stalk_surface_above_ring_scaly: p- value = 1.0
# cap_color_green - stalk_surface_belows_ring_y: p- value = 0.9355733966426865
# cap_color_green - stalk_color_above_ring_brown: p- value = 0.675111034167874
# cap_color_green - stalk_color_above_ring_buff: p- value = 0.6956143879564933
# cap_color_green - stalk_color_above_ring_cinnamon: p- value = 1.0
# cap_color_green - stalk_color_above_ring_gray: p- value = 0.5362029838251459
# cap_color_green - stalk_color_above_ring_orange: p- value = 1.0
# cap_color_green - stalk_color_above_ring_pink: p- value = 0.05824946135632782
# cap_color_green - stalk_color_above_ring_red: p- value = 1.0
# cap_color_green - stalk_color_below_ring_brown: p- value = 0.6006120177381675
# cap_color_green - stalk_color_below_ring_buff: p- value = 0.6956143879564933
# cap_color_green - stalk_color_below_ring_gray: p- value = 0.5362029838251459
# cap_color_green - stalk_color_below_ring_orange: p- value = 1.0
# cap_color_green - stalk_color_below_ring_pink: p- value = 0.05824946135632782
# cap_color_green - stalk_color_below_ring_red: p- value = 1.0
# cap_color_green - stalk_color_below_ring_yellow: p- value = 1.0
# cap_color_green - veil_type_partial: p- value = 1.0
# cap_color_green - veil_color_brown: p- value = 1.0
# cap_color_green - veil_color_white: p- value = 1.0
# cap_color_green - veil_color_yellow: p- value = 1.0
# cap_color_green - number_of_rings_o: p- value = 0.48323850728934026
# cap_color_green - number_of_rings_t: p- value = 0.5142331856770237
# cap_color_green - ring_type_large: p- value = 0.16071225352157303
# cap_color_green - spore_p_color_black: p- value = 0.05824946135632782
# cap_color_green - spore_p_color_green: p- value = 1.0
# cap_color_green - spore_p_color_orange: p- value = 1.0
# cap_color_green - spore_p_color_purple: p- value = 1.0
# cap_color_green - spore_p_color_yellow: p- value = 1.0
# cap_color_green - pop_clustered: p- value = 0.8321296616165377
# cap_color_green - pop_numerous: p- value = 0.7392400423073215
# cap_color_green - pop_scattered: p- value = 0.17421165005460315
# cap_color_green - pop_several: p- value = 1.0
# cap_color_green - habitat_leaves: p- value = 0.3473319325637789
# cap_color_green - habitat_meadows: p- value = 0.9195968231122602
# cap_color_green - habitat_paths: p- value = 0.20722174465100424
# cap_color_green - habitat_urban: p- value = 0.7867953600179951
# cap_color_pink - odor_pungent: p- value = 0.05197420451555402
# cap_color_pink - gill_attachment_free: p- value = 0.08775081081181595
# cap_color_pink - gill_spacing_close: p- value = 0.05959472708535859
# cap_color_pink - gill_color_brown: p- value = 0.6025321417223588
# cap_color_pink - gill_color_yellow: p- value = 0.40001077845807687
# cap_color_pink - stalk_surface_above_ring_scaly: p- value = 1.0
# cap_color_pink - stalk_color_above_ring_cinnamon: p- value = 0.8612108918745691
# cap_color_pink - stalk_color_above_ring_orange: p- value = 0.10805541037167346
# cap_color_pink - stalk_color_below_ring_orange: p- value = 0.10805541037167346
# cap_color_pink - stalk_color_below_ring_yellow: p- value = 1.0
# cap_color_pink - veil_type_partial: p- value = 1.0
# cap_color_pink - veil_color_brown: p- value = 0.34979921737714215
# cap_color_pink - veil_color_white: p- value = 0.09848060583527231
# cap_color_pink - veil_color_yellow: p- value = 1.0
# cap_color_pink - ring_type_evanescent: p- value = 0.9004913152960009
# cap_color_pink - ring_type_flaring: p- value = 0.7003243492411996
# cap_color_pink - spore_p_color_black: p- value = 0.8917336344254357
# cap_color_pink - spore_p_color_brown: p- value = 0.6399812258956046
# cap_color_pink - spore_p_color_orange: p- value = 0.7003243492411996
# cap_color_pink - spore_p_color_purple: p- value = 0.7003243492411996
# cap_color_pink - spore_p_color_yellow: p- value = 0.7003243492411996
# cap_color_pink - pop_several: p- value = 0.06171558717459263
# cap_color_pink - habitat_woods: p- value = 0.18381731850269722
# cap_color_red - has_bruises_False: p- value = 0.992512244690798
# cap_color_red - odor_none: p- value = 0.12065554819535962
# cap_color_red - gill_color_red: p- value = 0.1264959612812414
# cap_color_red - stalk_surface_above_ring_silky: p- value = 0.727606754854232
# cap_color_red - stalk_surface_belows_ring_k: p- value = 0.699070533246213
# cap_color_red - stalk_color_above_ring_red: p- value = 0.1264959612812414
# cap_color_red - stalk_color_below_ring_red: p- value = 0.1264959612812414
# cap_color_red - veil_type_partial: p- value = 1.0
# cap_color_red - veil_color_yellow: p- value = 0.3730430352227134
# cap_color_red - pop_clustered: p- value = 0.7450792710462726
# cap_color_red - pop_solitary: p- value = 0.052970872317682285
# cap_color_white - odor_none: p- value = 0.8334041327204004
# cap_color_white - gill_color_chocolate: p- value = 0.5017248589314222
# cap_color_white - gill_color_pink: p- value = 0.07872156136642372
# cap_color_white - stalk_surface_above_ring_scaly: p- value = 0.11550347197456005
# cap_color_white - stalk_color_below_ring_yellow: p- value = 0.11550347197456005
# cap_color_white - veil_type_partial: p- value = 1.0
# cap_color_white - veil_color_yellow: p- value = 0.5789596261620605
# cap_color_yellow - gill_color_black: p- value = 0.14696932515210978
# cap_color_yellow - gill_color_green: p- value = 0.10720682452842072
# cap_color_yellow - veil_type_partial: p- value = 1.0
# cap_color_yellow - pop_scattered: p- value = 0.3252496342318713
# has_bruises_False - veil_type_partial: p- value = 1.0
# odor_almond - gill_color_green: p- value = 0.5195246775058994
# odor_almond - gill_color_yellow: p- value = 0.06133089272838691
# odor_almond - stalk_surface_above_ring_scaly: p- value = 0.5195246775058994
# odor_almond - stalk_color_above_ring_cinnamon: p- value = 0.32589148444340044
# odor_almond - stalk_color_below_ring_yellow: p- value = 0.5195246775058994
# odor_almond - veil_type_partial: p- value = 1.0
# odor_almond - veil_color_yellow: p- value = 1.0
# odor_almond - ring_type_flaring: p- value = 0.2124847785119635
# odor_almond - spore_p_color_green: p- value = 0.09570937571371005
# odor_almond - spore_p_color_orange: p- value = 0.2124847785119635
# odor_almond - spore_p_color_yellow: p- value = 0.2124847785119635
# odor_almond - habitat_paths: p- value = 0.2485559440257078
# odor_anise - gill_color_green: p- value = 0.5195246775058994
# odor_anise - gill_color_yellow: p- value = 0.06133089272838691
# odor_anise - stalk_surface_above_ring_scaly: p- value = 0.5195246775058994
# odor_anise - stalk_color_above_ring_cinnamon: p- value = 0.32589148444340044
# odor_anise - stalk_color_below_ring_yellow: p- value = 0.5195246775058994
# odor_anise - veil_type_partial: p- value = 1.0
# odor_anise - veil_color_yellow: p- value = 1.0
# odor_anise - ring_type_flaring: p- value = 0.2124847785119635
# odor_anise - spore_p_color_green: p- value = 0.09570937571371005
# odor_anise - spore_p_color_orange: p- value = 0.2124847785119635
# odor_anise - spore_p_color_yellow: p- value = 0.2124847785119635
# odor_anise - habitat_paths: p- value = 0.2485559440257078
# odor_creosote - gill_color_green: p- value = 0.927933111911829
# odor_creosote - gill_color_red: p- value = 0.23188004230352288
# odor_creosote - gill_color_yellow: p- value = 0.27409662519389466
# odor_creosote - stalk_surface_above_ring_scaly: p- value = 0.927933111911829
# odor_creosote - stalk_color_above_ring_cinnamon: p- value = 0.6996751880620475
# odor_creosote - stalk_color_above_ring_orange: p- value = 0.05221718924747854
# odor_creosote - stalk_color_above_ring_red: p- value = 0.23188004230352288
# odor_creosote - stalk_color_below_ring_orange: p- value = 0.05221718924747854
# odor_creosote - stalk_color_below_ring_red: p- value = 0.23188004230352288
# odor_creosote - stalk_color_below_ring_yellow: p- value = 0.927933111911829
# odor_creosote - veil_type_partial: p- value = 1.0
# odor_creosote - veil_color_brown: p- value = 0.23188004230352288
# odor_creosote - veil_color_yellow: p- value = 1.0
# odor_creosote - ring_type_flaring: p- value = 0.5454443553499428
# odor_creosote - spore_p_color_green: p- value = 0.3490647730828257
# odor_creosote - spore_p_color_orange: p- value = 0.5454443553499428
# odor_creosote - spore_p_color_purple: p- value = 0.5454443553499428
# odor_creosote - spore_p_color_yellow: p- value = 0.5454443553499428
# odor_creosote - pop_several: p- value = 0.9976758513433275
# odor_fishy - gill_color_green: p- value = 0.33852665282583294
# odor_fishy - stalk_surface_above_ring_scaly: p- value = 0.33852665282583294
# odor_fishy - stalk_color_above_ring_cinnamon: p- value = 0.18163043493305414
# odor_fishy - stalk_color_below_ring_white: p- value = 0.052789898438689954
# odor_fishy - stalk_color_below_ring_yellow: p- value = 0.33852665282583294
# odor_fishy - veil_type_partial: p- value = 1.0
# odor_fishy - veil_color_yellow: p- value = 0.9262004350155789
# odor_fishy - ring_type_flaring: p- value = 0.10151660739824817
# odor_fishy - spore_p_color_orange: p- value = 0.10151660739824817
# odor_fishy - spore_p_color_purple: p- value = 0.10151660739824817
# odor_fishy - spore_p_color_yellow: p- value = 0.10151660739824817
# odor_foul - veil_type_partial: p- value = 1.0
# odor_foul - veil_color_yellow: p- value = 0.19268274839642002
# odor_foul - habitat_grasses: p- value = 0.8025089789519952
# odor_none - veil_type_partial: p- value = 1.0
# odor_none - pop_scattered: p- value = 0.4031482180955215
# odor_pungent - gill_color_green: p- value = 0.7642592662944275
# odor_pungent - gill_color_red: p- value = 0.13779990006082563
# odor_pungent - gill_color_yellow: p- value = 0.17024375672579306
# odor_pungent - stalk_surface_above_ring_scaly: p- value = 0.7642592662944275
# odor_pungent - stalk_color_above_ring_cinnamon: p- value = 0.5441136320634636
# odor_pungent - stalk_color_above_ring_red: p- value = 0.13779990006082563
# odor_pungent - stalk_color_below_ring_red: p- value = 0.13779990006082563
# odor_pungent - stalk_color_below_ring_yellow: p- value = 0.7642592662944275
# odor_pungent - veil_type_partial: p- value = 1.0
# odor_pungent - veil_color_brown: p- value = 0.13779990006082563
# odor_pungent - veil_color_yellow: p- value = 1.0
# odor_pungent - ring_type_flaring: p- value = 0.4014251112825047
# odor_pungent - spore_p_color_green: p- value = 0.23068656467916399
# odor_pungent - spore_p_color_orange: p- value = 0.4014251112825047
# odor_pungent - spore_p_color_purple: p- value = 0.4014251112825047
# odor_pungent - spore_p_color_yellow: p- value = 0.4014251112825047
# odor_pungent - pop_several: p- value = 0.9804162727928407
# odor_spicy - gill_color_green: p- value = 0.33852665282583294
# odor_spicy - stalk_surface_above_ring_scaly: p- value = 0.33852665282583294
# odor_spicy - stalk_color_above_ring_cinnamon: p- value = 0.18163043493305414
# odor_spicy - stalk_color_below_ring_white: p- value = 0.052789898438689954
# odor_spicy - stalk_color_below_ring_yellow: p- value = 0.33852665282583294
# odor_spicy - veil_type_partial: p- value = 1.0
# odor_spicy - veil_color_yellow: p- value = 0.9262004350155789
# odor_spicy - ring_type_flaring: p- value = 0.10151660739824817
# odor_spicy - spore_p_color_orange: p- value = 0.10151660739824817
# odor_spicy - spore_p_color_purple: p- value = 0.10151660739824817
# odor_spicy - spore_p_color_yellow: p- value = 0.10151660739824817
# gill_attachment_free - gill_color_green: p- value = 0.8767548092765964
# gill_attachment_free - gill_color_red: p- value = 0.19981998278083143
# gill_attachment_free - stalk_surface_above_ring_scaly: p- value = 0.8767548092765964
# gill_attachment_free - stalk_color_above_ring_red: p- value = 0.19981998278083143
# gill_attachment_free - stalk_color_below_ring_red: p- value = 0.19981998278083143
# gill_attachment_free - stalk_color_below_ring_yellow: p- value = 0.8767548092765964
# gill_attachment_free - veil_type_partial: p- value = 1.0
# gill_attachment_free - veil_color_yellow: p- value = 1.0
# gill_attachment_free - number_of_rings_o: p- value = 0.7826652424626519
# gill_attachment_free - ring_type_flaring: p- value = 0.49917503636962857
# gill_attachment_free - spore_p_color_brown: p- value = 0.6987588300165892
# gill_attachment_free - spore_p_color_green: p- value = 0.30991677251890887
# gill_attachment_free - spore_p_color_purple: p- value = 0.49917503636962857
# gill_attachment_free - pop_several: p- value = 0.26740012585468387
# gill_spacing_close - gill_color_gray: p- value = 0.9216401560201185
# gill_spacing_close - gill_color_green: p- value = 0.06073703252528053
# gill_spacing_close - gill_color_white: p- value = 0.6332564526040879
# gill_spacing_close - veil_type_partial: p- value = 1.0
# gill_size_broad - stalk_surface_above_ring_scaly: p- value = 0.972116015220568
# gill_size_broad - stalk_surface_above_ring_smooth: p- value = 0.4256470873266085
# gill_size_broad - stalk_surface_belows_ring_s: p- value = 0.6491825467624394
# gill_size_broad - veil_type_partial: p- value = 1.0
# gill_size_broad - habitat_woods: p- value = 0.15465141353085812
# gill_color_black - gill_color_green: p- value = 0.5091355018099061
# gill_color_black - gill_color_yellow: p- value = 0.05800450856078977
# gill_color_black - stalk_surface_above_ring_scaly: p- value = 0.5091355018099061
# gill_color_black - stalk_color_above_ring_cinnamon: p- value = 0.3171358318332733
# gill_color_black - stalk_color_below_ring_yellow: p- value = 0.5091355018099061
# gill_color_black - veil_type_partial: p- value = 1.0
# gill_color_black - veil_color_yellow: p- value = 1.0
# gill_color_black - ring_type_flaring: p- value = 0.20535241269067284
# gill_color_black - ring_type_pendant: p- value = 0.09925857418200704
# gill_color_black - spore_p_color_green: p- value = 0.09124047729412292
# gill_color_black - spore_p_color_orange: p- value = 0.20535241269067284
# gill_color_black - spore_p_color_purple: p- value = 0.20535241269067284
# gill_color_black - spore_p_color_yellow: p- value = 0.20535241269067284
# gill_color_brown - gill_color_green: p- value = 0.1133733346576124
# gill_color_brown - stalk_surface_above_ring_scaly: p- value = 0.1133733346576124
# gill_color_brown - stalk_color_below_ring_yellow: p- value = 0.1133733346576124
# gill_color_brown - veil_type_partial: p- value = 1.0
# gill_color_brown - veil_color_yellow: p- value = 0.5745189410311697
# gill_color_brown - pop_clustered: p- value = 0.0604234172058156
# gill_color_brown - pop_numerous: p- value = 0.06869674915698774
# gill_color_brown - habitat_urban: p- value = 0.2013488161700174
# gill_color_buff - veil_type_partial: p- value = 1.0
# gill_color_buff - veil_color_yellow: p- value = 0.2989537168626001
# gill_color_chocolate - gill_color_green: p- value = 0.2352531348805573
# gill_color_chocolate - stalk_surface_above_ring_scaly: p- value = 0.2352531348805573
# gill_color_chocolate - stalk_color_above_ring_cinnamon: p- value = 0.10946237960076798
# gill_color_chocolate - stalk_color_below_ring_yellow: p- value = 0.2352531348805573
# gill_color_chocolate - veil_type_partial: p- value = 1.0
# gill_color_chocolate - veil_color_yellow: p- value = 0.7850018903289449
# gill_color_chocolate - spore_p_color_orange: p- value = 0.0531293604478158
# gill_color_chocolate - spore_p_color_purple: p- value = 0.0531293604478158
# gill_color_chocolate - spore_p_color_yellow: p- value = 0.0531293604478158
# gill_color_gray - gill_color_green: p- value = 0.2246302266458707
# gill_color_gray - stalk_surface_above_ring_scaly: p- value = 0.2246302266458707
# gill_color_gray - stalk_color_above_ring_cinnamon: p- value = 0.10259399517701151
# gill_color_gray - stalk_color_below_ring_yellow: p- value = 0.2246302266458707
# gill_color_gray - veil_type_partial: p- value = 1.0
# gill_color_gray - veil_color_yellow: p- value = 0.7690967064684145
# gill_color_gray - habitat_urban: p- value = 0.07831319654165407
# gill_color_green - gill_color_purple: p- value = 0.41383109808085916
# gill_color_green - gill_color_red: p- value = 1.0
# gill_color_green - gill_color_white: p- value = 0.07898438295507
# gill_color_green - gill_color_yellow: p- value = 1.0
# gill_color_green - stalk_surface_above_ring_scaly: p- value = 1.0
# gill_color_green - stalk_surface_belows_ring_y: p- value = 0.705952766071211
# gill_color_green - stalk_color_above_ring_brown: p- value = 0.46082409299249394
# gill_color_green - stalk_color_above_ring_buff: p- value = 0.47945532125647206
# gill_color_green - stalk_color_above_ring_cinnamon: p- value = 1.0
# gill_color_green - stalk_color_above_ring_gray: p- value = 0.33852665282583294
# gill_color_green - stalk_color_above_ring_orange: p- value = 0.927933111911829
# gill_color_green - stalk_color_above_ring_red: p- value = 1.0
# gill_color_green - stalk_color_below_ring_brown: p- value = 0.39432126710970117
# gill_color_green - stalk_color_below_ring_buff: p- value = 0.47945532125647206
# gill_color_green - stalk_color_below_ring_gray: p- value = 0.33852665282583294
# gill_color_green - stalk_color_below_ring_orange: p- value = 0.927933111911829
# gill_color_green - stalk_color_below_ring_red: p- value = 1.0
# gill_color_green - stalk_color_below_ring_yellow: p- value = 1.0
# gill_color_green - veil_type_partial: p- value = 1.0
# gill_color_green - veil_color_brown: p- value = 1.0
# gill_color_green - veil_color_white: p- value = 0.9046089860819467
# gill_color_green - veil_color_yellow: p- value = 1.0
# gill_color_green - ring_type_flaring: p- value = 1.0
# gill_color_green - ring_type_large: p- value = 0.0631200160457633
# gill_color_green - spore_p_color_orange: p- value = 1.0
# gill_color_green - spore_p_color_purple: p- value = 1.0
# gill_color_green - spore_p_color_yellow: p- value = 1.0
# gill_color_green - pop_clustered: p- value = 0.6065856014074797
# gill_color_green - pop_numerous: p- value = 0.5195246775058994
# gill_color_green - pop_scattered: p- value = 0.07080413142473008
# gill_color_green - habitat_leaves: p- value = 0.18679556375506318
# gill_color_green - habitat_paths: p- value = 0.09057153485698202
# gill_color_green - habitat_urban: p- value = 0.5638168583450868
# gill_color_pink - stalk_surface_belows_ring_y: p- value = 0.07681929832277164
# gill_color_pink - stalk_color_below_ring_white: p- value = 0.060627787975757755
# gill_color_pink - veil_type_partial: p- value = 1.0
# gill_color_pink - veil_color_yellow: p- value = 0.3759209634566719
# gill_color_pink - number_of_rings_t: p- value = 0.1335924263436826
# gill_color_pink - ring_type_flaring: p- value = 0.31551069602489584
# gill_color_purple - stalk_surface_above_ring_scaly: p- value = 0.41383109808085916
# gill_color_purple - stalk_color_above_ring_cinnamon: p- value = 0.239338742054687
# gill_color_purple - stalk_color_below_ring_yellow: p- value = 0.41383109808085916
# gill_color_purple - veil_type_partial: p- value = 1.0
# gill_color_purple - veil_color_yellow: p- value = 1.0
# gill_color_purple - spore_p_color_green: p- value = 0.055380068201623854
# gill_color_purple - spore_p_color_orange: p- value = 0.14406174694134238
# gill_color_purple - spore_p_color_purple: p- value = 0.14406174694134238
# gill_color_purple - spore_p_color_yellow: p- value = 0.14406174694134238
# gill_color_purple - pop_several: p- value = 0.9382792657103858
# gill_color_red - gill_color_yellow: p- value = 0.6045239253553879
# gill_color_red - stalk_surface_above_ring_scaly: p- value = 1.0
# gill_color_red - stalk_surface_belows_ring_y: p- value = 0.11038954245565887
# gill_color_red - stalk_color_above_ring_cinnamon: p- value = 1.0
# gill_color_red - stalk_color_above_ring_orange: p- value = 0.23188004230352288
# gill_color_red - stalk_color_above_ring_white: p- value = 0.3804427551664651
# gill_color_red - stalk_color_below_ring_orange: p- value = 0.23188004230352288
# gill_color_red - stalk_color_below_ring_white: p- value = 0.49599871665790096
# gill_color_red - stalk_color_below_ring_yellow: p- value = 1.0
# gill_color_red - veil_type_partial: p- value = 1.0
# gill_color_red - veil_color_brown: p- value = 0.5466624958885064
# gill_color_red - veil_color_white: p- value = 0.21697871468660185
# gill_color_red - veil_color_yellow: p- value = 1.0
# gill_color_red - ring_type_flaring: p- value = 0.9282580576491384
# gill_color_red - spore_p_color_green: p- value = 0.7007547943661672
# gill_color_red - spore_p_color_orange: p- value = 0.9282580576491384
# gill_color_red - spore_p_color_purple: p- value = 0.9282580576491384
# gill_color_red - spore_p_color_yellow: p- value = 0.9282580576491384
# gill_color_red - habitat_meadows: p- value = 0.10365883958688799
# gill_color_red - habitat_urban: p- value = 0.05742073537382826
# gill_color_white - stalk_color_below_ring_brown: p- value = 0.6300072981368409
# gill_color_white - veil_type_partial: p- value = 1.0
# gill_color_white - ring_type_flaring: p- value = 0.07293934091209364
# gill_color_white - spore_p_color_white: p- value = 0.8465970137618212
# gill_color_yellow - stalk_surface_above_ring_silky: p- value = 0.11502843995309728
# gill_color_yellow - stalk_color_above_ring_red: p- value = 0.6045239253553879
# gill_color_yellow - stalk_color_below_ring_red: p- value = 0.6045239253553879
# gill_color_yellow - veil_type_partial: p- value = 1.0
# gill_color_yellow - ring_type_flaring: p- value = 0.9908310966415571
# gill_color_yellow - spore_p_color_brown: p- value = 0.2729057628738698
# gill_color_yellow - spore_p_color_green: p- value = 0.7616874316651184
# gill_color_yellow - spore_p_color_purple: p- value = 0.9908310966415571
# gill_color_yellow - spore_p_color_white: p- value = 0.5083936348148363
# gill_color_yellow - pop_numerous: p- value = 0.06133089272838691
# gill_color_yellow - habitat_meadows: p- value = 0.13130160103446056
# gill_color_yellow - habitat_urban: p- value = 0.07670379629178323
# stalk_shape_tapering - veil_type_partial: p- value = 1.0
# stalk_surface_above_ring_scaly - stalk_color_above_ring_buff: p- value = 0.47945532125647206
# stalk_surface_above_ring_scaly - stalk_color_above_ring_cinnamon: p- value = 1.0
# stalk_surface_above_ring_scaly - stalk_color_above_ring_gray: p- value = 0.33852665282583294
# stalk_surface_above_ring_scaly - stalk_color_above_ring_orange: p- value = 0.927933111911829
# stalk_surface_above_ring_scaly - stalk_color_above_ring_red: p- value = 1.0
# stalk_surface_above_ring_scaly - stalk_color_below_ring_buff: p- value = 0.47945532125647206
# stalk_surface_above_ring_scaly - stalk_color_below_ring_gray: p- value = 0.33852665282583294
# stalk_surface_above_ring_scaly - stalk_color_below_ring_orange: p- value = 0.927933111911829
# stalk_surface_above_ring_scaly - stalk_color_below_ring_red: p- value = 1.0
# stalk_surface_above_ring_scaly - veil_type_partial: p- value = 1.0
# stalk_surface_above_ring_scaly - veil_color_brown: p- value = 1.0
# stalk_surface_above_ring_scaly - ring_type_evanescent: p- value = 1.0
# stalk_surface_above_ring_scaly - ring_type_flaring: p- value = 1.0
# stalk_surface_above_ring_scaly - ring_type_large: p- value = 0.0631200160457633
# stalk_surface_above_ring_scaly - ring_type_pendant: p- value = 0.12236207064284889
# stalk_surface_above_ring_scaly - spore_p_color_green: p- value = 1.0
# stalk_surface_above_ring_scaly - spore_p_color_orange: p- value = 1.0
# stalk_surface_above_ring_scaly - spore_p_color_purple: p- value = 1.0
# stalk_surface_above_ring_scaly - spore_p_color_yellow: p- value = 1.0
# stalk_surface_above_ring_scaly - pop_numerous: p- value = 0.5195246775058994
# stalk_surface_above_ring_scaly - pop_scattered: p- value = 0.07080413142473008
# stalk_surface_above_ring_scaly - habitat_meadows: p- value = 0.690455361571799
# stalk_surface_above_ring_scaly - habitat_urban: p- value = 0.5638168583450868
# stalk_surface_above_ring_scaly - habitat_woods: p- value = 0.7371509395606574
# stalk_surface_above_ring_silky - stalk_surface_belows_ring_y: p- value = 0.055386104963545756
# stalk_surface_above_ring_silky - veil_type_partial: p- value = 1.0
# stalk_surface_above_ring_silky - veil_color_yellow: p- value = 0.15322741779486862
# stalk_surface_above_ring_silky - number_of_rings_o: p- value = 0.6369422612611022
# stalk_surface_above_ring_smooth - stalk_surface_belows_ring_y: p- value = 0.18478078121306526
# stalk_surface_above_ring_smooth - veil_type_partial: p- value = 1.0
# stalk_surface_above_ring_smooth - habitat_leaves: p- value = 0.18073527148111862
# stalk_surface_belows_ring_k - veil_type_partial: p- value = 1.0
# stalk_surface_belows_ring_k - veil_color_yellow: p- value = 0.16510442757575905
# stalk_surface_belows_ring_k - habitat_grasses: p- value = 0.06814616698833623
# stalk_surface_belows_ring_s - veil_type_partial: p- value = 1.0
# stalk_surface_belows_ring_s - habitat_leaves: p- value = 0.6534287262756764
# stalk_surface_belows_ring_y - stalk_color_above_ring_brown: p- value = 1.0
# stalk_surface_belows_ring_y - stalk_color_above_ring_red: p- value = 0.11038954245565887
# stalk_surface_belows_ring_y - stalk_color_below_ring_red: p- value = 0.11038954245565887
# stalk_surface_belows_ring_y - veil_type_partial: p- value = 1.0
# stalk_surface_belows_ring_y - veil_color_brown: p- value = 0.11038954245565887
# stalk_surface_belows_ring_y - veil_color_white: p- value = 0.8429146763691572
# stalk_surface_belows_ring_y - number_of_rings_t: p- value = 0.3013594415840841
# stalk_surface_belows_ring_y - ring_type_flaring: p- value = 0.35317153287559633
# stalk_surface_belows_ring_y - spore_p_color_green: p- value = 0.19362228550461005
# stalk_surface_belows_ring_y - spore_p_color_orange: p- value = 0.35317153287559633
# stalk_surface_belows_ring_y - spore_p_color_purple: p- value = 0.35317153287559633
# stalk_surface_belows_ring_y - spore_p_color_white: p- value = 0.28761119160003223
# stalk_surface_belows_ring_y - spore_p_color_yellow: p- value = 0.35317153287559633
# stalk_color_above_ring_brown - stalk_color_above_ring_cinnamon: p- value = 0.27710271162342215
# stalk_color_above_ring_brown - stalk_color_below_ring_yellow: p- value = 0.46082409299249394
# stalk_color_above_ring_brown - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_brown - veil_color_yellow: p- value = 1.0
# stalk_color_above_ring_brown - ring_type_flaring: p- value = 0.17331778686229754
# stalk_color_above_ring_brown - spore_p_color_green: p- value = 0.07189694773145451
# stalk_color_above_ring_brown - spore_p_color_orange: p- value = 0.17331778686229754
# stalk_color_above_ring_brown - spore_p_color_purple: p- value = 0.17331778686229754
# stalk_color_above_ring_brown - spore_p_color_yellow: p- value = 0.17331778686229754
# stalk_color_above_ring_brown - pop_several: p- value = 0.5411030998031519
# stalk_color_above_ring_buff - stalk_color_above_ring_cinnamon: p- value = 0.2924040200417837
# stalk_color_above_ring_buff - stalk_color_below_ring_yellow: p- value = 0.47945532125647206
# stalk_color_above_ring_buff - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_buff - veil_color_yellow: p- value = 1.0
# stalk_color_above_ring_buff - ring_type_flaring: p- value = 0.18544585773432903
# stalk_color_above_ring_buff - spore_p_color_green: p- value = 0.07907486931379541
# stalk_color_above_ring_buff - spore_p_color_orange: p- value = 0.18544585773432903
# stalk_color_above_ring_buff - spore_p_color_purple: p- value = 0.18544585773432903
# stalk_color_above_ring_buff - spore_p_color_yellow: p- value = 0.18544585773432903
# stalk_color_above_ring_buff - pop_several: p- value = 0.9471833377366299
# stalk_color_above_ring_cinnamon - stalk_color_above_ring_gray: p- value = 0.18163043493305414
# stalk_color_above_ring_cinnamon - stalk_color_above_ring_orange: p- value = 0.6996751880620475
# stalk_color_above_ring_cinnamon - stalk_color_above_ring_red: p- value = 1.0
# stalk_color_above_ring_cinnamon - stalk_color_below_ring_brown: p- value = 0.224036164528499
# stalk_color_above_ring_cinnamon - stalk_color_below_ring_buff: p- value = 0.2924040200417837
# stalk_color_above_ring_cinnamon - stalk_color_below_ring_gray: p- value = 0.18163043493305414
# stalk_color_above_ring_cinnamon - stalk_color_below_ring_orange: p- value = 0.6996751880620475
# stalk_color_above_ring_cinnamon - stalk_color_below_ring_red: p- value = 1.0
# stalk_color_above_ring_cinnamon - stalk_color_below_ring_yellow: p- value = 1.0
# stalk_color_above_ring_cinnamon - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_cinnamon - veil_color_brown: p- value = 1.0
# stalk_color_above_ring_cinnamon - veil_color_white: p- value = 0.677139688978057
# stalk_color_above_ring_cinnamon - veil_color_yellow: p- value = 1.0
# stalk_color_above_ring_cinnamon - number_of_rings_t: p- value = 0.16796434985305658
# stalk_color_above_ring_cinnamon - ring_type_flaring: p- value = 1.0
# stalk_color_above_ring_cinnamon - spore_p_color_green: p- value = 1.0
# stalk_color_above_ring_cinnamon - spore_p_color_orange: p- value = 1.0
# stalk_color_above_ring_cinnamon - spore_p_color_purple: p- value = 1.0
# stalk_color_above_ring_cinnamon - spore_p_color_yellow: p- value = 1.0
# stalk_color_above_ring_cinnamon - pop_numerous: p- value = 0.32589148444340044
# stalk_color_above_ring_cinnamon - habitat_leaves: p- value = 0.0791328207709051
# stalk_color_above_ring_cinnamon - habitat_meadows: p- value = 0.4761956129384751
# stalk_color_above_ring_cinnamon - habitat_urban: p- value = 0.3637556962741235
# stalk_color_above_ring_gray - stalk_color_below_ring_yellow: p- value = 0.33852665282583294
# stalk_color_above_ring_gray - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_gray - veil_color_yellow: p- value = 0.9262004350155789
# stalk_color_above_ring_gray - ring_type_flaring: p- value = 0.10151660739824817
# stalk_color_above_ring_gray - spore_p_color_orange: p- value = 0.10151660739824817
# stalk_color_above_ring_gray - spore_p_color_purple: p- value = 0.10151660739824817
# stalk_color_above_ring_gray - spore_p_color_yellow: p- value = 0.10151660739824817
# stalk_color_above_ring_gray - pop_several: p- value = 0.9269937442247185
# stalk_color_above_ring_orange - stalk_color_above_ring_red: p- value = 0.23188004230352288
# stalk_color_above_ring_orange - stalk_color_below_ring_red: p- value = 0.23188004230352288
# stalk_color_above_ring_orange - stalk_color_below_ring_yellow: p- value = 0.927933111911829
# stalk_color_above_ring_orange - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_orange - veil_color_yellow: p- value = 1.0
# stalk_color_above_ring_orange - ring_type_flaring: p- value = 0.5454443553499428
# stalk_color_above_ring_orange - spore_p_color_brown: p- value = 0.8661249014441068
# stalk_color_above_ring_orange - spore_p_color_green: p- value = 0.3490647730828257
# stalk_color_above_ring_orange - spore_p_color_purple: p- value = 0.5454443553499428
# stalk_color_above_ring_orange - pop_several: p- value = 0.9976758513433275
# stalk_color_above_ring_pink - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_pink - veil_color_yellow: p- value = 0.25912096495994347
# stalk_color_above_ring_red - stalk_color_below_ring_orange: p- value = 0.23188004230352288
# stalk_color_above_ring_red - stalk_color_below_ring_white: p- value = 0.49599871665790096
# stalk_color_above_ring_red - stalk_color_below_ring_yellow: p- value = 1.0
# stalk_color_above_ring_red - veil_type_partial: p- value = 1.0
# stalk_color_above_ring_red - veil_color_brown: p- value = 0.5466624958885064
# stalk_color_above_ring_red - veil_color_white: p- value = 0.21697871468660185
# stalk_color_above_ring_red - veil_color_yellow: p- value = 1.0
# stalk_color_above_ring_red - ring_type_flaring: p- value = 0.9282580576491384
# stalk_color_above_ring_red - spore_p_color_green: p- value = 0.7007547943661672
# stalk_color_above_ring_red - spore_p_color_orange: p- value = 0.9282580576491384
# stalk_color_above_ring_red - spore_p_color_purple: p- value = 0.9282580576491384
# stalk_color_above_ring_red - spore_p_color_yellow: p- value = 0.9282580576491384
# stalk_color_above_ring_red - habitat_meadows: p- value = 0.10365883958688799
# stalk_color_above_ring_red - habitat_urban: p- value = 0.05742073537382826
# stalk_color_above_ring_white - stalk_color_below_ring_red: p- value = 0.3804427551664651
# stalk_color_above_ring_white - stalk_color_below_ring_yellow: p- value = 0.3420623420667322
# stalk_color_above_ring_white - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_brown - stalk_color_below_ring_yellow: p- value = 0.39432126710970117
# stalk_color_below_ring_brown - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_brown - veil_color_yellow: p- value = 0.995139277065691
# stalk_color_below_ring_brown - ring_type_flaring: p- value = 0.13250618151063417
# stalk_color_below_ring_brown - spore_p_color_orange: p- value = 0.13250618151063417
# stalk_color_below_ring_brown - spore_p_color_purple: p- value = 0.13250618151063417
# stalk_color_below_ring_brown - spore_p_color_yellow: p- value = 0.13250618151063417
# stalk_color_below_ring_brown - habitat_grasses: p- value = 0.40019114316403326
# stalk_color_below_ring_brown - habitat_leaves: p- value = 0.5534520001338494
# stalk_color_below_ring_buff - stalk_color_below_ring_yellow: p- value = 0.47945532125647206
# stalk_color_below_ring_buff - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_buff - veil_color_yellow: p- value = 1.0
# stalk_color_below_ring_buff - ring_type_flaring: p- value = 0.18544585773432903
# stalk_color_below_ring_buff - spore_p_color_green: p- value = 0.07907486931379541
# stalk_color_below_ring_buff - spore_p_color_orange: p- value = 0.18544585773432903
# stalk_color_below_ring_buff - spore_p_color_purple: p- value = 0.18544585773432903
# stalk_color_below_ring_buff - spore_p_color_yellow: p- value = 0.18544585773432903
# stalk_color_below_ring_buff - pop_several: p- value = 0.9471833377366299
# stalk_color_below_ring_gray - stalk_color_below_ring_yellow: p- value = 0.33852665282583294
# stalk_color_below_ring_gray - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_gray - veil_color_yellow: p- value = 0.9262004350155789
# stalk_color_below_ring_gray - ring_type_flaring: p- value = 0.10151660739824817
# stalk_color_below_ring_gray - spore_p_color_orange: p- value = 0.10151660739824817
# stalk_color_below_ring_gray - spore_p_color_purple: p- value = 0.10151660739824817
# stalk_color_below_ring_gray - spore_p_color_yellow: p- value = 0.10151660739824817
# stalk_color_below_ring_gray - pop_several: p- value = 0.9269937442247185
# stalk_color_below_ring_orange - stalk_color_below_ring_red: p- value = 0.23188004230352288
# stalk_color_below_ring_orange - stalk_color_below_ring_yellow: p- value = 0.927933111911829
# stalk_color_below_ring_orange - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_orange - veil_color_yellow: p- value = 1.0
# stalk_color_below_ring_orange - ring_type_flaring: p- value = 0.5454443553499428
# stalk_color_below_ring_orange - spore_p_color_brown: p- value = 0.8661249014441068
# stalk_color_below_ring_orange - spore_p_color_green: p- value = 0.3490647730828257
# stalk_color_below_ring_orange - spore_p_color_purple: p- value = 0.5454443553499428
# stalk_color_below_ring_orange - pop_several: p- value = 0.9976758513433275
# stalk_color_below_ring_pink - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_pink - veil_color_yellow: p- value = 0.25912096495994347
# stalk_color_below_ring_red - stalk_color_below_ring_yellow: p- value = 1.0
# stalk_color_below_ring_red - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_red - veil_color_brown: p- value = 0.5466624958885064
# stalk_color_below_ring_red - veil_color_white: p- value = 0.21697871468660185
# stalk_color_below_ring_red - veil_color_yellow: p- value = 1.0
# stalk_color_below_ring_red - ring_type_flaring: p- value = 0.9282580576491384
# stalk_color_below_ring_red - spore_p_color_green: p- value = 0.7007547943661672
# stalk_color_below_ring_red - spore_p_color_orange: p- value = 0.9282580576491384
# stalk_color_below_ring_red - spore_p_color_purple: p- value = 0.9282580576491384
# stalk_color_below_ring_red - spore_p_color_yellow: p- value = 0.9282580576491384
# stalk_color_below_ring_red - habitat_meadows: p- value = 0.10365883958688799
# stalk_color_below_ring_red - habitat_urban: p- value = 0.05742073537382826
# stalk_color_below_ring_white - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_white - spore_p_color_white: p- value = 0.9941551197672825
# stalk_color_below_ring_yellow - veil_type_partial: p- value = 1.0
# stalk_color_below_ring_yellow - veil_color_brown: p- value = 1.0
# stalk_color_below_ring_yellow - number_of_rings_o: p- value = 0.29401644693295026
# stalk_color_below_ring_yellow - number_of_rings_t: p- value = 0.31990312259692805
# stalk_color_below_ring_yellow - ring_type_flaring: p- value = 1.0
# stalk_color_below_ring_yellow - ring_type_large: p- value = 0.0631200160457633
# stalk_color_below_ring_yellow - spore_p_color_green: p- value = 1.0
# stalk_color_below_ring_yellow - spore_p_color_orange: p- value = 1.0
# stalk_color_below_ring_yellow - spore_p_color_purple: p- value = 1.0
# stalk_color_below_ring_yellow - spore_p_color_yellow: p- value = 1.0
# stalk_color_below_ring_yellow - pop_numerous: p- value = 0.5195246775058994
# stalk_color_below_ring_yellow - pop_scattered: p- value = 0.07080413142473008
# stalk_color_below_ring_yellow - pop_several: p- value = 0.1449568765785155
# stalk_color_below_ring_yellow - habitat_meadows: p- value = 0.690455361571799
# stalk_color_below_ring_yellow - habitat_paths: p- value = 0.09057153485698202
# stalk_color_below_ring_yellow - habitat_urban: p- value = 0.5638168583450868
# veil_type_partial - veil_color_brown: p- value = 1.0
# veil_type_partial - veil_color_white: p- value = 1.0
# veil_type_partial - veil_color_yellow: p- value = 1.0
# veil_type_partial - number_of_rings_o: p- value = 1.0
# veil_type_partial - number_of_rings_t: p- value = 1.0
# veil_type_partial - ring_type_evanescent: p- value = 1.0
# veil_type_partial - ring_type_flaring: p- value = 1.0
# veil_type_partial - ring_type_large: p- value = 1.0
# veil_type_partial - ring_type_pendant: p- value = 1.0
# veil_type_partial - spore_p_color_black: p- value = 1.0
# veil_type_partial - spore_p_color_brown: p- value = 1.0
# veil_type_partial - spore_p_color_chocolate: p- value = 1.0
# veil_type_partial - spore_p_color_green: p- value = 1.0
# veil_type_partial - spore_p_color_orange: p- value = 1.0
# veil_type_partial - spore_p_color_purple: p- value = 1.0
# veil_type_partial - spore_p_color_white: p- value = 1.0
# veil_type_partial - spore_p_color_yellow: p- value = 1.0
# veil_type_partial - pop_clustered: p- value = 1.0
# veil_type_partial - pop_numerous: p- value = 1.0
# veil_type_partial - pop_scattered: p- value = 1.0
# veil_type_partial - pop_several: p- value = 1.0
# veil_type_partial - pop_solitary: p- value = 1.0
# veil_type_partial - habitat_grasses: p- value = 1.0
# veil_type_partial - habitat_leaves: p- value = 1.0
# veil_type_partial - habitat_meadows: p- value = 1.0
# veil_type_partial - habitat_paths: p- value = 1.0
# veil_type_partial - habitat_urban: p- value = 1.0
# veil_type_partial - habitat_woods: p- value = 1.0
# veil_color_brown - veil_color_yellow: p- value = 1.0
# veil_color_brown - ring_type_flaring: p- value = 0.9282580576491384
# veil_color_brown - spore_p_color_brown: p- value = 0.9532851708920551
# veil_color_brown - spore_p_color_green: p- value = 0.7007547943661672
# veil_color_brown - spore_p_color_purple: p- value = 0.9282580576491384
# veil_color_brown - pop_several: p- value = 1.0
# veil_color_brown - habitat_meadows: p- value = 0.10365883958688799
# veil_color_brown - habitat_urban: p- value = 0.05742073537382826
# veil_color_white - ring_type_flaring: p- value = 0.5242275685148228
# veil_color_white - spore_p_color_brown: p- value = 1.0
# veil_color_white - spore_p_color_green: p- value = 0.33099503510634376
# veil_color_white - spore_p_color_purple: p- value = 0.5242275685148228
# veil_color_white - pop_several: p- value = 0.6718331642619556
# veil_color_yellow - number_of_rings_o: p- value = 0.8679170750914087
# veil_color_yellow - number_of_rings_t: p- value = 0.9022146505746722
# veil_color_yellow - ring_type_flaring: p- value = 1.0
# veil_color_yellow - ring_type_large: p- value = 0.45334582242831134
# veil_color_yellow - spore_p_color_black: p- value = 0.25912096495994347
# veil_color_yellow - spore_p_color_brown: p- value = 0.23514830318843327
# veil_color_yellow - spore_p_color_chocolate: p- value = 0.3283709843178648
# veil_color_yellow - spore_p_color_green: p- value = 1.0
# veil_color_yellow - spore_p_color_orange: p- value = 1.0
# veil_color_yellow - spore_p_color_purple: p- value = 1.0
# veil_color_yellow - spore_p_color_yellow: p- value = 1.0
# veil_color_yellow - pop_numerous: p- value = 1.0
# veil_color_yellow - pop_scattered: p- value = 0.47455199183038466
# veil_color_yellow - pop_solitary: p- value = 0.30368946787045076
# veil_color_yellow - habitat_grasses: p- value = 0.19513841457192843
# veil_color_yellow - habitat_meadows: p- value = 1.0
# veil_color_yellow - habitat_paths: p- value = 0.5240230184895691
# veil_color_yellow - habitat_urban: p- value = 1.0
# veil_color_yellow - habitat_woods: p- value = 0.059058378334980274
# number_of_rings_o - ring_type_flaring: p- value = 0.07914468385050226
# number_of_rings_o - spore_p_color_orange: p- value = 0.07914468385050226
# number_of_rings_o - spore_p_color_purple: p- value = 0.07914468385050226
# number_of_rings_o - spore_p_color_yellow: p- value = 0.07914468385050226
# number_of_rings_t - ring_type_evanescent: p- value = 0.26270218959486286
# number_of_rings_t - ring_type_flaring: p- value = 0.09189065357942579
# number_of_rings_t - spore_p_color_orange: p- value = 0.09189065357942579
# number_of_rings_t - spore_p_color_purple: p- value = 0.09189065357942579
# number_of_rings_t - spore_p_color_yellow: p- value = 0.09189065357942579
# ring_type_evanescent - habitat_grasses: p- value = 0.07539843173396868
# ring_type_flaring - spore_p_color_green: p- value = 1.0
# ring_type_flaring - spore_p_color_orange: p- value = 1.0
# ring_type_flaring - spore_p_color_purple: p- value = 1.0
# ring_type_flaring - spore_p_color_yellow: p- value = 1.0
# ring_type_flaring - pop_clustered: p- value = 0.27536111851515477
# ring_type_flaring - pop_numerous: p- value = 0.2124847785119635
# ring_type_flaring - pop_several: p- value = 1.0
# ring_type_flaring - habitat_meadows: p- value = 0.34065327249786514
# ring_type_flaring - habitat_urban: p- value = 0.2438016057109474
# ring_type_large - pop_several: p- value = 0.8552832669484915
# spore_p_color_chocolate - pop_several: p- value = 0.8281527775819388
# spore_p_color_green - spore_p_color_orange: p- value = 1.0
# spore_p_color_green - spore_p_color_purple: p- value = 1.0
# spore_p_color_green - spore_p_color_yellow: p- value = 1.0
# spore_p_color_green - pop_clustered: p- value = 0.1373512214175833
# spore_p_color_green - pop_numerous: p- value = 0.09570937571371005
# spore_p_color_green - habitat_urban: p- value = 0.11596886012712118
# spore_p_color_orange - spore_p_color_purple: p- value = 1.0
# spore_p_color_orange - spore_p_color_yellow: p- value = 1.0
# spore_p_color_orange - pop_numerous: p- value = 0.2124847785119635
# spore_p_color_orange - pop_several: p- value = 1.0
# spore_p_color_orange - habitat_meadows: p- value = 0.34065327249786514
# spore_p_color_orange - habitat_urban: p- value = 0.2438016057109474
# spore_p_color_purple - spore_p_color_yellow: p- value = 1.0
# spore_p_color_purple - pop_clustered: p- value = 0.27536111851515477
# spore_p_color_purple - pop_numerous: p- value = 0.2124847785119635
# spore_p_color_purple - habitat_meadows: p- value = 0.34065327249786514
# spore_p_color_purple - habitat_urban: p- value = 0.2438016057109474
# spore_p_color_yellow - pop_numerous: p- value = 0.2124847785119635
# spore_p_color_yellow - pop_several: p- value = 1.0
# spore_p_color_yellow - habitat_meadows: p- value = 0.34065327249786514
# spore_p_color_yellow - habitat_urban: p- value = 0.2438016057109474
# pop_several - habitat_urban: p- value = 0.9577446802183185

# %% [markdown]
# ##### Cramer's V with Bias Correction
#
# Let us try and use another method that measures the association between two nominal variables. Since all our data is binary, we could use the Cramer's V method. Cramer's V is a measure of association between two nominal variables, similar to Pearson's correlation coefficient for continuous variables. In the context of our EDA, Cramer's V can help assess the strength of the relationship between each pair of categorical variables.
#
# Cramer's V is a number between 0 and 1. A high Cramer's V value indicates a strong association, while a low value suggests little to no association. Moreover,  if two variables have a high Cramer's V value, it implies that changes in one variable are likely to be associated with changes in the other variable.
#
# We will calculate the Cramer's V value using the formula with the bias correction, since Cramer's V can be highly biased. When it comes to evaluating our model and seeing which variables we might drop, this long list might prove to be helpful.
#
# The general rule of thumb is as follows:
#
# * Weak association: Cramér's V around 0.1 or lower.
# * Moderate association: Cramér's V between 0.1 and 0.3.
# * Strong association: Cramér's V above 0.3.

# %%
def cramers_v_corrected(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    if min((kcorr-1), (rcorr-1)) == 0:
        return np.nan
    else:
        return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# List to store Cramér's V values for each pair of variable-target variable
cramers_v_values = []

# Iterate over each predictor variable
for col in df.columns:
    # Skip the variable if it's the target variable 'is_poisonous'
    if col == 'is_poisonous':
        continue
        
    # Create the confusion matrix between the predictor and the target variable
    confusion_matrix = pd.crosstab(df[col], df['is_poisonous'])
    
    # Check for NaN values in the confusion matrix
    if confusion_matrix.isnull().values.any():
        cramers_v_values.append((col, np.nan))
    else:
        # Compute Cramér's V value
        cramers_v_value = cramers_v_corrected(confusion_matrix)
        cramers_v_values.append((col, cramers_v_value))

# Create a DataFrame to store the Cramér's V values
cramers_v_df = pd.DataFrame(cramers_v_values, columns=['Predictor Variable', 'Cramers V'])

# Display the DataFrame
for index, row in cramers_v_df.iterrows():
    print(f"{row['Predictor Variable']}: {row['Cramers V']}")
# Out:
# cap_shape_bell: 0.181702057508935
# cap_shape_convex: 0.024218934252358784
# cap_shape_flat: 0.014519805842328837
# cap_shape_knobbed: 0.16279027973742483
# cap_shape_sunken: 0.057642852789245934
# cap_surface_fibrous: 0.19483839261536737
# cap_surface_scaly: 0.08773206015371075
# cap_surface_smooth: 0.09454620087058581
# cap_color_brown: 0.04266946589223426
# cap_color_buff: 0.06575294915347991
# cap_color_cinnamon: 0.027046211114787506
# cap_color_gray: 0.044810993015422025
# cap_color_green: 0.03851113105419004
# cap_color_pink: 0.031895942385548895
# cap_color_red: 0.09616286089629046
# cap_color_white: 0.1328598808495438
# cap_color_yellow: 0.11210910341557564
# has_bruises_False: 0.5011884872000123
# odor_almond: 0.21869210047695598
# odor_anise: 0.21869210047695598
# odor_creosote: 0.16009320261032758
# odor_fishy: 0.28568193617728954
# odor_foul: 0.623502824292488
# odor_none: 0.7852780750230953
# odor_pungent: 0.18595960174434836
# odor_spicy: 0.28568193617728954
# gill_attachment_free: 0.1279513384833157
# gill_spacing_close: 0.34789658744266105
# gill_size_broad: 0.5396770170525035
# gill_color_black: 0.14867235129080697
# gill_color_brown: 0.288379815176697
# gill_color_buff: 0.5384259965726416
# gill_color_chocolate: 0.14986320351605945
# gill_color_gray: 0.11935233540204335
# gill_color_green: 0.053011027929365566
# gill_color_pink: 0.04881958127241608
# gill_color_purple: 0.19453858397240753
# gill_color_red: 0.1037660076210547
# gill_color_white: 0.23071686232648347
# gill_color_yellow: 0.04425760368940749
# stalk_shape_tapering: 0.10117000903111316
# stalk_surface_above_ring_scaly: 0.0084210497970184
# stalk_surface_above_ring_silky: 0.5873187057097609
# stalk_surface_above_ring_smooth: 0.49096287218696716
# stalk_surface_belows_ring_k: 0.5731786463271819
# stalk_surface_belows_ring_s: 0.4250731684667105
# stalk_surface_belows_ring_y: 0.080244706737578
# stalk_color_above_ring_brown: 0.23237363128013513
# stalk_color_above_ring_buff: 0.2448773282336466
# stalk_color_above_ring_cinnamon: 0.0663875680173798
# stalk_color_above_ring_gray: 0.26579364421897167
# stalk_color_above_ring_orange: 0.14887228129964844
# stalk_color_above_ring_pink: 0.22973072261980862
# stalk_color_above_ring_red: 0.1037660076210547
# stalk_color_above_ring_white: 0.21722304740724643
# stalk_color_below_ring_brown: 0.20316864541805593
# stalk_color_below_ring_buff: 0.2448773282336466
# stalk_color_below_ring_gray: 0.26579364421897167
# stalk_color_below_ring_orange: 0.14887228129964844
# stalk_color_below_ring_pink: 0.22973072261980862
# stalk_color_below_ring_red: 0.1037660076210547
# stalk_color_below_ring_white: 0.21359016644293688
# stalk_color_below_ring_yellow: 0.053011027929365566
# veil_type_partial: nan
# veil_color_brown: 0.1037660076210547
# veil_color_white: 0.1393137935147719
# veil_color_yellow: 0.02638168120144186
# number_of_rings_o: 0.18131481517606615
# number_of_rings_t: 0.20383941943328807
# ring_type_evanescent: 0.22276376342947488
# ring_type_flaring: 0.07191774588785793
# ring_type_large: 0.4511740399280959
# ring_type_pendant: 0.5401417989260805
# spore_p_color_black: 0.3964088498932191
# spore_p_color_brown: 0.4162355667557526
# spore_p_color_chocolate: 0.48982624679946457
# spore_p_color_green: 0.09607677686258781
# spore_p_color_orange: 0.07191774588785793
# spore_p_color_purple: 0.07191774588785793
# spore_p_color_white: 0.35696320294945993
# spore_p_color_yellow: 0.07191774588785793
# pop_clustered: 0.1365882332720766
# pop_numerous: 0.21869210047695598
# pop_scattered: 0.15885274370803482
# pop_several: 0.44336450386003584
# pop_solitary: 0.10618121423214372
# habitat_grasses: 0.16436087132866678
# habitat_leaves: 0.15435449058164477
# habitat_meadows: 0.13752653176810392
# habitat_paths: 0.32282091724068607
# habitat_urban: 0.11093919263874683
# habitat_woods: 0.1253880335816472

# %% [markdown]
# Here we compute all of the varaibles whose Cramer V value is less than 0.1.

# %%
def cramers_v_corrected(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    if min((kcorr-1), (rcorr-1)) == 0:
        return np.nan
    else:
        return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# List to store Cramér's V values for each predictor variable
cramers_v_values = []

# Iterate over each predictor variable
for col in df.columns:
    # Skip the variable if it's the target variable 'is_poisonous'
    if col == 'is_poisonous':
        continue
        
    # Create the confusion matrix between the predictor and the target variable
    confusion_matrix = pd.crosstab(df[col], df['is_poisonous'])
    
    # Check for NaN values in the confusion matrix
    if confusion_matrix.isnull().values.any():
        cramers_v_values.append((col, np.nan))
    else:
        # Compute Cramér's V value
        cramers_v_value = cramers_v_corrected(confusion_matrix)
        # Check if the Cramér's V value is less than 0.1
        if cramers_v_value < 0.1:
            cramers_v_values.append((col, cramers_v_value))

# Create a DataFrame to store the Cramér's V values
cramers_v_df = pd.DataFrame(cramers_v_values, columns=['Predictor Variable', 'Cramers V'])

# Display the DataFrame
for index, row in cramers_v_df.iterrows():
    print(f"{row['Predictor Variable']}: {row['Cramers V']}")
# Out:
# cap_shape_convex: 0.024218934252358784
# cap_shape_flat: 0.014519805842328837
# cap_shape_sunken: 0.057642852789245934
# cap_surface_scaly: 0.08773206015371075
# cap_surface_smooth: 0.09454620087058581
# cap_color_brown: 0.04266946589223426
# cap_color_buff: 0.06575294915347991
# cap_color_cinnamon: 0.027046211114787506
# cap_color_gray: 0.044810993015422025
# cap_color_green: 0.03851113105419004
# cap_color_pink: 0.031895942385548895
# cap_color_red: 0.09616286089629046
# gill_color_green: 0.053011027929365566
# gill_color_pink: 0.04881958127241608
# gill_color_yellow: 0.04425760368940749
# stalk_surface_above_ring_scaly: 0.0084210497970184
# stalk_surface_belows_ring_y: 0.080244706737578
# stalk_color_above_ring_cinnamon: 0.0663875680173798
# stalk_color_below_ring_yellow: 0.053011027929365566
# veil_color_yellow: 0.02638168120144186
# ring_type_flaring: 0.07191774588785793
# spore_p_color_green: 0.09607677686258781
# spore_p_color_orange: 0.07191774588785793
# spore_p_color_purple: 0.07191774588785793
# spore_p_color_yellow: 0.07191774588785793

# %% [markdown]
# ##### The Phi Coefficient $\varphi$
#
# The $\varphi$ coefficient, also known as the phi correlation coefficient, is a measure of association for two binary variables. It ranges from -1 to 1, where:
#
#  * 1 indicates a perfect positive association, meaning that both variables tend to have the same value simultaneously.
#
#  * 0 indicates no association between the variables.
#
#  * -1 indicates a perfect negative association, meaning that the variables tend to have opposite values simultaneously.
#
# The $\varphi$ coefficient can help assess the strength of relationships between predictor variables. Higher $\varphi$ coefficients indicate stronger associations between variables, which can be useful for feature selection, identifying multicollinearity, and understanding the potential impact of predictor variables on the target variable. Also, variables with higher $\varphi$ coefficients may be more informative for predicting the target variable, which in our case, is mushroom toxicity.
#
# Since there are too many variable, we will only display those whose $\varphi$ coefficient is above a certain threshold. The threshold of the $\varphi$ coefficient depends on many factors, including the field in which your analysis is in. Since our dataset is in biology, a good threshold is at 0.7. Thus, for our case, any variable whose $\varphi$ coefficient is greater than 0.7 will be considered to have very high association with the other variable.
#
# We will run two codes: one which does not includes the target varaible 'is_poisonous' and one which does. Excluding the target variable will help us understand the relationships among the predictor variables. Including the target variable will provide a comprehensive overview of the relationships among all variables in our dataset.

# %% [markdown]
# #####  List of Variables where $|\varphi|> 0.7$

# %%
def phi_coefficient(x, y):
    n11 = np.sum((x == 1) & (y == 1))
    n10 = np.sum((x == 1) & (y == 0))
    n01 = np.sum((x == 0) & (y == 1))
    n00 = np.sum((x == 0) & (y == 0))
    
    # Handle division by zero
    if (n11 + n10) * (n11 + n01) * (n10 + n00) * (n01 + n00) == 0:
        return np.nan
    
    phi = (n11 * n00 - n10 * n01) / np.sqrt((n11 + n10) * (n11 + n01) * (n10 + n00) * (n01 + n00))
    return phi

# Computing the phi coefficient correlation matrix:
corr_matrix = pd.DataFrame(index=df.columns, columns=df.columns, dtype=float)
for i in range(len(df.columns)):
    for j in range(len(df.columns)):
        if i != j:  # Avoid computing phi for the same variable with itself
            corr_matrix.iloc[i, j] = phi_coefficient(df.iloc[:, i], df.iloc[:, j])

# Extracting variables with phi coefficient > 0.7
high_phi_variables = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > 0.7:
            high_phi_variables.append(((corr_matrix.columns[i], corr_matrix.columns[j]), corr_matrix.iloc[i, j]))

# Printing variables with phi coefficient > 0.7
print("Variable pairs with absolute phi coefficient > 0.7:")
for pair, phi_coefficient in high_phi_variables:
    print(f"{pair}: Phi Coefficient = {phi_coefficient}")
# Out:
# Variable pairs with absolute phi coefficient > 0.7:
# ('is_poisonous', 'odor_none'): Phi Coefficient = -0.7855566222366936
# ('cap_shape_convex', 'cap_shape_flat'): Phi Coefficient = -0.7202347239357578
# ('has_bruises_False', 'ring_type_pendant'): Phi Coefficient = -0.7670361113113316
# ('odor_foul', 'ring_type_large'): Phi Coefficient = 0.7239318535931049
# ('odor_foul', 'spore_p_color_chocolate'): Phi Coefficient = 0.7997515343521001
# ('gill_attachment_free', 'stalk_color_above_ring_orange'): Phi Coefficient = -0.9550973436312871
# ('gill_attachment_free', 'stalk_color_below_ring_orange'): Phi Coefficient = -0.9550973436312871
# ('gill_attachment_free', 'veil_color_white'): Phi Coefficient = 0.9352375509363866
# ('gill_size_broad', 'gill_color_buff'): Phi Coefficient = -0.7769027436644634
# ('gill_color_buff', 'ring_type_evanescent'): Phi Coefficient = 0.7214456346935011
# ('gill_color_buff', 'spore_p_color_white'): Phi Coefficient = 0.8055732780196047
# ('stalk_surface_above_ring_silky', 'stalk_surface_above_ring_smooth'): Phi Coefficient = -0.8509054354991242
# ('stalk_surface_belows_ring_k', 'stalk_surface_belows_ring_s'): Phi Coefficient = -0.7829033730935361
# ('stalk_color_above_ring_orange', 'stalk_color_below_ring_orange'): Phi Coefficient = 1.0
# ('stalk_color_above_ring_orange', 'veil_color_brown'): Phi Coefficient = 0.7028662225177368
# ('stalk_color_above_ring_orange', 'veil_color_white'): Phi Coefficient = -0.979301674687318
# ('stalk_color_below_ring_orange', 'veil_color_brown'): Phi Coefficient = 0.7028662225177368
# ('stalk_color_below_ring_orange', 'veil_color_white'): Phi Coefficient = -0.979301674687318
# ('number_of_rings_o', 'number_of_rings_t'): Phi Coefficient = -0.9689594258132992
# ('ring_type_evanescent', 'ring_type_pendant'): Phi Coefficient = -0.7039828737323405
# ('ring_type_large', 'spore_p_color_chocolate'): Phi Coefficient = 0.8689302627422733

# %%
def phi_coefficient(x, y):
    n11 = np.sum((x == 1) & (y == 1))
    n10 = np.sum((x == 1) & (y == 0))
    n01 = np.sum((x == 0) & (y == 1))
    n00 = np.sum((x == 0) & (y == 0))
    
    # Handle division by zero
    if (n11 + n10) * (n11 + n01) * (n10 + n00) * (n01 + n00) == 0:
        return np.nan
    
    phi = (n11 * n00 - n10 * n01) / np.sqrt((n11 + n10) * (n11 + n01) * (n10 + n00) * (n01 + n00))
    return phi

# Computing the phi coefficient correlation with the target variable:
phi_with_target = pd.Series(index=df.columns, dtype=float)
for col in df.columns:
    if col != 'is_poisonous':  # Avoid computing phi with the target variable itself
        phi_with_target[col] = phi_coefficient(df[col], df['is_poisonous'])

# Printing variables with phi coefficient with the target variable
print("Phi coefficients with the target variable:")
print(phi_with_target)
# Out:
# Phi coefficients with the target variable:
# is_poisonous                            NaN
# cap_shape_bell                    -0.182567
# cap_shape_convex                  -0.026886
# cap_shape_flat                     0.018526
# cap_shape_knobbed                  0.163565
# cap_shape_sunken                  -0.060664
# cap_surface_fibrous               -0.195415
# cap_surface_scaly                  0.088677
# cap_surface_smooth                 0.095454
# cap_color_brown                   -0.044360
# cap_color_buff                     0.067544
# cap_color_cinnamon                -0.030910
# cap_color_gray                    -0.046456
# cap_color_green                   -0.042854
# cap_color_pink                     0.034702
# cap_color_red                      0.097112
# cap_color_white                   -0.133683
# cap_color_yellow                   0.113014
# has_bruises_False                  0.501530
# odor_almond                       -0.219529
# odor_anise                        -0.219529
# odor_creosote                      0.161278
# odor_fishy                         0.286360
# odor_foul                          0.623842
# odor_none                         -0.785557
# odor_pungent                       0.186984
# odor_spicy                         0.286360
# gill_attachment_free               0.129200
# gill_spacing_close                 0.348387
# gill_size_broad                   -0.540024
# gill_color_black                  -0.149641
# gill_color_brown                  -0.288943
# gill_color_buff                    0.538808
# gill_color_chocolate               0.150694
# gill_color_gray                    0.120285
# gill_color_green                   0.056426
# gill_color_pink                   -0.050380
# gill_color_purple                 -0.195359
# gill_color_red                    -0.105491
# gill_color_white                  -0.231316
# gill_color_yellow                 -0.046828
# stalk_shape_tapering              -0.102019
# stalk_surface_above_ring_scaly    -0.016198
# stalk_surface_above_ring_silky     0.587658
# stalk_surface_above_ring_smooth   -0.491314
# stalk_surface_belows_ring_k        0.573524
# stalk_surface_belows_ring_s       -0.425444
# stalk_surface_belows_ring_y       -0.081674
# stalk_color_above_ring_brown       0.233164
# stalk_color_above_ring_buff        0.245662
# stalk_color_above_ring_cinnamon    0.069159
# stalk_color_above_ring_gray       -0.266489
# stalk_color_above_ring_orange     -0.150087
# stalk_color_above_ring_pink        0.230277
# stalk_color_above_ring_red        -0.105491
# stalk_color_above_ring_white      -0.217740
# stalk_color_below_ring_brown       0.203966
# stalk_color_below_ring_buff        0.245662
# stalk_color_below_ring_gray       -0.266489
# stalk_color_below_ring_orange     -0.150087
# stalk_color_below_ring_pink        0.230277
# stalk_color_below_ring_red        -0.105491
# stalk_color_below_ring_white      -0.214112
# stalk_color_below_ring_yellow      0.056426
# veil_type_partial                       NaN
# veil_color_brown                  -0.105491
# veil_color_white                   0.140541
# veil_color_yellow                  0.032545
# number_of_rings_o                  0.182101
# number_of_rings_t                 -0.204600
# ring_type_evanescent               0.223286
# ring_type_flaring                 -0.074371
# ring_type_large                    0.451619
# ring_type_pendant                 -0.540469
# spore_p_color_black               -0.396832
# spore_p_color_brown               -0.416645
# spore_p_color_chocolate            0.490229
# spore_p_color_green                0.098024
# spore_p_color_orange              -0.074371
# spore_p_color_purple              -0.074371
# spore_p_color_white                0.357384
# spore_p_color_yellow              -0.074371
# pop_clustered                     -0.137645
# pop_numerous                      -0.219529
# pop_scattered                     -0.159572
# pop_several                        0.443722
# pop_solitary                      -0.107055
# habitat_grasses                   -0.165004
# habitat_leaves                     0.155150
# habitat_meadows                   -0.138627
# habitat_paths                      0.323346
# habitat_urban                      0.112078
# habitat_woods                     -0.126123
# dtype: float64

# %%
def phi_coefficient(x, y):
    n11 = np.sum((x == 1) & (y == 1))
    n10 = np.sum((x == 1) & (y == 0))
    n01 = np.sum((x == 0) & (y == 1))
    n00 = np.sum((x == 0) & (y == 0))
    
    # Handle division by zero
    if (n11 + n10) * (n11 + n01) * (n10 + n00) * (n01 + n00) == 0:
        return np.nan
    
    phi = (n11 * n00 - n10 * n01) / np.sqrt((n11 + n10) * (n11 + n01) * (n10 + n00) * (n01 + n00))
    return phi

# Computing the phi coefficient correlation with the target variable:
phi_with_target = pd.Series(index=df.columns, dtype=float)
for col in df.columns:
    if col != 'is_poisonous':  # Avoid computing phi with the target variable itself
        phi_with_target[col] = phi_coefficient(df[col], df['is_poisonous'])

# Extracting variables with phi coefficient > 0.7 with the target variable
high_phi_with_target = phi_with_target[abs(phi_with_target) > 0.7]

# Printing variables with phi coefficient > 0.7 with the target variable
print("Variables with absolute phi coefficient > 0.7 with the target variable:")
print(high_phi_with_target)
# Out:
# Variables with absolute phi coefficient > 0.7 with the target variable:
# odor_none   -0.785557
# dtype: float64

# %% [markdown]
# ##### Baseline Model: The Logisitic Regression Model
#
# We have chosen the logistic regression model as the classifier for predicting mushroom toxicity due to its popularity and effectiveness in binary classification tasks. Logistic regression is well-suited for this mushroom toxicity capstone as it offers simplicity, interpretability, and robust performance. By leveraging logistic regression, we aim to build a reliable classifier that accurately distinguishes between poisonous and edible mushrooms based on various features.
#
# We will first run our model using a 20/80 split and we will inlcude the classification report for evaluation metrics.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Splitting the dataset into features (X) and target variable (y):
X = df.drop(columns=['is_poisonous'])  
y = df['is_poisonous'] 

# Splitting the data into train and test sets:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1212)

# Initializing the logistic regression model:
logistic_model = LogisticRegression(max_iter=1000)  

# Training the model on the training data:
logistic_model.fit(X_train, y_train)

# Making predictions on the train and test data:
y_train_pred = logistic_model.predict(X_train)
y_test_pred = logistic_model.predict(X_test)

# Evaluating the model on training data:
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy)

# Evaluating the model on test data:
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)

# Generating a classification report for test data:
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Training Accuracy: 0.9998461301738729
# Test Accuracy: 0.9987692307692307
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       839
#            1       1.00      1.00      1.00       786
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %% [markdown]
# ##### Observations:

# %% [markdown]
# We achieved exceptionally high accuracy rates with our logistic regression classifier for predicting mushroom toxicity. During training, the model demonstrated outstanding performance with an accuracy of 99.98%. This high level of accuracy was also maintained during testing, with a test accuracy of 99.88%.
#
# The classification report further confirms the robustness of our classifier, with precision, recall, and F1-score all reaching 100% for both classes (poisonous and non-poisonous mushrooms). These findings indicate that our logistic regression model effectively distinguishes between poisonous and non-poisonous mushrooms based on the given features, making it a reliable tool for mushroom toxicity classification.

# %% [markdown]
# ##### Advanced Model Evaluation Techniques

# %% [markdown]
# Now we plan to conduct cross-validation to ensure the robustness of our model across different datasets. Additionally, we will generate a confusion matrix and perform ROC analysis to further evaluate the model's performance and explore its sensitivity and specificity.

# %% [markdown]
# ##### Cross-Validation using a 5-fold

# %% [markdown]
# Cross-validation helps assess the generalization ability of the model by evaluating its performance on multiple subsets of the data, thereby reducing the risk of overfitting and providing more reliable performance estimates. In our case, we will be using a 5-fold cross-validation technique to assess the performance of our model.

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LogisticRegression

# Defining the number of folds for cross-validation:
num_folds = 5

# Initializing the logistic regression model:
logistic_model = LogisticRegression(max_iter=1000)  

# Defining the cross-validation strategy:
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Performing cross-validation:
cv_scores = cross_val_score(logistic_model, X, y, cv=kfold, scoring='accuracy')

# Displaying the cross-validation scores:
print("Cross-validation scores:", cv_scores)

# Calculating the mean and standard deviation of the cross-validation scores:
mean_cv_score = cv_scores.mean()
std_cv_score = cv_scores.std()

print("Mean cross-validation score:", mean_cv_score)
print("Standard deviation of cross-validation scores:", std_cv_score)
# Out:
# Cross-validation scores: [1.         0.99938462 1.         1.         0.99938424]
# Mean cross-validation score: 0.9997537703675634
# Standard deviation of cross-validation scores: 0.00030156850331830007

# %% [markdown]
# ##### Observations:
#
# Based on the cross-validation scores, it appears that the logistic regression model performs extremely well on our dataset. The mean cross-validation score is very close to 1, indicating high accuracy across different folds of the data. Additionally, the standard deviation of the cross-validation scores is very low (0.0003), suggesting that the model's performance is consistent across different splits of the data. The high consistency suggests that our model generalizes well to unseen data, which is a positive indicator of its reliability.

# %% [markdown]
# ##### Confusion Matrix
#
# The confusion matrix offers a detailed breakdown of correct and incorrect predictions, allowing for a better understanding of classification errors. Let us create a confusion matrix for our model.

# %%
from sklearn.metrics import confusion_matrix

# Fitting logistic regression model:
logistic_model.fit(X_train, y_train)

# Making predictions on the test data:
y_pred = logistic_model.predict(X_test)

# Generating a confusion matrix: 
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[839   0]
#  [  2 784]]

# %% [markdown]
# ##### Observations:
#
# Our confusion matrix indicates the following:
#
# * True Negative (TN): 839
# * False Positive (FP): 0
# * False Negative (FN): 2
# * True Positive (TP): 784
#
# Furthermore, we can observe that:
#
# * The model correctly predicted 839 instances of class 0 (non-poisonous) as non-poisonous.
# * There were no instances of class 0 that were incorrectly predicted as poisonous (False Positive).
# * The model correctly predicted 784 instances of class 1 (poisonous) as poisonous.
# * There were 2 instances of class 1 that were incorrectly predicted as non-poisonous (False Negative).

# %% [markdown]
# Overall, our model performs very well, with a high number of true positives and true negatives and very few misclassifications.

# %% [markdown]
# ##### ROC Analysis
#
# ROC analysis assesses the trade-off between true positive and false positive rates across different threshold values, offering insights into model sensitivity and specificity. Let us run ROC analysis with our model.

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Computing predicted probabilities for the positive class:
y_prob = logistic_model.predict_proba(X_test)[:, 1]

# Computing ROC curve and ROC area for each class:
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plotting ROC curve:
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##### Observations:
#
# For our ROC Curve plot, we have the following observations:
#
# * The blue line represents the ROC curve itself. In our case, the blue line appears perfectly linear, indicating that the model is making perfect predictions. This means that the true positive rate is always equal to the false positive rate, resulting in an area under the curve (AUC) of 1.
#
# * The orange line represents the ROC curve for a random classifier. Since it's perfectly horizontal at a true positive rate of 1, it suggests that the model's performance is significantly better than random chance.
#
# * The AUC is a quantitative measure of the overall performance of the model. An AUC of 1 indicates a perfect classifier, while an AUC of 0.5 suggests that the classifier performs no better than random chance. In our case, the AUC value of 1 indicates that the model has excellent predictive ability, with perfect discrimination between the positive and negative classes.

# %% [markdown]
# ##### Feature Importance
#
# Here we will look into feature importance, which is a crucial aspect of understanding the predictive power of our model. Examining feature importance provides valuable insights into which variables contribute most significantly to our model's predictive performance. Features with higher coefficients carry greater weight in determining the target outcome.

# %%
# Extracting feature coefficients:
feature_coefficients = logistic_model.coef_[0]

# Computing feature importance as absolute coefficients:
feature_importance = np.abs(feature_coefficients)

# Creating a DataFrame to store feature importance scores:
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})

# Sorting features by importance (descending order):
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Ploting feature importance
plt.figure(figsize=(12, 14))
barplot = plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')

# Increasing font size for y-axis labels:
plt.yticks(fontsize=9)

# Showing plot:
plt.tight_layout()
plt.show()

# Displaying feature importance scores
print("Feature Importance Scores:")
print(feature_importance_df)
# Out:
# Feature Importance Scores:
#                             Feature  Importance
# 76              spore_p_color_green    4.584006
# 23                        odor_none    4.182939
# 28                  gill_size_broad    3.489320
# 18                      odor_almond    3.474180
# 19                       odor_anise    3.431935
# 20                    odor_creosote    3.321845
# 22                        odor_foul    3.191362
# 24                     odor_pungent    2.407654
# 70                ring_type_flaring    2.136418
# 74              spore_p_color_brown    1.774806
# 31                  gill_color_buff    1.731304
# 73              spore_p_color_black    1.607245
# 27               gill_spacing_close    1.595312
# 42   stalk_surface_above_ring_silky    1.574699
# 78             spore_p_color_purple    1.509716
# 46      stalk_surface_belows_ring_y    1.395635
# 82                     pop_numerous    1.191705
# 71                  ring_type_large    1.151898
# 81                    pop_clustered    1.143207
# 13                   cap_color_pink    0.998810
# 75          spore_p_color_chocolate    0.980048
# 62    stalk_color_below_ring_yellow    0.964226
# 5               cap_surface_fibrous    0.920536
# 9                    cap_color_buff    0.908583
# 43  stalk_surface_above_ring_smooth    0.888882
# 85                     pop_solitary    0.850576
# 21                       odor_fishy    0.833262
# 25                       odor_spicy    0.823145
# 84                      pop_several    0.818442
# 34                 gill_color_green    0.817536
# 37                   gill_color_red    0.717303
# 53       stalk_color_above_ring_red    0.714114
# 60       stalk_color_below_ring_red    0.693257
# 58    stalk_color_below_ring_orange    0.657956
# 51    stalk_color_above_ring_orange    0.657956
# 10               cap_color_cinnamon    0.656851
# 40             stalk_shape_tapering    0.647500
# 88                  habitat_meadows    0.601883
# 30                 gill_color_brown    0.583310
# 66                veil_color_yellow    0.569399
# 44      stalk_surface_belows_ring_k    0.560251
# 87                   habitat_leaves    0.545778
# 15                  cap_color_white    0.530574
# 49  stalk_color_above_ring_cinnamon    0.512006
# 4                  cap_shape_sunken    0.498240
# 29                 gill_color_black    0.487208
# 72                ring_type_pendant    0.475188
# 17                has_bruises_False    0.461650
# 12                  cap_color_green    0.448837
# 68                number_of_rings_t    0.445999
# 35                  gill_color_pink    0.409274
# 8                   cap_color_brown    0.409032
# 50      stalk_color_above_ring_gray    0.376922
# 57      stalk_color_below_ring_gray    0.374488
# 55     stalk_color_below_ring_brown    0.357260
# 48      stalk_color_above_ring_buff    0.345802
# 26             gill_attachment_free    0.334247
# 59      stalk_color_below_ring_pink    0.315534
# 6                 cap_surface_scaly    0.305720
# 86                  habitat_grasses    0.298878
# 52      stalk_color_above_ring_pink    0.294573
# 56      stalk_color_below_ring_buff    0.293780
# 16                 cap_color_yellow    0.292754
# 36                gill_color_purple    0.289041
# 41   stalk_surface_above_ring_scaly    0.288291
# 0                    cap_shape_bell    0.285617
# 64                 veil_color_brown    0.280188
# 90                    habitat_urban    0.263673
# 1                  cap_shape_convex    0.226390
# 91                    habitat_woods    0.218281
# 80             spore_p_color_yellow    0.207225
# 77             spore_p_color_orange    0.194863
# 39                gill_color_yellow    0.188361
# 47     stalk_color_above_ring_brown    0.143924
# 7                cap_surface_smooth    0.132814
# 83                    pop_scattered    0.126490
# 45      stalk_surface_belows_ring_s    0.121878
# 54     stalk_color_above_ring_white    0.116492
# 3                 cap_shape_knobbed    0.115589
# 2                    cap_shape_flat    0.109878
# 65                 veil_color_white    0.088777
# 38                 gill_color_white    0.085135
# 67                number_of_rings_o    0.065787
# 79              spore_p_color_white    0.052955
# 32             gill_color_chocolate    0.041659
# 11                   cap_color_gray    0.039690
# 89                    habitat_paths    0.035745
# 14                    cap_color_red    0.035343
# 33                  gill_color_gray    0.019803
# 69             ring_type_evanescent    0.002454
# 61     stalk_color_below_ring_white    0.002365
# 63                veil_type_partial    0.000220

# %% [markdown]
# ##### Beyond Perfection
#
# We have seen that our model has perfect perdictive powers. However, this does not necessarily imply that we have found a perfect model. In fact, models that run with near-perfect accuracy on their first try should always be subjected to deeper scrutiny. We will continue this notebook by exploring the dataset further, including look at feature importance and unusual predictors, collinearity between features, data leakage, and robustness checks.
#
# Moreover, our aim will also be to create a dataset that is less perfect and more challenging. The following techniques might be employed:
#
# * Introduce Noise: Adding noise to the dataset by perturbing feature values or adding random noise can help make the dataset more realistic and challenging for our model.
#
#
# * Feature Selection: Identifying and removing features that are highly correlated with the target variable or with each other. This can help reduce the complexity of the model and prevent it from memorizing irrelevant patterns.
#
#
# * Feature Engineering: Creating new features or transforming existing ones to introduce additional complexity or variability into the dataset.
#
#
# * Data Augmentation: Generating synthetic data points by applying transformations or perturbations to existing data points.
#
#
# * Resampling Techniques: Using techniques like oversampling (e.g., SMOTE) or undersampling to balance the class distribution in the dataset. This can prevent the model from being biased towards the majority class and encourage it to learn from the minority class as well.
